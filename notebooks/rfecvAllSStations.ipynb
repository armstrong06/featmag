# %%
import numpy as np
import pandas as pd
from sklearn.base import clone 
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import json
import sys
import os
# make paths above 'notebooks/' visible for local imports.
# +----------------------------------------------------------------------------+
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.processing import GatherFeatureDatasets
from src.feature_selection import RFE
from src import plotting
from src.utils import write_dict_to_json

# %%
proc = GatherFeatureDatasets(is_p=False)

# %%
data_dir = '/uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_splits'
train = pd.read_csv(f'{data_dir}/s.train.csv')
test = pd.read_csv(f'{data_dir}/s.test.csv')
outfile_dir = '/uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv'
outfile_name = 'SVR.sr'

# %%
station_feature_dict, station_meta_dict, feature_names = proc.process_all_stations_datasets(train, 
                                                                  test, 
                                                                  scaler=False,
                                                                  linear_model=False,
                                                                  source_dist_type='dist')
# Out:
# YHB
# X shape: (942, 45), y shape: (942,)
# X shape: (227, 45), y shape: (227,)
# YHL
# X shape: (468, 45), y shape: (468,)
# X shape: (114, 45), y shape: (114,)
# YMR
# X shape: (1293, 45), y shape: (1293,)
# X shape: (303, 45), y shape: (303,)
# YHH
# X shape: (883, 45), y shape: (883,)
# X shape: (214, 45), y shape: (214,)
# B207
# X shape: (314, 45), y shape: (314,)
# X shape: (81, 45), y shape: (81,)
# FLWY
# X shape: (310, 45), y shape: (310,)
# X shape: (78, 45), y shape: (78,)
# YPP
# X shape: (157, 45), y shape: (157,)
# X shape: (44, 45), y shape: (44,)
# YNR
# X shape: (1784, 45), y shape: (1784,)
# X shape: (454, 45), y shape: (454,)
# YUF
# X shape: (725, 45), y shape: (725,)
# X shape: (190, 45), y shape: (190,)
# YML
# X shape: (421, 45), y shape: (421,)
# X shape: (107, 45), y shape: (107,)
# YFT
# X shape: (741, 45), y shape: (741,)
# X shape: (188, 45), y shape: (188,)
# LKWY
# X shape: (203, 45), y shape: (203,)
# X shape: (53, 45), y shape: (53,)
# YTP
# X shape: (382, 45), y shape: (382,)
# X shape: (93, 45), y shape: (93,)
# B206
# X shape: (196, 45), y shape: (196,)
# X shape: (59, 45), y shape: (59,)
# YMC
# X shape: (1157, 45), y shape: (1157,)
# X shape: (306, 45), y shape: (306,)
# YNM
# X shape: (326, 45), y shape: (326,)
# X shape: (70, 45), y shape: (70,)
# YDD
# X shape: (216, 45), y shape: (216,)
# X shape: (57, 45), y shape: (57,)

# %%
feature_names
# Out:
# array(['amp_ratio_1', 'amp_ratio_2', 'amp_ratio_3', 'amp_ratio_4',
#        'amp_ratio_5', 'amp_ratio_6', 'amp_ratio_7', 'amp_ratio_8',
#        'amp_ratio_9', 'amp_ratio_10', 'amp_ratio_11', 'amp_ratio_12',
#        'amp_ratio_13', 'amp_ratio_14', 'amp_ratio_15', 'amp_ratio_16',
#        'amp_ratio_17', 'amp_ratio_18', 'amp_1', 'amp_2', 'amp_3', 'amp_4',
#        'amp_5', 'amp_6', 'amp_7', 'amp_8', 'amp_9', 'amp_10', 'amp_11',
#        'amp_12', 'amp_13', 'amp_14', 'amp_15', 'amp_16', 'amp_17',
#        'amp_18', 'signal_dominant_frequency', 'signal_dominant_amplitude',
#        'noise_max_amplitude', 'signal_max_amplitude', 'signal_variance',
#        'noise_variance', 'source_depth_km',
#        'source_receiver_distance_logkm',
#        'source_receiver_back_azimuth_deg'], dtype='<U32')

# %%
feature_subset = ['amp_ratio_1', 'amp_ratio_2', 'amp_ratio_3', 'amp_ratio_4',
                    'amp_1', 'amp_2', 'amp_3', 'amp_4','amp_5', 'signal_dominant_frequency',
                    'signal_dominant_amplitude',
                    'noise_max_amplitude', 'signal_max_amplitude', 'signal_variance',
                    'noise_variance', 'source_depth_km',
                    'source_receiver_distance_logkm',
                    'source_receiver_back_azimuth_deg']

# %%
selected_feat_dict, selected_feature_names = proc.filter_station_dict_features(station_feature_dict,
                                                                                feature_names,
                                                                                feature_subset)
# Out:
# YHB
# X_train: (942, 18), X_test: (227, 18)
# YHL
# X_train: (468, 18), X_test: (114, 18)
# YMR
# X_train: (1293, 18), X_test: (303, 18)
# YHH
# X_train: (883, 18), X_test: (214, 18)
# B207
# X_train: (314, 18), X_test: (81, 18)
# FLWY
# X_train: (310, 18), X_test: (78, 18)
# YPP
# X_train: (157, 18), X_test: (44, 18)
# YNR
# X_train: (1784, 18), X_test: (454, 18)
# YUF
# X_train: (725, 18), X_test: (190, 18)
# YML
# X_train: (421, 18), X_test: (107, 18)
# YFT
# X_train: (741, 18), X_test: (188, 18)
# LKWY
# X_train: (203, 18), X_test: (53, 18)
# YTP
# X_train: (382, 18), X_test: (93, 18)
# B206
# X_train: (196, 18), X_test: (59, 18)
# YMC
# X_train: (1157, 18), X_test: (306, 18)
# YNM
# X_train: (326, 18), X_test: (70, 18)
# YDD
# X_train: (216, 18), X_test: (57, 18)

# %%
### Set Parameters ###
# The model to used to estimate feature importance 
estimator_model =  DecisionTreeRegressor()
# Boolean - True if data for estimator_model needs to be scaled
estimator_scaler = False
# The main model to fit
model = SVR(kernel='rbf')
# Boolean - True if data for model needs to be scaled 
model_scaler = True
# The scoring method to use in RFECV and GridCV
scoring_method = 'r2'
# The function used to evaluate the performance on the test model
score_func = r2_score
# The parameter space for GridCV to search
# Decrease upper-limit of C for linear model because 100 is very slow 
svr_Cspace = [0.1, 1, 10, 100, 1000]
svr_gspace = [1, 0.1, 0.01, 0.001]
param_grid = [
    {'m__C': svr_Cspace, 'm__gamma': svr_gspace},
]
# The number of jobs for RFECV and GridCV to use
n_jobs = 10
# number of folds for outer CV
cv_folds_outer = 5
# number of folds for inner cv
cv_folds_inner = 5
n_outer_repeats = 2
# Run grid search over all features
run_gridsearchcv_all = True
#####################

# %%
#stat_important_feat_dict = {}
stat_results = {}
for stat in selected_feat_dict.keys():
    print(stat)
    X = selected_feat_dict[stat]['X_train']
    y = station_meta_dict[stat]['y_train']
    results = RFE.nested_rfecv(X, y, estimator_model, clone(model), param_grid, 
                                estimator_scaler=estimator_scaler, 
                                model_scaler=model_scaler, 
                                scoring_method=scoring_method,
                                score_func=score_func,
                                n_jobs=n_jobs, 
                                cv_folds_outer=cv_folds_outer, 
                                cv_folds_inner=cv_folds_inner,
                                n_outer_repeats=n_outer_repeats,
                                run_gridsearchcv_all_feats=run_gridsearchcv_all)
    
    filename = os.path.join(outfile_dir, f'{stat}.{outfile_name}.json')
    write_dict_to_json(filename, results)

    # feat_usage_df = RFE.count_feature_usage(results['optfts_bool'], selected_feature_names)
    # if_usage = RFE.import_feats_by_usage(feat_usage_df, thresh=(cv_folds_outer*n_outer_repeats)//2)
    # if_best = RFE.important_feats_by_best_model(results, selected_feature_names)
    # impfeat_cnts_df = RFE.combine_important_features([if_usage, if_best], feat_usage_df)

    #stat_important_feat_dict[stat] = impfeat_cnts_df
    stat_results[stat] = results

filename = os.path.join(outfile_dir, f'all.{outfile_name}.json')
write_dict_to_json(filename, stat_results)
# Out:
# YHB
# Fold 0: test score (10 best feats): 0.939, test score (all feats): 0.941, diff: -0.002, time: 7.93 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 1: test score (7 best feats): 0.954, test score (all feats): 0.965, diff: -0.011, time: 10.02 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 2: test score (12 best feats): 0.962, test score (all feats): 0.960, diff: 0.002, time: 6.64 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 3: test score (4 best feats): 0.922, test score (all feats): 0.937, diff: -0.015, time: 15.54 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 4: test score (6 best feats): 0.953, test score (all feats): 0.959, diff: -0.006, time: 8.19 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 5: test score (4 best feats): 0.945, test score (all feats): 0.960, diff: -0.015, time: 16.73 s, best model params: {'m__C': 100, 'm__gamma': 0.1}
# Fold 6: test score (6 best feats): 0.943, test score (all feats): 0.959, diff: -0.016, time: 8.40 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 7: test score (8 best feats): 0.938, test score (all feats): 0.932, diff: 0.005, time: 8.72 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 8: test score (5 best feats): 0.942, test score (all feats): 0.957, diff: -0.015, time: 8.83 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 9: test score (8 best feats): 0.951, test score (all feats): 0.959, diff: -0.007, time: 7.87 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Total time: 98.86 s (1.65 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YHB.SVR.sr.json
# YHL
# Fold 0: test score (6 best feats): 0.914, test score (all feats): 0.942, diff: -0.028, time: 2.71 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 1: test score (7 best feats): 0.951, test score (all feats): 0.944, diff: 0.006, time: 2.51 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 2: test score (4 best feats): 0.928, test score (all feats): 0.942, diff: -0.014, time: 3.16 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 3: test score (4 best feats): 0.937, test score (all feats): 0.948, diff: -0.011, time: 3.64 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 4: test score (8 best feats): 0.912, test score (all feats): 0.916, diff: -0.003, time: 2.39 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 5: test score (6 best feats): 0.944, test score (all feats): 0.946, diff: -0.002, time: 2.90 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 6: test score (5 best feats): 0.939, test score (all feats): 0.936, diff: 0.003, time: 2.59 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 7: test score (4 best feats): 0.938, test score (all feats): 0.951, diff: -0.014, time: 3.18 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 8: test score (4 best feats): 0.894, test score (all feats): 0.923, diff: -0.029, time: 3.14 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 9: test score (4 best feats): 0.930, test score (all feats): 0.937, diff: -0.007, time: 3.03 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Total time: 29.24 s (0.49 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YHL.SVR.sr.json
# YMR
# Fold 0: test score (9 best feats): 0.936, test score (all feats): 0.920, diff: 0.016, time: 15.63 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 1: test score (7 best feats): 0.931, test score (all feats): 0.934, diff: -0.002, time: 17.41 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 2: test score (7 best feats): 0.946, test score (all feats): 0.949, diff: -0.003, time: 16.13 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 3: test score (9 best feats): 0.951, test score (all feats): 0.947, diff: 0.003, time: 16.28 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 4: test score (8 best feats): 0.955, test score (all feats): 0.952, diff: 0.004, time: 13.35 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 5: test score (7 best feats): 0.957, test score (all feats): 0.959, diff: -0.002, time: 16.24 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 6: test score (8 best feats): 0.945, test score (all feats): 0.946, diff: -0.002, time: 17.76 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 7: test score (6 best feats): 0.927, test score (all feats): 0.941, diff: -0.014, time: 16.23 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 8: test score (14 best feats): 0.942, test score (all feats): 0.916, diff: 0.026, time: 13.83 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 9: test score (7 best feats): 0.926, test score (all feats): 0.927, diff: -0.001, time: 15.76 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Total time: 158.62 s (2.64 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YMR.SVR.sr.json
# YHH
# Fold 0: test score (6 best feats): 0.872, test score (all feats): 0.879, diff: -0.007, time: 11.24 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 1: test score (10 best feats): 0.895, test score (all feats): 0.904, diff: -0.008, time: 7.89 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 2: test score (10 best feats): 0.883, test score (all feats): 0.886, diff: -0.002, time: 7.50 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 3: test score (7 best feats): 0.855, test score (all feats): 0.886, diff: -0.031, time: 11.28 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 4: test score (8 best feats): 0.880, test score (all feats): 0.895, diff: -0.015, time: 10.71 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 5: test score (5 best feats): 0.864, test score (all feats): 0.898, diff: -0.034, time: 10.60 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 6: test score (5 best feats): 0.861, test score (all feats): 0.882, diff: -0.021, time: 11.06 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 7: test score (6 best feats): 0.853, test score (all feats): 0.915, diff: -0.062, time: 10.58 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 8: test score (11 best feats): 0.879, test score (all feats): 0.892, diff: -0.013, time: 8.18 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 9: test score (16 best feats): 0.896, test score (all feats): 0.903, diff: -0.007, time: 8.81 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Total time: 97.84 s (1.63 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YHH.SVR.sr.json
# B207
# Fold 0: test score (4 best feats): 0.938, test score (all feats): 0.961, diff: -0.023, time: 1.60 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 1: test score (7 best feats): 0.917, test score (all feats): 0.921, diff: -0.004, time: 0.98 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 2: test score (7 best feats): 0.872, test score (all feats): 0.880, diff: -0.008, time: 1.11 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 3: test score (5 best feats): 0.854, test score (all feats): 0.871, diff: -0.017, time: 1.39 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 4: test score (4 best feats): 0.932, test score (all feats): 0.941, diff: -0.009, time: 1.66 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 5: test score (5 best feats): 0.911, test score (all feats): 0.925, diff: -0.014, time: 1.47 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 6: test score (10 best feats): 0.943, test score (all feats): 0.933, diff: 0.010, time: 1.10 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 7: test score (11 best feats): 0.925, test score (all feats): 0.914, diff: 0.011, time: 1.00 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 8: test score (18 best feats): 0.918, test score (all feats): 0.918, diff: -0.000, time: 0.98 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 9: test score (5 best feats): 0.924, test score (all feats): 0.913, diff: 0.011, time: 1.29 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Total time: 12.57 s (0.21 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/B207.SVR.sr.json
# FLWY
# Fold 0: test score (11 best feats): 0.803, test score (all feats): 0.802, diff: 0.001, time: 1.29 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 1: test score (5 best feats): 0.738, test score (all feats): 0.708, diff: 0.030, time: 1.72 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 2: test score (9 best feats): 0.810, test score (all feats): 0.844, diff: -0.034, time: 1.23 s, best model params: {'m__C': 1, 'm__gamma': 0.01}
# Fold 3: test score (7 best feats): 0.792, test score (all feats): 0.820, diff: -0.028, time: 1.73 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 4: test score (7 best feats): 0.734, test score (all feats): 0.745, diff: -0.010, time: 1.56 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 5: test score (10 best feats): 0.746, test score (all feats): 0.751, diff: -0.005, time: 1.29 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 6: test score (3 best feats): 0.788, test score (all feats): 0.872, diff: -0.085, time: 1.90 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 7: test score (6 best feats): 0.635, test score (all feats): 0.712, diff: -0.077, time: 1.62 s, best model params: {'m__C': 1, 'm__gamma': 0.01}
# Fold 8: test score (11 best feats): 0.812, test score (all feats): 0.810, diff: 0.002, time: 1.27 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 9: test score (13 best feats): 0.781, test score (all feats): 0.815, diff: -0.034, time: 1.40 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Total time: 15.00 s (0.25 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/FLWY.SVR.sr.json
# YPP
# Fold 0: test score (17 best feats): 0.929, test score (all feats): 0.927, diff: 0.002, time: 0.47 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 1: test score (4 best feats): 0.872, test score (all feats): 0.896, diff: -0.024, time: 0.60 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 2: test score (4 best feats): 0.817, test score (all feats): 0.904, diff: -0.087, time: 0.63 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 3: test score (3 best feats): 0.892, test score (all feats): 0.856, diff: 0.036, time: 0.71 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 4: test score (3 best feats): 0.859, test score (all feats): 0.893, diff: -0.034, time: 0.58 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 5: test score (7 best feats): 0.921, test score (all feats): 0.916, diff: 0.004, time: 0.46 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 6: test score (5 best feats): 0.937, test score (all feats): 0.896, diff: 0.041, time: 0.53 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 7: test score (3 best feats): 0.867, test score (all feats): 0.913, diff: -0.046, time: 0.69 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 8: test score (3 best feats): 0.855, test score (all feats): 0.888, diff: -0.032, time: 0.74 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 9: test score (3 best feats): 0.910, test score (all feats): 0.886, diff: 0.025, time: 0.70 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Total time: 6.12 s (0.10 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YPP.SVR.sr.json
# YNR
# Fold 0: test score (8 best feats): 0.947, test score (all feats): 0.945, diff: 0.002, time: 21.13 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 1: test score (7 best feats): 0.926, test score (all feats): 0.936, diff: -0.011, time: 25.22 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 2: test score (11 best feats): 0.949, test score (all feats): 0.954, diff: -0.005, time: 19.51 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 3: test score (12 best feats): 0.958, test score (all feats): 0.953, diff: 0.005, time: 16.24 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 4: test score (12 best feats): 0.961, test score (all feats): 0.960, diff: 0.001, time: 16.82 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 5: test score (9 best feats): 0.944, test score (all feats): 0.943, diff: 0.000, time: 20.51 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 6: test score (9 best feats): 0.950, test score (all feats): 0.949, diff: 0.001, time: 21.07 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 7: test score (7 best feats): 0.941, test score (all feats): 0.949, diff: -0.007, time: 24.39 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 8: test score (10 best feats): 0.958, test score (all feats): 0.960, diff: -0.002, time: 21.42 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 9: test score (11 best feats): 0.960, test score (all feats): 0.957, diff: 0.002, time: 19.33 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Total time: 205.64 s (3.43 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YNR.SVR.sr.json
# YUF
# Fold 0: test score (17 best feats): 0.943, test score (all feats): 0.942, diff: 0.001, time: 3.94 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 1: test score (6 best feats): 0.933, test score (all feats): 0.936, diff: -0.003, time: 5.33 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 2: test score (5 best feats): 0.910, test score (all feats): 0.920, diff: -0.010, time: 4.88 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 3: test score (14 best feats): 0.909, test score (all feats): 0.908, diff: 0.001, time: 4.02 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 4: test score (5 best feats): 0.700, test score (all feats): 0.849, diff: -0.149, time: 5.42 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 5: test score (3 best feats): 0.906, test score (all feats): 0.921, diff: -0.015, time: 12.66 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 6: test score (8 best feats): 0.948, test score (all feats): 0.945, diff: 0.003, time: 4.74 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 7: test score (5 best feats): 0.899, test score (all feats): 0.913, diff: -0.014, time: 5.38 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 8: test score (3 best feats): 0.914, test score (all feats): 0.942, diff: -0.028, time: 9.58 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 9: test score (5 best feats): 0.888, test score (all feats): 0.926, diff: -0.038, time: 6.04 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Total time: 61.99 s (1.03 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YUF.SVR.sr.json
# YML
# Fold 0: test score (6 best feats): 0.915, test score (all feats): 0.904, diff: 0.011, time: 2.19 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 1: test score (16 best feats): 0.895, test score (all feats): 0.896, diff: -0.002, time: 1.48 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 2: test score (5 best feats): 0.904, test score (all feats): 0.915, diff: -0.011, time: 1.78 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 3: test score (8 best feats): 0.905, test score (all feats): 0.921, diff: -0.015, time: 1.93 s, best model params: {'m__C': 1, 'm__gamma': 0.1}
# Fold 4: test score (4 best feats): 0.883, test score (all feats): 0.857, diff: 0.026, time: 2.01 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 5: test score (7 best feats): 0.871, test score (all feats): 0.875, diff: -0.004, time: 1.96 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 6: test score (3 best feats): 0.903, test score (all feats): 0.902, diff: 0.000, time: 3.45 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 7: test score (6 best feats): 0.913, test score (all feats): 0.901, diff: 0.011, time: 1.93 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 8: test score (4 best feats): 0.925, test score (all feats): 0.901, diff: 0.024, time: 2.04 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 9: test score (2 best feats): 0.887, test score (all feats): 0.913, diff: -0.026, time: 3.18 s, best model params: {'m__C': 1000, 'm__gamma': 0.1}
# Total time: 21.96 s (0.37 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YML.SVR.sr.json
# YFT
# Fold 0: test score (6 best feats): 0.940, test score (all feats): 0.951, diff: -0.011, time: 4.70 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 1: test score (11 best feats): 0.963, test score (all feats): 0.962, diff: 0.001, time: 3.21 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 2: test score (8 best feats): 0.954, test score (all feats): 0.952, diff: 0.002, time: 3.90 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 3: test score (16 best feats): 0.951, test score (all feats): 0.950, diff: 0.001, time: 3.05 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 4: test score (5 best feats): 0.955, test score (all feats): 0.959, diff: -0.004, time: 4.52 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 5: test score (2 best feats): 0.916, test score (all feats): 0.961, diff: -0.045, time: 6.36 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 6: test score (9 best feats): 0.965, test score (all feats): 0.965, diff: 0.001, time: 3.89 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 7: test score (5 best feats): 0.943, test score (all feats): 0.955, diff: -0.013, time: 4.46 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 8: test score (5 best feats): 0.949, test score (all feats): 0.960, diff: -0.011, time: 4.30 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 9: test score (9 best feats): 0.947, test score (all feats): 0.946, diff: 0.001, time: 3.23 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Total time: 41.61 s (0.69 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YFT.SVR.sr.json
# LKWY
# Fold 0: test score (3 best feats): 0.930, test score (all feats): 0.944, diff: -0.014, time: 0.73 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 1: test score (3 best feats): 0.920, test score (all feats): 0.942, diff: -0.022, time: 0.75 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 2: test score (3 best feats): 0.956, test score (all feats): 0.941, diff: 0.015, time: 0.70 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 3: test score (3 best feats): 0.763, test score (all feats): 0.887, diff: -0.124, time: 0.79 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 4: test score (6 best feats): 0.942, test score (all feats): 0.954, diff: -0.012, time: 0.54 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 5: test score (4 best feats): 0.890, test score (all feats): 0.916, diff: -0.026, time: 0.65 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 6: test score (3 best feats): 0.923, test score (all feats): 0.941, diff: -0.019, time: 0.87 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 7: test score (3 best feats): 0.938, test score (all feats): 0.938, diff: 0.001, time: 0.74 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 8: test score (6 best feats): 0.951, test score (all feats): 0.952, diff: -0.001, time: 0.55 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 9: test score (3 best feats): 0.947, test score (all feats): 0.950, diff: -0.003, time: 0.69 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Total time: 7.02 s (0.12 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/LKWY.SVR.sr.json
# YTP
# Fold 0: test score (3 best feats): 0.911, test score (all feats): 0.900, diff: 0.011, time: 3.44 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 1: test score (4 best feats): 0.801, test score (all feats): 0.863, diff: -0.062, time: 1.91 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 2: test score (4 best feats): 0.863, test score (all feats): 0.880, diff: -0.017, time: 1.57 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 3: test score (3 best feats): 0.884, test score (all feats): 0.873, diff: 0.010, time: 2.98 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 4: test score (3 best feats): 0.879, test score (all feats): 0.916, diff: -0.037, time: 2.23 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 5: test score (4 best feats): 0.861, test score (all feats): 0.834, diff: 0.027, time: 1.68 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 6: test score (3 best feats): 0.874, test score (all feats): 0.890, diff: -0.016, time: 2.81 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 7: test score (3 best feats): 0.865, test score (all feats): 0.876, diff: -0.011, time: 2.65 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 8: test score (5 best feats): 0.836, test score (all feats): 0.870, diff: -0.033, time: 1.89 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 9: test score (4 best feats): 0.904, test score (all feats): 0.920, diff: -0.016, time: 1.71 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Total time: 22.86 s (0.38 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YTP.SVR.sr.json
# B206
# Fold 0: test score (3 best feats): 0.927, test score (all feats): 0.927, diff: -0.000, time: 0.94 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 1: test score (4 best feats): 0.935, test score (all feats): 0.945, diff: -0.010, time: 0.82 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 2: test score (4 best feats): 0.944, test score (all feats): 0.932, diff: 0.012, time: 0.76 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 3: test score (5 best feats): 0.965, test score (all feats): 0.945, diff: 0.019, time: 0.65 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 4: test score (3 best feats): 0.890, test score (all feats): 0.941, diff: -0.051, time: 0.71 s, best model params: {'m__C': 1, 'm__gamma': 0.1}
# Fold 5: test score (5 best feats): 0.950, test score (all feats): 0.946, diff: 0.004, time: 0.74 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 6: test score (4 best feats): 0.936, test score (all feats): 0.951, diff: -0.014, time: 0.80 s, best model params: {'m__C': 1, 'm__gamma': 0.1}
# Fold 7: test score (3 best feats): 0.892, test score (all feats): 0.903, diff: -0.011, time: 0.77 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 8: test score (4 best feats): 0.873, test score (all feats): 0.893, diff: -0.020, time: 0.78 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 9: test score (10 best feats): 0.949, test score (all feats): 0.953, diff: -0.005, time: 0.63 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Total time: 7.61 s (0.13 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/B206.SVR.sr.json
# YMC
# Fold 0: test score (7 best feats): 0.758, test score (all feats): 0.760, diff: -0.002, time: 17.47 s, best model params: {'m__C': 1, 'm__gamma': 0.1}
# Fold 1: test score (9 best feats): 0.817, test score (all feats): 0.822, diff: -0.006, time: 12.44 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 2: test score (16 best feats): 0.809, test score (all feats): 0.799, diff: 0.010, time: 13.91 s, best model params: {'m__C': 10, 'm__gamma': 0.01}
# Fold 3: test score (8 best feats): 0.796, test score (all feats): 0.797, diff: -0.001, time: 17.30 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 4: test score (8 best feats): 0.821, test score (all feats): 0.847, diff: -0.026, time: 16.52 s, best model params: {'m__C': 1, 'm__gamma': 0.1}
# Fold 5: test score (9 best feats): 0.802, test score (all feats): 0.820, diff: -0.019, time: 13.10 s, best model params: {'m__C': 1, 'm__gamma': 0.1}
# Fold 6: test score (8 best feats): 0.823, test score (all feats): 0.832, diff: -0.010, time: 14.54 s, best model params: {'m__C': 1, 'm__gamma': 0.1}
# Fold 7: test score (8 best feats): 0.778, test score (all feats): 0.777, diff: 0.001, time: 16.51 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 8: test score (16 best feats): 0.821, test score (all feats): 0.820, diff: 0.002, time: 11.44 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 9: test score (13 best feats): 0.782, test score (all feats): 0.796, diff: -0.014, time: 10.72 s, best model params: {'m__C': 1, 'm__gamma': 0.1}
# Total time: 143.95 s (2.40 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YMC.SVR.sr.json
# YNM
# Fold 0: test score (6 best feats): 0.909, test score (all feats): 0.923, diff: -0.014, time: 1.22 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 1: test score (5 best feats): 0.936, test score (all feats): 0.944, diff: -0.008, time: 1.58 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 2: test score (4 best feats): 0.933, test score (all feats): 0.945, diff: -0.012, time: 1.56 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 3: test score (18 best feats): 0.940, test score (all feats): 0.940, diff: -0.000, time: 0.77 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 4: test score (9 best feats): 0.964, test score (all feats): 0.960, diff: 0.004, time: 1.08 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 5: test score (5 best feats): 0.946, test score (all feats): 0.949, diff: -0.003, time: 1.41 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 6: test score (8 best feats): 0.958, test score (all feats): 0.956, diff: 0.002, time: 1.08 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 7: test score (8 best feats): 0.921, test score (all feats): 0.914, diff: 0.006, time: 1.02 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Fold 8: test score (12 best feats): 0.928, test score (all feats): 0.940, diff: -0.012, time: 1.11 s, best model params: {'m__C': 10, 'm__gamma': 0.001}
# Fold 9: test score (6 best feats): 0.958, test score (all feats): 0.963, diff: -0.005, time: 1.35 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Total time: 12.19 s (0.20 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YNM.SVR.sr.json
# YDD
# Fold 0: test score (4 best feats): 0.853, test score (all feats): 0.904, diff: -0.052, time: 0.85 s, best model params: {'m__C': 1000, 'm__gamma': 0.01}
# Fold 1: test score (4 best feats): 0.923, test score (all feats): 0.921, diff: 0.002, time: 0.76 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 2: test score (4 best feats): 0.925, test score (all feats): 0.921, diff: 0.003, time: 0.82 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 3: test score (3 best feats): 0.940, test score (all feats): 0.940, diff: -0.000, time: 0.77 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 4: test score (4 best feats): 0.907, test score (all feats): 0.889, diff: 0.018, time: 0.72 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 5: test score (9 best feats): 0.945, test score (all feats): 0.944, diff: 0.001, time: 0.65 s, best model params: {'m__C': 1000, 'm__gamma': 0.001}
# Fold 6: test score (4 best feats): 0.947, test score (all feats): 0.945, diff: 0.002, time: 0.76 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 7: test score (3 best feats): 0.902, test score (all feats): 0.931, diff: -0.029, time: 0.91 s, best model params: {'m__C': 10, 'm__gamma': 0.1}
# Fold 8: test score (5 best feats): 0.891, test score (all feats): 0.903, diff: -0.012, time: 0.75 s, best model params: {'m__C': 100, 'm__gamma': 0.01}
# Fold 9: test score (5 best feats): 0.922, test score (all feats): 0.898, diff: 0.024, time: 0.75 s, best model params: {'m__C': 100, 'm__gamma': 0.001}
# Total time: 7.74 s (0.13 min)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/YDD.SVR.sr.json
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/s_feature_selection/rfecv/all.SVR.sr.json
