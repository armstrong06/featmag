# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pygmt
from obspy.core import UTCDateTime

# %%
# Read in features, look at names & datatypes
df_original = pd.read_csv('p_features.csv', dtype={'location_code': str})
print(len(df_original))
print(df_original.dtypes)
# Out:
# 72952
# arrival_identifier                int64
# avg_noise_1.00                  float64
# avg_noise_10.00                 float64
# avg_noise_11.00                 float64
# avg_noise_12.00                 float64
# avg_noise_13.00                 float64
# avg_noise_14.00                 float64
# avg_noise_15.00                 float64
# avg_noise_16.00                 float64
# avg_noise_17.00                 float64
# avg_noise_18.00                 float64
# avg_noise_2.00                  float64
# avg_noise_3.00                  float64
# avg_noise_4.00                  float64
# avg_noise_5.00                  float64
# avg_noise_6.00                  float64
# avg_noise_7.00                  float64
# avg_noise_8.00                  float64
# avg_noise_9.00                  float64
# avg_signal_1.00                 float64
# avg_signal_10.00                float64
# avg_signal_11.00                float64
# avg_signal_12.00                float64
# avg_signal_13.00                float64
# avg_signal_14.00                float64
# avg_signal_15.00                float64
# avg_signal_16.00                float64
# avg_signal_17.00                float64
# avg_signal_18.00                float64
# avg_signal_2.00                 float64
# avg_signal_3.00                 float64
# avg_signal_4.00                 float64
# avg_signal_5.00                 float64
# avg_signal_6.00                 float64
# avg_signal_7.00                 float64
# avg_signal_8.00                 float64
# avg_signal_9.00                 float64
# channel                          object
# event_identifier                  int64
# location_code                    object
# magnitude                       float64
# magnitude_type                   object
# network                          object
# noise_dominant_amplitude        float64
# noise_dominant_frequency        float64
# noise_maximum_value             float64
# noise_minimum_value             float64
# noise_variance                  float64
# signal_dominant_amplitude       float64
# signal_dominant_frequency       float64
# signal_maximum_value            float64
# signal_minimum_value            float64
# signal_variance                 float64
# source_depth_km                 float64
# source_latitude                 float64
# source_longitude                float64
# source_receiver_back_azimuth    float64
# source_receiver_distance_km     float64
# station                          object
# dtype: object

# %%
# This catalog of events seems to be missing 2 events 60055267, 60071327
# ngb_event_df = pd.read_csv("NGB_events_201309_201407.csv")
# ngb_event_df

# df_ngb_old = df_original[np.isin(df_original.event_identifier, ngb_event_df.evid)]

# %%
# Get metadata for 1 and 3c stations
eq_meta_onec = pd.read_csv("../currentEarthquakeArrivalInformation1CWithGains.csv")
eq_meta_threec = pd.read_csv("../currentEarthquakeArrivalInformation3CWithGains.csv")
eq_meta_all = pd.concat([eq_meta_onec, eq_meta_threec])

# Reduce to just location information
all_eq_locs = eq_meta_all.drop_duplicates("evid")[["evid", "event_lat", "event_lon", "origin_time"]]
all_eq_locs.columns = ["event_identifier", "event_lat", "event_lon", "origin_time"]

# Reduce to events in the dataset 
eq_locs_df = all_eq_locs[np.isin(all_eq_locs.event_identifier, df_original.event_identifier.unique())]
# Make date column for filtering
eq_locs_df.loc[:, "date"] = eq_locs_df.origin_time.apply(lambda x: int(UTCDateTime(x).strftime("%y%m%d")))
# Out:
# /tmp/ipykernel_24005/187499698.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   eq_meta_threec = pd.read_csv("../currentEarthquakeArrivalInformation3CWithGains.csv")
# /tmp/ipykernel_24005/187499698.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eq_locs_df.loc[:, "date"] = eq_locs_df.origin_time.apply(lambda x: int(UTCDateTime(x).strftime("%y%m%d")))

# %%
# Set filter bounds
lat_min = 44.680
lat_max = 44.870
lon_max = 110.850
lon_min = 110.640
date_min = 130901  # YYMMDD
date_max = 140630  # YYMMDD
bounds = {"lat_min": lat_min,
          "lat_max": lat_max,
          "lon_max": lon_max,
          "lon_min": lon_min,
          "date_min": date_min,
          "date_max": date_max}

# Get ngb event ids
ngb_event_locs = eq_locs_df.loc[
        (eq_locs_df["date"] >= bounds["date_min"]) & (eq_locs_df["date"] <= bounds["date_max"]) & (eq_locs_df["event_lat"] >= bounds["lat_min"])
        & (eq_locs_df["event_lat"] <= bounds["lat_max"]) & (-1 * eq_locs_df["event_lon"] >= bounds["lon_min"]) & (
                    -1 * eq_locs_df["event_lon"] <= bounds["lon_max"])]

# %%
df_ngb_removed = df_original[~np.isin(df_original.event_identifier, ngb_event_locs.event_identifier)]
df_ngb = df_original[np.isin(df_original.event_identifier, ngb_event_locs.event_identifier)]
np.where(np.isin(df_ngb_removed.event_identifier, df_ngb.event_identifier))
# Out:
# (array([], dtype=int64),)

# %%
# Read in park and caldera boundaries
utahnet_path = "../../maps/utahnet"
ys_border = pd.read_csv(f"{utahnet_path}/yell.border.g", delimiter=" ", names=["Longitude", "Latitude"], dtype=np.float64)
caldera = pd.read_csv(f"{utahnet_path}/caldera.ys", sep="\s+", names=["Latitude", "Longitude"], dtype=np.float64)

caldera = caldera.drop(caldera[caldera["Longitude"]==0].index)
caldera = caldera[["Longitude", "Latitude"]]
caldera["Longitude"] = caldera["Longitude"]*-1

# %%
# Lat/lon bounding box I could use to scale the source locations
bb_lat_min = ys_border.Latitude.min() - 0.2
bb_lat_max = ys_border.Latitude.max()
bb_lon_min = ys_border.Longitude.min() - 0.15
bb_lon_max = ys_border.Longitude.max()
ys_bb = [[bb_lon_max, bb_lat_max], [bb_lon_max, bb_lat_min], [bb_lon_min, bb_lat_min], [bb_lon_min, bb_lat_max], [bb_lon_max, bb_lat_max]]

# %%
#Draw event map 
region = [
    eq_locs_df.event_lon.min() - 0.2,
    eq_locs_df.event_lon.max() + 0.2,
    eq_locs_df.event_lat.min() - 0.1,
    eq_locs_df.event_lat.max() + 0.2,
]

unique_locations = df_ngb_removed[["source_longitude", "source_latitude"]].drop_duplicates()
unique_ngb_locations = df_ngb[["source_longitude", "source_latitude"]].drop_duplicates()

fig = pygmt.Figure()
fig.basemap(region=region, projection="M15c", frame=True)
fig.coast(land="white", borders=2, water="skyblue")
fig.plot(data=ys_border, pen="1.0p,black")
fig.plot(data=caldera, pen='1.0p,black')
fig.plot(x=unique_ngb_locations.source_longitude, y=unique_ngb_locations.source_latitude, style="c0.2c", pen="0.2p,red")
fig.plot(x=unique_locations.source_longitude, y=unique_locations.source_latitude, style="c0.2c", pen="0.2p,black")
fig.plot(ys_bb, pen="0.6p,blue")
fig.show()

# %%
# Keep stations with more than 350 observations - lose 2 stations when removing NGB events (YPK and B945)
stat_counts = df_ngb_removed.value_counts("station").to_frame().reset_index()
stat_counts.columns = ["Station", "Count"]
df_org_filtcounts = df_ngb_removed[np.isin(df_ngb_removed.station, stat_counts[stat_counts.Count >= 350])]

# %%
stat_counts[stat_counts.Station == "B208"]
# Out:
#    Station  Count
# 26    B208    513

# %% [markdown]
# ## Feature selection?

# %%
# Make train and test datasets

test_size = 0.2
station = "B208"

station_df = df_org_filtcounts[df_org_filtcounts.station == station]

evids = np.unique(station_df.event_identifier)
train_evids, test_evids = train_test_split(evids, test_size = test_size, random_state = 843823)

train_inds = np.isin(station_df.event_identifier, train_evids)
train_df = station_df[train_inds]
test_df = station_df[~train_inds]

assert len(train_df.event_identifier.unique()) == len(train_evids)
assert len(test_df.event_identifier.unique()) == len(test_evids)
assert len(test_df) + len(train_df) == len(station_df)

# %%
# Computes the feature matrix from a dataframe
def compute_feature_df(df, scaler = True):
    # Loosely speaking empirical magnitudes look like:
    # M = log10(A) + Q(Delta) 
    # where A is the amplitude and Q a distance dependent correction term.
    # Additionally, the difference between log10 and log amounts to a scalar
    # that a machine can learn.
    # Basically, I'm interested in features that:
    #   (1) Measure size in, potentially, different amplitudes.
    # different `passbands' deviates from the noise, 
    n_rows = len(df)
    n_columns = 48
    X = np.zeros([n_rows, n_columns])
    # Get a proxy on size
    
    # These are effectively amplitude ratios.  Note,
    # log(a/b) = log(a) - log(b)
    X[:,0]  = np.log(df['avg_signal_1.00']) - np.log(df['avg_noise_1.00'])
    X[:,1]  = np.log(df['avg_signal_2.00']) - np.log(df['avg_noise_2.00'])
    X[:,2]  = np.log(df['avg_signal_3.00']) - np.log(df['avg_noise_3.00'])
    X[:,3]  = np.log(df['avg_signal_4.00']) - np.log(df['avg_noise_4.00'])
    X[:,4]  = np.log(df['avg_signal_5.00']) - np.log(df['avg_noise_5.00'])
    X[:,5]  = np.log(df['avg_signal_6.00']) - np.log(df['avg_noise_6.00'])
    X[:,6]  = np.log(df['avg_signal_7.00']) - np.log(df['avg_noise_7.00'])
    X[:,7]  = np.log(df['avg_signal_8.00']) - np.log(df['avg_noise_8.00'])
    X[:,8]  = np.log(df['avg_signal_9.00']) - np.log(df['avg_noise_9.00'])
    X[:,9]  = np.log(df['avg_signal_10.00']) - np.log(df['avg_noise_10.00'])
    X[:,10] = np.log(df['avg_signal_11.00']) - np.log(df['avg_noise_11.00'])
    X[:,11] = np.log(df['avg_signal_12.00']) - np.log(df['avg_noise_12.00'])
    X[:,12] = np.log(df['avg_signal_13.00']) - np.log(df['avg_noise_13.00'])
    X[:,13] = np.log(df['avg_signal_14.00']) - np.log(df['avg_noise_14.00'])
    X[:,14] = np.log(df['avg_signal_15.00']) - np.log(df['avg_noise_15.00'])
    X[:,15] = np.log(df['avg_signal_16.00']) - np.log(df['avg_noise_16.00'])
    X[:,16] = np.log(df['avg_signal_17.00']) - np.log(df['avg_noise_17.00'])
    X[:,17] = np.log(df['avg_signal_18.00']) - np.log(df['avg_noise_18.00'])
    # Look at amplitudes
    X[:,18] = np.log(df['avg_signal_1.00']) 
    X[:,19] = np.log(df['avg_signal_2.00']) 
    X[:,20] = np.log(df['avg_signal_3.00']) 
    X[:,21] = np.log(df['avg_signal_4.00']) 
    X[:,22] = np.log(df['avg_signal_5.00'])
    X[:,23] = np.log(df['avg_signal_6.00'])
    X[:,24] = np.log(df['avg_signal_7.00'])
    X[:,25] = np.log(df['avg_signal_8.00'])
    X[:,26] = np.log(df['avg_signal_9.00'])
    X[:,27] = np.log(df['avg_signal_10.00'])
    X[:,28] = np.log(df['avg_signal_11.00'])
    X[:,29] = np.log(df['avg_signal_12.00'])
    X[:,30] = np.log(df['avg_signal_13.00'])
    X[:,31] = np.log(df['avg_signal_14.00'])
    X[:,32] = np.log(df['avg_signal_15.00'])
    X[:,33] = np.log(df['avg_signal_16.00'])
    X[:,34] = np.log(df['avg_signal_17.00'])
    X[:,35] = np.log(df['avg_signal_18.00'])
    # Frequency and max amplitude
    X[:,36] = np.log(df['signal_dominant_frequency'])
    X[:,37] = np.log(df['signal_dominant_amplitude'])
    # Time-based featuers: Look at max amplitudes of noise/signal
    X[:,38] = np.log(df['noise_maximum_value']  - df['noise_minimum_value'])
    X[:,39] = np.log(df['signal_maximum_value'] - df['signal_minimum_value'])
    X[:,40] = np.log(df['signal_variance'])
    X[:,41] = np.log(df['noise_variance'])
    # Source/recv distance (take log to flatten this)
    X[:,42] = np.log(df['source_receiver_distance_km'])
    X[:,43] = df['source_depth_km']
    # Single stations can learn location
    X[:,44] = df['source_latitude']
    X[:,45] = df['source_longitude']
    X[:,46] = np.sin(df['source_receiver_back_azimuth'])
    X[:,47] = df['source_receiver_back_azimuth']

    
    # Standardize features
    if (scaler):
        scaler = StandardScaler()
        scaler = scaler.fit(X)
        X = scaler.transform(X)
        return X, scaler
    
    return X
    
#X, scaler = compute_feature_matrix(df)

# %%
train_feat_matrix_scaled, scaler = compute_feature_df(train_df)
train_feat_matrix_unscaled = compute_feature_df(train_df, scaler=False)

train_y = train_df.magnitude.values

# %%
train_feat_matrix_scaled[0], train_feat_matrix_unscaled[0]
# Out:
# (array([ 1.37799911,  0.99581247, -0.12597027, -0.35563096, -0.52227232,
#         -0.91949519, -1.0903427 , -1.10752313, -1.27476239, -1.41432806,
#         -1.48795245, -1.51781274, -1.5265889 , -1.52475287, -1.50754226,
#         -1.47892056, -1.44526535, -1.40910845,  0.60066611, -0.11074152,
#         -0.64348082, -0.50311957, -0.54415501, -0.7133212 , -0.79695914,
#         -0.78637718, -0.81061393, -0.86454007, -0.93025056, -0.99995612,
#         -1.0666898 , -1.12380731, -1.16683864, -1.19663688, -1.21674063,
#         -1.22826749, -2.41638783, -0.44386845, -0.07215975, -0.60398884,
#         -0.46245863, -0.26099892,  1.37927798,  3.36617858, -1.20642467,
#         -2.07060799, -1.36438504, -0.12494186]),
#  array([   3.20592077,    3.27737116,    2.57552289,    2.59786938,
#            2.51538357,    2.35329026,    2.51000679,    2.69148906,
#            2.5654322 ,    2.3641488 ,    2.19082056,    2.05898701,
#            1.95636036,    1.87436431,    1.82297366,    1.79923992,
#            1.79515106,    1.80666924,   -3.25146554,   -3.67340392,
#           -4.6876218 ,   -4.63930018,   -4.92944718,   -5.14904675,
#           -5.01876842,   -4.82717152,   -4.8238866 ,   -4.96253494,
#           -5.17675453,   -5.42236026,   -5.66976193,   -5.90307892,
#           -6.11563542,   -6.30825797,   -6.48599099,   -6.64965952,
#            0.        ,   -5.62067342,   -3.34258589,   -1.2283476 ,
#           -5.50714651,  -10.00643671,    3.98755986,   14.3       ,
#           44.3893333 , -111.0358333 ,   -0.98867232,  249.60595657]))

# %%
train_y
# Out:
# array([2.06, 3.16, 2.76, 2.08, 2.5 , 2.33, 2.  , 1.58, 2.02, 1.71, 2.01,
#        1.43, 1.24, 1.38, 1.51, 2.62, 2.03, 1.8 , 1.2 , 1.36, 1.2 , 0.71,
#        1.56, 1.27, 1.2 , 2.13, 2.07, 1.88, 1.31, 1.42, 2.18, 1.88, 1.21,
#        1.44, 1.51, 2.28, 1.99, 1.38, 0.99, 1.66, 1.48, 1.13, 1.54, 0.92,
#        3.27, 1.15, 1.46, 1.59, 2.25, 3.05, 1.45, 1.37, 1.46, 0.9 , 1.44,
#        1.54, 1.26, 2.06, 2.83, 1.42, 2.99, 2.5 , 1.46, 0.96, 2.17, 1.73,
#        1.47, 0.87, 1.84, 1.35, 0.86, 1.42, 1.76, 2.4 , 2.87, 1.78, 1.43,
#        0.83, 1.4 , 1.26, 0.71, 0.82, 2.22, 1.19, 1.64, 1.07, 1.33, 1.09,
#        2.72, 1.71, 2.39, 2.3 , 1.81, 1.77, 2.69, 0.58, 1.56, 0.92, 0.96,
#        2.12, 1.92, 0.98, 0.78, 1.49, 1.82, 1.27, 1.52, 0.94, 0.78, 2.13,
#        1.59, 1.99, 1.62, 1.63, 3.43, 2.66, 2.7 , 1.63, 1.12, 1.35, 1.24,
#        1.86, 1.58, 1.18, 2.1 , 1.64, 2.48, 1.33, 1.81, 2.1 , 1.5 , 2.34,
#        2.13, 1.3 , 1.62, 2.07, 1.95, 2.43, 1.77, 2.3 , 2.82, 2.48, 1.82,
#        1.52, 1.28, 1.22, 1.2 , 1.38, 1.28, 1.15, 1.28, 1.69, 1.64, 1.35,
#        3.  , 1.94, 2.85, 2.03, 2.25, 2.46, 1.51, 1.37, 2.03, 1.73, 1.78,
#        1.67, 2.18, 1.86, 1.02, 1.35, 1.78, 1.1 , 1.4 , 1.56, 2.06, 1.35,
#        2.67, 1.64, 1.45, 1.69, 1.19, 1.67, 1.53, 1.32, 1.67, 2.06, 1.73,
#        1.84, 1.52, 0.91, 2.17, 1.72, 1.64, 0.94, 0.75, 0.68, 1.28, 0.91,
#        1.14, 0.62, 0.47, 0.93, 1.07, 1.51, 1.23, 1.72, 1.64, 1.08, 1.97,
#        2.45, 1.77, 1.64, 2.49, 1.69, 2.39, 1.08, 1.55, 1.22, 1.08, 1.08,
#        1.38, 1.37, 1.51, 2.22, 2.2 , 2.16, 1.35, 1.43, 1.46, 1.95, 1.19,
#        1.55, 1.62, 1.63, 3.22, 2.34, 1.97, 1.57, 1.45, 1.61, 1.9 , 1.62,
#        2.2 , 2.17, 1.48, 1.7 , 1.74, 2.71, 1.37, 1.47, 1.63, 1.84, 1.56,
#        1.35, 1.56, 1.86, 1.55, 1.76, 1.63, 2.1 , 1.88, 1.76, 1.55, 1.56,
#        2.08, 2.33, 1.46, 2.36, 2.  , 0.95, 1.66, 1.78, 1.36, 1.43, 1.74,
#        1.02, 1.09, 1.27, 1.38, 2.44, 1.45, 1.49, 1.43, 1.43, 2.34, 2.4 ,
#        1.98, 1.31, 1.85, 2.19, 1.46, 1.87, 1.26, 1.34, 1.47, 1.49, 2.17,
#        1.11, 2.15, 0.93, 0.82, 0.99, 1.33, 2.2 , 1.64, 0.84, 3.03, 2.21,
#        1.32, 1.36, 1.3 , 2.44, 1.75, 1.27, 1.35, 1.19, 1.89, 1.21, 1.81,
#        1.46, 2.11, 1.01, 1.43, 1.88, 1.16, 0.75, 1.54, 1.27, 1.41, 0.96,
#        1.3 , 0.65, 1.19, 1.02, 1.19, 1.2 , 1.61, 1.7 , 1.79, 1.6 , 1.94,
#        1.37, 1.36, 1.33, 1.08, 1.56, 1.63, 1.98, 1.75, 1.47, 1.49, 1.35,
#        1.25, 1.47, 1.26, 1.92, 0.94, 2.06, 2.33, 2.53, 1.48, 1.68, 1.86,
#        1.46, 1.97, 1.73, 1.92, 1.17, 2.28, 1.58, 1.4 , 2.18, 1.42, 1.62,
#        1.52, 1.55, 1.76, 1.95, 1.42, 1.1 , 1.03, 1.3 , 1.21, 2.36, 1.02,
#        1.88, 1.89, 2.94, 2.2 , 1.91, 1.7 , 1.33, 1.86, 1.63, 1.27, 1.43,
#        1.51, 2.  , 1.36, 1.59, 1.75, 1.69, 1.95, 1.52, 1.54, 1.27, 1.16,
#        2.79, 2.16, 2.52])

# %%
train_feat_df = pd.DataFrame(train_feat_matrix_scaled, columns=["amp_ratio_01.0", "amp_ratio_02.0", "amp_ratio_03.0", "amp_ratio_04.0", 
                                 "amp_ratio_05.0", "amp_ratio_06.0", "amp_ratio_07.0", "amp_ratio_08.0",
                                 "amp_ratio_09.0", "amp_ratio_10.0", "amp_ratio_11.0", "amp_ratio_12.0", 
                                 "amp_ratio_13.0", "amp_ratio_14.0", "amp_ratio_15.0", "amp_ratio_16.0", 
                                 "amp_ratio_17.0", "amp_ratio_18.0", 
                                 "amp_01.0", "amp_02.0", "amp_03.0", "amp_04.0", 
                                 "amp_05.0", "amp_06.0", "amp_07.0", "amp_08.0",
                                 "amp_09.0", "amp_10.0", "amp_11.0", "amp_12.0", 
                                 "amp_13.0", "amp_14.0", "amp_15.0", "amp_16.0", 
                                 "amp_17.0", "amp_18.0",
                                 "signal_dominant_frequency", "signal_dominant_amplitude", 
                                 "noise_max_amplitude", "signal_max_amplitude", "signal_variance", "noise_variance",
                                 "source_receiver_distance_logkm", "source_depth_km","source_latitude", "source_longitude", 
                                 "sin_receiver_back_azimuth", "receiver_back_azimuth"])

# %%
train_feat_df_unscaled = pd.DataFrame(train_feat_matrix_unscaled, columns=["amp_ratio_01.0", "amp_ratio_02.0", "amp_ratio_03.0", "amp_ratio_04.0", 
                                 "amp_ratio_05.0", "amp_ratio_06.0", "amp_ratio_07.0", "amp_ratio_08.0",
                                 "amp_ratio_09.0", "amp_ratio_10.0", "amp_ratio_11.0", "amp_ratio_12.0", 
                                 "amp_ratio_13.0", "amp_ratio_14.0", "amp_ratio_15.0", "amp_ratio_16.0", 
                                 "amp_ratio_17.0", "amp_ratio_18.0", 
                                 "amp_01.0", "amp_02.0", "amp_03.0", "amp_04.0", 
                                 "amp_05.0", "amp_06.0", "amp_07.0", "amp_08.0",
                                 "amp_09.0", "amp_10.0", "amp_11.0", "amp_12.0", 
                                 "amp_13.0", "amp_14.0", "amp_15.0", "amp_16.0", 
                                 "amp_17.0", "amp_18.0",
                                 "signal_dominant_frequency", "signal_dominant_amplitude", 
                                 "noise_max_amplitude", "signal_max_amplitude", "signal_variance", "noise_variance",
                                 "source_receiver_distance_logkm", "source_depth_km","source_latitude", "source_longitude", 
                                 "sin_receiver_back_azimuth", "receiver_back_azimuth"])

# %%
feat_target_df = train_feat_df.copy()
feat_target_df.loc[:, "magnitude"] = train_y
corr = feat_target_df.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_f265d_row0_col0, #T_f265d_row1_col1, #T_f265d_row2_col2, #T_f265d_row3_col3, #T_f265d_row4_col4, #T_f265d_row5_col5, #T_f265d_row6_col6, #T_f265d_row7_col7, #T_f265d_row8_col8, #T_f265d_row8_col9, #T_f265d_row9_col8, #T_f265d_row9_col9, #T_f265d_row9_col10, #T_f265d_row10_col9, #T_f265d_row10_col10, #T_f265d_row10_col11, #T_f265d_row11_col10, #T_f265d_row11_col11, #T_f265d_row11_col12, #T_f265d_row12_col11, #T_f265d_row12_col12, #T_f265d_row12_col13, #T_f265d_row13_col12, #T_f265d_row13_col13, #T_f265d_row13_col14, #T_f265d_row13_col15, #T_f265d_row14_col13, #T_f265d_row14_col14, #T_f265d_row14_col15, #T_f265d_row14_col16, #T_f265d_row15_col13, #T_f265d_row15_col14, #T_f265d_row15_col15, #T_f265d_row15_col16, #T_f265d_row15_col17, #T_f265d_row16_col14, #T_f265d_row16_col15, #T_f265d_row16_col16, #T_f265d_row16_col17, #T_f265d_row17_col15, #T_f265d_row17_col16, #T_f265d_row17_col17, #T_f265d_row18_col18, #T_f265d_row19_col19, #T_f265d_row20_col20, #T_f265d_row21_col21, #T_f265d_row22_col22, #T_f265d_row23_col23, #T_f265d_row23_col24, #T_f265d_row24_col23, #T_f265d_row24_col24, #T_f265d_row24_col25, #T_f265d_row24_col26, #T_f265d_row25_col24, #T_f265d_row25_col25, #T_f265d_row25_col26, #T_f265d_row25_col27, #T_f265d_row25_col28, #T_f265d_row26_col24, #T_f265d_row26_col25, #T_f265d_row26_col26, #T_f265d_row26_col27, #T_f265d_row26_col28, #T_f265d_row26_col29, #T_f265d_row27_col25, #T_f265d_row27_col26, #T_f265d_row27_col27, #T_f265d_row27_col28, #T_f265d_row27_col29, #T_f265d_row27_col30, #T_f265d_row28_col25, #T_f265d_row28_col26, #T_f265d_row28_col27, #T_f265d_row28_col28, #T_f265d_row28_col29, #T_f265d_row28_col30, #T_f265d_row28_col31, #T_f265d_row29_col26, #T_f265d_row29_col27, #T_f265d_row29_col28, #T_f265d_row29_col29, #T_f265d_row29_col30, #T_f265d_row29_col31, #T_f265d_row29_col32, #T_f265d_row30_col27, #T_f265d_row30_col28, #T_f265d_row30_col29, #T_f265d_row30_col30, #T_f265d_row30_col31, #T_f265d_row30_col32, #T_f265d_row30_col33, #T_f265d_row31_col28, #T_f265d_row31_col29, #T_f265d_row31_col30, #T_f265d_row31_col31, #T_f265d_row31_col32, #T_f265d_row31_col33, #T_f265d_row31_col34, #T_f265d_row31_col35, #T_f265d_row32_col29, #T_f265d_row32_col30, #T_f265d_row32_col31, #T_f265d_row32_col32, #T_f265d_row32_col33, #T_f265d_row32_col34, #T_f265d_row32_col35, #T_f265d_row33_col30, #T_f265d_row33_col31, #T_f265d_row33_col32, #T_f265d_row33_col33, #T_f265d_row33_col34, #T_f265d_row33_col35, #T_f265d_row34_col31, #T_f265d_row34_col32, #T_f265d_row34_col33, #T_f265d_row34_col34, #T_f265d_row34_col35, #T_f265d_row35_col31, #T_f265d_row35_col32, #T_f265d_row35_col33, #T_f265d_row35_col34, #T_f265d_row35_col35, #T_f265d_row36_col36, #T_f265d_row37_col37, #T_f265d_row37_col40, #T_f265d_row38_col38, #T_f265d_row39_col39, #T_f265d_row39_col40, #T_f265d_row40_col37, #T_f265d_row40_col39, #T_f265d_row40_col40, #T_f265d_row41_col41, #T_f265d_row42_col42, #T_f265d_row43_col43, #T_f265d_row44_col44, #T_f265d_row45_col45, #T_f265d_row46_col46, #T_f265d_row47_col47, #T_f265d_row48_col48 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f265d_row0_col1, #T_f265d_row3_col45 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_f265d_row0_col2, #T_f265d_row36_col16, #T_f265d_row48_col23 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_f265d_row0_col3, #T_f265d_row9_col1, #T_f265d_row36_col29 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_f265d_row0_col4, #T_f265d_row18_col1, #T_f265d_row18_col38, #T_f265d_row48_col35 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_f265d_row0_col5, #T_f265d_row22_col38, #T_f265d_row23_col1, #T_f265d_row35_col36, #T_f265d_row36_col23, #T_f265d_row48_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_f265d_row0_col6, #T_f265d_row0_col21, #T_f265d_row27_col38, #T_f265d_row31_col36, #T_f265d_row32_col1, #T_f265d_row36_col8, #T_f265d_row48_col8 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_f265d_row0_col7, #T_f265d_row0_col19, #T_f265d_row0_col29, #T_f265d_row13_col36, #T_f265d_row27_col41, #T_f265d_row28_col41, #T_f265d_row30_col38, #T_f265d_row34_col1, #T_f265d_row36_col7, #T_f265d_row36_col37 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_f265d_row0_col8, #T_f265d_row0_col35, #T_f265d_row3_col0, #T_f265d_row28_col36, #T_f265d_row31_col41, #T_f265d_row33_col38, #T_f265d_row36_col6, #T_f265d_row36_col22 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_f265d_row0_col9, #T_f265d_row0_col10, #T_f265d_row18_col0, #T_f265d_row27_col36, #T_f265d_row33_col41, #T_f265d_row35_col38, #T_f265d_row45_col18 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_f265d_row0_col11, #T_f265d_row0_col12, #T_f265d_row0_col13, #T_f265d_row0_col14, #T_f265d_row10_col36, #T_f265d_row24_col48, #T_f265d_row34_col41, #T_f265d_row45_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_f265d_row0_col15, #T_f265d_row0_col16, #T_f265d_row0_col42, #T_f265d_row5_col48, #T_f265d_row9_col36, #T_f265d_row25_col48, #T_f265d_row26_col36, #T_f265d_row26_col48, #T_f265d_row35_col41 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_f265d_row0_col17, #T_f265d_row27_col48, #T_f265d_row42_col47, #T_f265d_row46_col42 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_f265d_row0_col18, #T_f265d_row20_col48, #T_f265d_row36_col14, #T_f265d_row48_col29 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_f265d_row0_col20, #T_f265d_row15_col36, #T_f265d_row17_col1, #T_f265d_row23_col41, #T_f265d_row25_col38, #T_f265d_row26_col38, #T_f265d_row31_col1, #T_f265d_row37_col41, #T_f265d_row39_col38, #T_f265d_row40_col48, #T_f265d_row48_col1, #T_f265d_row48_col7, #T_f265d_row48_col9 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_f265d_row0_col22, #T_f265d_row0_col23, #T_f265d_row0_col24, #T_f265d_row0_col25, #T_f265d_row0_col27, #T_f265d_row0_col28, #T_f265d_row26_col41, #T_f265d_row29_col38, #T_f265d_row30_col36, #T_f265d_row33_col1, #T_f265d_row39_col41 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_f265d_row0_col26, #T_f265d_row4_col48, #T_f265d_row14_col36, #T_f265d_row24_col41, #T_f265d_row25_col41, #T_f265d_row28_col38 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_f265d_row0_col30, #T_f265d_row0_col31, #T_f265d_row29_col41, #T_f265d_row35_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_f265d_row0_col32, #T_f265d_row0_col33, #T_f265d_row29_col36, #T_f265d_row31_col38 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_f265d_row0_col34, #T_f265d_row1_col45, #T_f265d_row12_col36, #T_f265d_row30_col41, #T_f265d_row32_col38, #T_f265d_row38_col45, #T_f265d_row39_col48, #T_f265d_row41_col45 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_f265d_row0_col36, #T_f265d_row5_col43, #T_f265d_row16_col44 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_f265d_row0_col37, #T_f265d_row0_col39, #T_f265d_row0_col40, #T_f265d_row22_col48, #T_f265d_row24_col38, #T_f265d_row32_col36, #T_f265d_row36_col9, #T_f265d_row36_col40, #T_f265d_row37_col48, #T_f265d_row40_col41, #T_f265d_row48_col10, #T_f265d_row48_col15, #T_f265d_row48_col16, #T_f265d_row48_col17 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_f265d_row0_col38, #T_f265d_row5_col44, #T_f265d_row12_col42, #T_f265d_row38_col46, #T_f265d_row47_col18 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_f265d_row0_col41, #T_f265d_row32_col47 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_f265d_row0_col43, #T_f265d_row29_col48 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_f265d_row0_col44, #T_f265d_row1_col36, #T_f265d_row32_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f265d_row0_col45, #T_f265d_row20_col0, #T_f265d_row36_col3, #T_f265d_row38_col11, #T_f265d_row41_col42, #T_f265d_row43_col23, #T_f265d_row44_col22, #T_f265d_row46_col8, #T_f265d_row46_col9, #T_f265d_row46_col19 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_f265d_row0_col46, #T_f265d_row20_col42, #T_f265d_row36_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_f265d_row0_col47, #T_f265d_row2_col42, #T_f265d

# %%
from sklearn.feature_selection import mutual_info_regression, SequentialFeatureSelector, RFE

# %%
mutual_reg = mutual_info_regression(train_feat_matrix_scaled, train_y, random_state=843824)
mutual_reg
# Out:
# array([0.068616  , 0.14894487, 0.12529253, 0.1393566 , 0.13187707,
#        0.15300521, 0.09950987, 0.08910805, 0.07028973, 0.09916849,
#        0.11589757, 0.08967765, 0.07550259, 0.07017811, 0.0635256 ,
#        0.07130777, 0.09145123, 0.05947773, 0.20454313, 0.28717855,
#        0.19851386, 0.19075795, 0.23227752, 0.13337246, 0.16069397,
#        0.19986572, 0.20483172, 0.22316165, 0.19248321, 0.16543422,
#        0.12030699, 0.07701252, 0.0560895 , 0.06906386, 0.10751519,
#        0.11293339, 0.07682536, 0.15757127, 0.037726  , 0.20926236,
#        0.21504497, 0.06229106, 0.14840084, 0.10524686, 0.10085118,
#        0.16749269, 0.03942481, 0.10963017])

# %%
train_feat_df.columns[np.argsort(mutual_reg, axis=0)]
# Out:
# Index(['noise_max_amplitude', 'sin_receiver_back_azimuth', 'amp_15.0',
#        'amp_ratio_18.0', 'noise_variance', 'amp_ratio_15.0', 'amp_ratio_01.0',
#        'amp_16.0', 'amp_ratio_14.0', 'amp_ratio_09.0', 'amp_ratio_16.0',
#        'amp_ratio_13.0', 'signal_dominant_frequency', 'amp_14.0',
#        'amp_ratio_08.0', 'amp_ratio_12.0', 'amp_ratio_17.0', 'amp_ratio_10.0',
#        'amp_ratio_07.0', 'source_latitude', 'source_depth_km', 'amp_17.0',
#        'receiver_back_azimuth', 'amp_18.0', 'amp_ratio_11.0', 'amp_13.0',
#        'amp_ratio_03.0', 'amp_ratio_05.0', 'amp_06.0', 'amp_ratio_04.0',
#        'source_receiver_distance_logkm', 'amp_ratio_02.0', 'amp_ratio_06.0',
#        'signal_dominant_amplitude', 'amp_07.0', 'amp_12.0', 'source_longitude',
#        'amp_04.0', 'amp_11.0', 'amp_03.0', 'amp_08.0', 'amp_01.0', 'amp_09.0',
#        'signal_max_amplitude', 'signal_variance', 'amp_10.0', 'amp_05.0',
#        'amp_02.0'],
#       dtype='object')

# %%
# Make cross validation splits across evids

from sklearn.model_selection import KFold
evids = train_df.event_identifier.unique()
kf = KFold(n_splits=5, shuffle=True, random_state=843824)
folds = []
for train_index, test_index in kf.split(evids):
    # Get the evids corresponding to the split indicies
    fold_train_evids = evids[train_index]
    fold_test_evids = evids[test_index]
    # Get rows of training dataset that correspond to split evids
    fold_train_inds = np.where(np.isin(train_df.event_identifier, fold_train_evids))[0]
    fold_test_inds = np.where(np.isin(train_df.event_identifier, fold_test_evids))[0]
    
    folds.append((fold_train_inds, fold_test_inds))

# %%
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, cross_validate
from sklearn.metrics import r2_score

# %% [markdown]
# ## RFE
#
# from RFECV, know that most of the gain comes from 5-10 features. Use RFE to find 8 "best" features

# %%
train_feat_df.columns[:-1]
# Out:
# Index(['amp_ratio_01.0', 'amp_ratio_02.0', 'amp_ratio_03.0', 'amp_ratio_04.0',
#        'amp_ratio_05.0', 'amp_ratio_06.0', 'amp_ratio_07.0', 'amp_ratio_08.0',
#        'amp_ratio_09.0', 'amp_ratio_10.0', 'amp_ratio_11.0', 'amp_ratio_12.0',
#        'amp_ratio_13.0', 'amp_ratio_14.0', 'amp_ratio_15.0', 'amp_ratio_16.0',
#        'amp_ratio_17.0', 'amp_ratio_18.0', 'amp_01.0', 'amp_02.0', 'amp_03.0',
#        'amp_04.0', 'amp_05.0', 'amp_06.0', 'amp_07.0', 'amp_08.0', 'amp_09.0',
#        'amp_10.0', 'amp_11.0', 'amp_12.0', 'amp_13.0', 'amp_14.0', 'amp_15.0',
#        'amp_16.0', 'amp_17.0', 'amp_18.0', 'signal_dominant_frequency',
#        'signal_dominant_amplitude', 'noise_max_amplitude',
#        'signal_max_amplitude', 'signal_variance', 'noise_variance',
#        'source_receiver_distance_logkm', 'source_depth_km', 'source_latitude',
#        'source_longitude', 'sin_receiver_back_azimuth'],
#       dtype='object')

# %%
# Find best features for whole training dataset
estimator = SVR(kernel="linear")
selector = RFE(estimator, n_features_to_select=8, step=1)
selector = selector.fit(train_feat_matrix_scaled[:, :-1], train_y)

train_feat_df.columns[:-1][selector.support_]
# Out:
# Index(['amp_02.0', 'amp_04.0', 'amp_06.0', 'amp_07.0', 'amp_10.0', 'amp_12.0',
#        'signal_variance', 'source_receiver_distance_logkm'],
#       dtype='object')

# %%
# Sort features by importance - first 8 are in no particular order
train_feat_df.columns[:-1][np.argsort(selector.ranking_)]
# Out:
# Index(['amp_06.0', 'source_receiver_distance_logkm', 'signal_variance',
#        'amp_10.0', 'amp_04.0', 'amp_02.0', 'amp_12.0', 'amp_07.0', 'amp_09.0',
#        'source_latitude', 'signal_dominant_amplitude', 'amp_ratio_12.0',
#        'amp_ratio_09.0', 'amp_ratio_16.0', 'amp_ratio_13.0', 'amp_ratio_15.0',
#        'amp_ratio_18.0', 'amp_ratio_03.0', 'amp_ratio_14.0', 'amp_13.0',
#        'amp_17.0', 'amp_08.0', 'noise_max_amplitude', 'amp_ratio_08.0',
#        'amp_11.0', 'amp_03.0', 'amp_ratio_01.0', 'amp_ratio_17.0', 'amp_14.0',
#        'amp_18.0', 'amp_05.0', 'amp_01.0', 'signal_max_amplitude',
#        'amp_ratio_10.0', 'signal_dominant_frequency', 'source_longitude',
#        'amp_15.0', 'source_depth_km', 'amp_16.0', 'amp_ratio_06.0',
#        'amp_ratio_05.0', 'amp_ratio_07.0', 'amp_ratio_04.0', 'noise_variance',
#        'amp_ratio_02.0', 'sin_receiver_back_azimuth', 'amp_ratio_11.0'],
#       dtype='object')

# %%
# Training performace with these 8 features in the linear model 
r2_score(selector.predict(train_feat_matrix_scaled[:, :-1]), train_y)
# Out:
# 0.5143746613565603

# %%
# CV performace with these 8 features in non-linear model
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:, :-1][:, selector.support_], train_y, cv=folds, scoring="r2")
# Out:
# {'fit_time': array([0.00464606, 0.00314617, 0.00312161, 0.00331879, 0.00368285]),
#  'score_time': array([0.0009222 , 0.0007925 , 0.00077558, 0.00120258, 0.00081635]),
#  'test_score': array([0.74984688, 0.70625334, 0.66964256, 0.65429882, 0.69940108])}

# %%
# Get best RFE features for various folds and evaluate 
for fold in folds:
    # Pipeline for choosing features for fold
    estimator = SVR(kernel="linear")
    selector = RFE(estimator, n_features_to_select=8, step=1)
    pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('selector', selector)])
    
    # Fold data - exclude receiver_back_azimuth since linear model
    cv_train_X = train_feat_matrix_unscaled[fold[0], :-1]
    cv_train_y = train_y[fold[0]]
    cv_test_X = train_feat_matrix_unscaled[fold[1], :-1]
    cv_test_y = train_y[fold[1]]
    
    # Fit selector to fold training data
    s = pipeline.fit(cv_train_X, cv_train_y)
    # Make predictions on the fold test data
    preds = s.predict(cv_test_X)
    # Get the features for this model
    support = s.named_steps.selector.support_
    # Print the features
    print(train_feat_df.columns[:-1][support])
    # Print the test R^2 score
    print(r2_score(cv_test_y, preds))
    
    # Use this features in a non-linear model. Cross validate over all the folds
    svr = SVR(C=1.0, epsilon=0.2)
    nl_pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
    print(cross_validate(nl_pipeline, train_feat_matrix_unscaled[:, :-1][:, support],
                         train_y, cv=folds, scoring="r2")["test_score"])
# Out:
# Index(['amp_04.0', 'amp_05.0', 'amp_06.0', 'amp_07.0', 'amp_10.0', 'amp_12.0',
#        'signal_variance', 'source_receiver_distance_logkm'],
#       dtype='object')
# 0.7056501207672271
# [0.74854379 0.68714694 0.65336043 0.59569672 0.68685325]
# Index(['amp_02.0', 'amp_04.0', 'amp_05.0', 'amp_10.0', 'amp_12.0',
#        'signal_max_amplitude', 'signal_variance',
#        'source_receiver_distance_logkm'],
#       dtype='object')
# 0.5916890337984648
# [0.76346751 0.71388326 0.67002121 0.66130773 0.70435837]
# Index(['amp_04.0', 'amp_05.0', 'amp_09.0', 'amp_10.0', 'amp_12.0',
#        'signal_variance', 'source_receiver_distance_logkm', 'source_latitude'],
#       dtype='object')
# 0.6712131679414122
# [0.81355487 0.80670988 0.76680758 0.70428845 0.77803008]
# Index(['amp_ratio_11.0', 'amp_02.0', 'amp_03.0', 'amp_10.0', 'amp_12.0',
#        'signal_variance', 'source_receiver_distance_logkm', 'source_latitude'],
#       dtype='object')
# 0.6548826913516126
# [0.80495734 0.81184397 0.78084717 0.72336862 0.77333524]
# Index(['amp_02.0', 'amp_04.0', 'amp_09.0', 'amp_10.0', 'amp_12.0', 'amp_14.0',
#        'signal_dominant_amplitude', 'source_receiver_distance_logkm'],
#       dtype='object')
# 0.6157758954728806
# [0.76648576 0.71813865 0.65836943 0.66590469 0.71208688]

# %% [markdown]
# ## Sequential Feature Selection.
# Forward selection until change in score is less than 1e-4 or reach half of the features. Slightly better CV performace with 13 features than 46 for non-linear SVR. Pretty comparable performace between the 13 and 46 features in linear SVR.

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
sfs = SequentialFeatureSelector(pipeline, n_features_to_select="auto", tol=1e-3, scoring="r2", 
                                cv=folds, n_jobs=3).fit(train_feat_matrix_unscaled, train_y)

sfs.get_feature_names_out(train_feat_df.columns)
# Out:
# array(['amp_01.0', 'amp_02.0', 'amp_12.0', 'signal_variance',
#        'source_receiver_distance_logkm', 'source_latitude',
#        'source_longitude'], dtype=object)

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:, sfs.get_support()], train_y, cv=folds)
# Out:
# {'fit_time': array([0.00410104, 0.00345111, 0.00337768, 0.0037818 , 0.00322771]),
#  'score_time': array([0.00084114, 0.00075316, 0.0007627 , 0.00072241, 0.00069785]),
#  'test_score': array([0.84029266, 0.84085736, 0.77791695, 0.7373395 , 0.78765805])}

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
sfs = SequentialFeatureSelector(pipeline, n_features_to_select="auto", tol=1e-4, scoring="r2", 
                                cv=folds, n_jobs=3).fit(train_feat_matrix_unscaled, train_y)

sfs.get_feature_names_out(train_feat_df.columns)
# Out:
# array(['amp_ratio_05.0', 'amp_01.0', 'amp_02.0', 'amp_12.0', 'amp_18.0',
#        'signal_dominant_amplitude', 'signal_max_amplitude',
#        'signal_variance', 'source_receiver_distance_logkm',
#        'source_latitude', 'source_longitude'], dtype=object)

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:, sfs.get_support()], train_y, cv=folds)
# Out:
# {'fit_time': array([0.00380015, 0.00394106, 0.00382948, 0.00352287, 0.00343442]),
#  'score_time': array([0.0008266 , 0.00077701, 0.00081062, 0.00084066, 0.0007844 ]),
#  'test_score': array([0.85231683, 0.8318038 , 0.78419293, 0.74705664, 0.78679361])}

# %%
tmp_feats = ['amp_ratio_05.0', 'amp_01.0', 'amp_02.0', 'amp_12.0', 'amp_18.0',
       'signal_dominant_amplitude', 'signal_max_amplitude',
       'signal_variance',
       'source_latitude', 'source_longitude']
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_df_unscaled[tmp_feats], train_y, cv=folds)
# Out:
# {'fit_time': array([0.00579453, 0.00549698, 0.00611877, 0.00554943, 0.00561547]),
#  'score_time': array([0.00158906, 0.00163126, 0.00165033, 0.00170612, 0.00165486]),
#  'test_score': array([0.83735579, 0.80339981, 0.77690996, 0.72592579, 0.79346798])}

# %%
# Result when selecting 6 features
# array(['amp_01.0', 'amp_02.0', 'amp_12.0', 'signal_dominant_amplitude',
#        'source_receiver_distance_logkm', 'source_longitude'], dtype=object)
# 0.86665783, 0.86072235, 0.83637506, 0.87239198, 0.87021598

# %%
# Performance when using all features
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled, train_y, cv=folds)
# Out:
# {'fit_time': array([0.00424552, 0.00455427, 0.00419164, 0.00438428, 0.00465941]),
#  'score_time': array([0.00101447, 0.00104189, 0.00099087, 0.00101304, 0.00100589]),
#  'test_score': array([0.74094275, 0.76558213, 0.73389374, 0.6863152 , 0.75156792])}

# %% [markdown]
# # Go more in-depth into the effect of the more important features

# %%
all_selected_features = ['signal_dominant_amplitude', "signal_max_amplitude", "signal_variance", 
                         'source_longitude', "source_latitude", 'source_receiver_distance_logkm',
                         'source_depth_km', "receiver_back_azimuth", "amp_01.0", 
                         'amp_02.0', "amp_12.0", "amp_18.0", "amp_ratio_01.0","amp_ratio_05.0"]

selected_features_lat_lon = ['signal_dominant_amplitude', "signal_max_amplitude", "signal_variance", 
                         'source_longitude', "source_latitude",'source_depth_km', "amp_01.0", 
                         'amp_02.0', "amp_12.0", "amp_18.0", "amp_ratio_01.0","amp_ratio_05.0"]

selected_features_sr = ['signal_dominant_amplitude', "signal_max_amplitude", "signal_variance", 
                         'source_receiver_distance_logkm','source_depth_km', "receiver_back_azimuth", 
                        "amp_01.0",'amp_02.0', "amp_12.0", "amp_18.0", "amp_ratio_01.0","amp_ratio_05.0"]

# %%
def svr_cv(X, y, folds, C=1.0, epsilon=0.2):
    svr = SVR(C=C, epsilon=epsilon)
    pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
    cv_scores = cross_validate(pipeline, X, y, scoring="r2", cv=folds)["test_score"]
    
    return cv_scores

# %%
def seq_feature_importance(selected_features, train_feat_df_unscaled):
    feat_selection = np.copy(selected_features)
    best_features = []
    r2_maxs = []
    r2_mins = []
    r2_means = []

    for it in range(len(selected_features)):
        print("iteration", it)
        print(best_features)

        it_r2_vals = []
    #     best_feat_ind = -1

        for feature_ind in range(len(feat_selection)):
            features = [feat_selection[feature_ind]]
            if len(best_features) == 0:
                train_X = train_feat_df_unscaled[features].values.reshape(-1, 1)
            else:
                features = np.concatenate([best_features, features])
                train_X = train_feat_df_unscaled[features].values

            cv_scores = svr_cv(train_X, train_y, folds)

            mean_cv = np.mean(cv_scores)
            print(features[-1], mean_cv)
    #         if mean_cv > max_r2:
    #             best_feat_ind = feature_ind
    #             max_r2 = mean_cv

            it_r2_vals.append(mean_cv)

        best_feat_ind = np.argmax(it_r2_vals)
        best_features.append(feat_selection[best_feat_ind])
        r2_means.append(np.mean(it_r2_vals))
        r2_mins.append(np.min(it_r2_vals))
        r2_maxs.append(np.max(it_r2_vals))

        feat_selection = np.delete(feat_selection, best_feat_ind)

    n_features = np.arange(1, len(selected_features)+1)
    plt.plot(n_features, r2_means, linestyle="--", color="k", label="mean")
    plt.plot(n_features, r2_mins, color="k", label="min")
    plt.fill_between(n_features, r2_maxs, r2_mins, color="gray")
    plt.plot(n_features, r2_maxs, marker="x", color="r", label="max")
    plt.xticks(n_features) #, labels=n_features[::-1]) #, labels=best_features, rotation=45);
    plt.grid()
    plt.xlabel("N Features") #("N Features to Choose From");
    plt.ylabel(r"Mean $R^2$ of 5-fold CV");
    plt.legend();
    
    return best_features

# %%
best_features_lat_lon = seq_feature_importance(selected_features_lat_lon, train_feat_df_unscaled)
# Out:
# iteration 0
# []
# signal_dominant_amplitude 0.05747161455026619
# signal_max_amplitude 0.05099426807287435
# signal_variance 0.053281172890568815
# source_longitude 0.12299752284267162
# source_latitude 0.032327802308537844
# source_depth_km 0.03177324137925854
# amp_01.0 0.2584899849932939
# amp_02.0 0.18902091295419984
# amp_12.0 0.0077514803267334734
# amp_18.0 0.013086570903305983
# amp_ratio_01.0 0.10296459848392318
# amp_ratio_05.0 0.051483797088306284
# iteration 1
# ['amp_01.0']
# signal_dominant_amplitude 0.3204295090896049
# signal_max_amplitude 0.342465368603067
# signal_variance 0.33273035399490186
# source_longitude 0.5404367532879748
# source_latitude 0.5180347168432348
# source_depth_km 0.3204032349789957
# amp_02.0 0.27504378719740463
# amp_12.0 0.3341955160615707
# amp_18.0 0.3592853206782043
# amp_ratio_01.0 0.30113908933259903
# amp_ratio_05.0 0.2596398063004762
# iteration 2
# ['amp_01.0', 'source_longitude']
# signal_dominant_amplitude 0.5658521662736483
# signal_max_amplitude 0.5618702876300097
# signal_variance 0.5640286087538321
# source_latitude 0.7173885510125876
# source_depth_km 0.5365427416625949
# amp_02.0 0.5983536782683798
# amp_12.0 0.5521619109106679
# amp_18.0 0.5750906826283471
# amp_ratio_01.0 0.5106020404808529
# amp_ratio_05.0 0.5252170509270476
# iteration 3
# ['amp_01.0', 'source_longitude', 'source_latitude']
# signal_dominant_amplitude 0.7696972214729539
# signal_max_amplitude 0.767864871031302
# signal_variance 0.7714604987422694
# source_depth_km 0.6992647010235415
# amp_02.0 0.7628675494353836
# amp_12.0 0.7596586734898911
# amp_18.0 0.7583175278027695
# amp_ratio_01.0 0.7135938727648258
# amp_ratio_05.0 0.7235164476089069
# iteration 4
# ['amp_01.0', 'source_longitude', 'source_latitude', 'signal_variance']
# signal_dominant_amplitude 0.7710002314014752
# signal_max_amplitude 0.7692911100567738
# source_depth_km 0.7538618514351441
# amp_02.0 0.7873787612426897
# amp_12.0 0.7675751147284527
# amp_18.0 0.7700502767155456
# amp_ratio_01.0 0.7660367176116957
# amp_ratio_05.0 0.7712088180130448
# iteration 5
# ['amp_01.0', 'source_longitude', 'source_latitude', 'signal_variance', 'amp_02.0']
# signal_dominant_amplitude 0.7866520630621036
# signal_max_amplitude 0.7896640844399533
# source_depth_km 0.7695844205809784
# amp_12.0 0.7892142252452536
# amp_18.0 0.7911427224413509
# amp_ratio_01.0 0.7793219055044215
# amp_ratio_05.0 0.7837232946408589
# iteration 6
# ['amp_01.0', 'source_longitude', 'source_latitude', 'signal_variance', 'amp_02.0', 'amp_18.0']
# signal_dominant_amplitude 0.7878206940447023
# signal_max_amplitude 0.789894560039053
# source_depth_km 0.7772686778239478
# amp_12.0 0.7894190458454038
# amp_ratio_01.0 0.7835944813649617
# amp_ratio_05.0 0.7899689091164339
# iteration 7
# ['amp_01.0', 'source_longitude', 'source_latitude', 'signal_variance', 'amp_02.0', 'amp_18.0', 'amp_ratio_05.0']
# signal_dominant_amplitude 0.7893004266471257
# signal_max_amplitude 0.7896065641510834
# source_depth_km 0.7744741537764757
# amp_12.0 0.7872361300621776
# amp_ratio_01.0 0.778368344339966
# iteration 8
# ['amp_01.0', 'source_longitude', 'source_latitude', 'signal_variance', 'amp_02.0', 'amp_18.0', 'amp_ratio_05.0', 'signal_max_amplitude']
# signal_dominant_amplitude 0.789209092735935
# source_depth_km 0.7765565744025574
# amp_12.0 0.7868471508364419
# amp_ratio_01.0 0.7801078886553843
# iteration 9
# ['amp_01.0', 'source_longitude', 'source_latitude', 'signal_variance', 'amp_02.0', 'amp_18.0', 'amp_ratio_05.0', 'signal_max_amplitude', 'signal_dominant_amplitude']
# source_depth_km 0.7780227102702982
# amp_12.0 0.787411866346957
# amp_ratio_01.0 0.7773483830796432
# iteration 10
# ['amp_01.0', 'source_longitude', 'source_latitude', 'signal_variance', 'amp_02.0', 'amp_18.0', 'amp_ratio_05.0', 'signal_max_amplitude', 'signal_dominant_amplitude', 'amp_12.0']
# source_depth_km 0.777261524581734
# amp_ratio_01.0 0.7772699757516122
# iteration 11
# ['amp_01.0', 'source_longitude', 'source_latitude', 'signal_variance', 'amp_02.0', 'amp_18.0', 'amp_ratio_05.0', 'signal_max_amplitude', 'signal_dominant_amplitude', 'amp_12.0', 'amp_ratio_01.0']
# source_depth_km 0.7649519108444068

# %%
# Best features when including lat, lon, and source_receiver_distance_logkm. Do not include receiver_back_azimith
# ['amp_01.0',
#  'source_longitude',
#  'amp_12.0',
#  'source_receiver_distance_logkm',
#  'amp_02.0',
#  'signal_dominant_amplitude',
#  'amp_ratio_01.0',
#  'source_latitude',
#  'amp_08.0',
#  'amp_18.0',
#  'source_depth_km',
#  'signal_max_amplitude',
#  'signal_variance']

# %%
best_features_lat_lon
# Out:
# ['amp_01.0',
#  'source_longitude',
#  'source_latitude',
#  'signal_variance',
#  'amp_02.0',
#  'amp_18.0',
#  'amp_ratio_05.0',
#  'signal_max_amplitude',
#  'signal_dominant_amplitude',
#  'amp_12.0',
#  'amp_ratio_01.0',
#  'source_depth_km']

# %%
best_features_sr = seq_feature_importance(selected_features_sr, train_feat_df_unscaled)
best_features_sr
# Out:
# iteration 0
# []
# signal_dominant_amplitude 0.05747161455026619
# signal_max_amplitude 0.05099426807287435
# signal_variance 0.053281172890568815
# source_receiver_distance_logkm 0.16943855256429247
# source_depth_km 0.03177324137925854
# receiver_back_azimuth -0.027528371130667927
# amp_01.0 0.2584899849932939
# amp_02.0 0.18902091295419984
# amp_12.0 0.0077514803267334734
# amp_18.0 0.013086570903305983
# amp_ratio_01.0 0.10296459848392318
# amp_ratio_05.0 0.051483797088306284
# iteration 1
# ['amp_01.0']
# signal_dominant_amplitude 0.3204295090896049
# signal_max_amplitude 0.342465368603067
# signal_variance 0.33273035399490186
# source_receiver_distance_logkm 0.636439203127205
# source_depth_km 0.3204032349789957
# receiver_back_azimuth 0.3581501613581534
# amp_02.0 0.27504378719740463
# amp_12.0 0.3341955160615707
# amp_18.0 0.3592853206782043
# amp_ratio_01.0 0.30113908933259903
# amp_ratio_05.0 0.2596398063004762
# iteration 2
# ['amp_01.0', 'source_receiver_distance_logkm']
# signal_dominant_amplitude 0.6979949741807198
# signal_max_amplitude 0.6943183413745222
# signal_variance 0.6974130334906331
# source_depth_km 0.6150573306682462
# receiver_back_azimuth 0.6959734299673141
# amp_02.0 0.6945773733918424
# amp_12.0 0.6730549352937188
# amp_18.0 0.6823138762031163
# amp_ratio_01.0 0.6152169872217759
# amp_ratio_05.0 0.6308350859922776
# iteration 3
# ['amp_01.0', 'source_receiver_distance_logkm', 'signal_dominant_amplitude']
# signal_max_amplitude 0.7003025005691137
# signal_variance 0.6962907569444944
# source_depth_km 0.6764933099547749
# receiver_back_azimuth 0.7593592024825808
# amp_02.0 0.70372666781489
# amp_12.0 0.6979310159976766
# amp_18.0 0.7078509636819232
# amp_ratio_01.0 0.6912015882524946
# amp_ratio_05.0 0.6839223528655859
# iteration 4
# ['amp_01.0', 'source_receiver_distance_logkm', 'signal_dominant_amplitude', 'receiver_back_azimuth']
# signal_max_amplitude 0.757433083091675
# signal_variance 0.7573696073637193
# source_depth_km 0.7348518257862743
# amp_02.0 0.756555755145459
# amp_12.0 0.7552889387255368
# amp_18.0 0.757903839687162
# amp_ratio_01.0 0.7451935558201178
# amp_ratio_05.0 0.7540163624493217
# iteration 5
# ['amp_01.0', 'source_receiver_distance_logkm', 'signal_dominant_amplitude', 'receiver_back_azimuth', 'amp_18.0']
# signal_max_amplitude 0.7555420466332761
# signal_variance 0.7581012538259915
# source_depth_km 0.7383027239096305
# amp_02.0 0.760213507144536
# amp_12.0 0.7549957848688534
# amp_ratio_01.0 0.7412274392268576
# amp_ratio_05.0 0.7574762180312782
# iteration 6
# ['amp_01.0', 'source_receiver_distance_logkm', 'signal_dominant_amplitude', 'receiver_back_azimuth', 'amp_18.0', 'amp_02.0']
# signal_max_amplitude 0.7584257971702568
# signal_variance 0.7582263044020352
# source_depth_km 0.7446566593327547
# amp_12.0 0.7563220657222662
# amp_ratio_01.0 0.7482780599592191
# amp_ratio_05.0 0.7630520200756106
# iteration 7
# ['amp_01.0', 'source_receiver_distance_logkm', 'signal_dominant_amplitude', 'receiver_back_azimuth', 'amp_18.0', 'amp_02.0', 'amp_ratio_05.0']
# signal_max_amplitude 0.7620378948553952
# signal_variance 0.7619061059073535
# source_depth_km 0.745870346700031
# amp_12.0 0.7606156033201016
# amp_ratio_01.0 0.7479399066976568
# iteration 8
# ['amp_01.0', 'source_receiver_distance_logkm', 'signal_dominant_amplitude', 'receiver_back_azimuth', 'amp_18.0', 'amp_02.0', 'amp_ratio_05.0', 'signal_max_amplitude']
# signal_variance 0.7611908451867432
# source_depth_km 0.7468418523865694
# amp_12.0 0.7608794551133091
# amp_ratio_01.0 0.7481308554788677
# iteration 9
# ['amp_01.0', 'source_receiver_distance_logkm', 'signal_dominant_amplitude', 'receiver_back_azimuth', 'amp_18.0', 'amp_02.0', 'amp_ratio_05.0', 'signal_max_amplitude', 'signal_variance']
# source_depth_km 0.7471474154132677
# amp_12.0 0.7613498111472797
# amp_ratio_01.0 0.7496946568603173
# iteration 10
# ['amp_01.0', 'source_receiver_distance_logkm', 'signal_dominant_amplitude', 'receiver_back_azimuth', 'amp_18.0', 'amp_02.0', 'amp_ratio_05.0', 'signal_max_amplitude', 'signal_variance', 'amp_12.0']
# source_depth_km 0.7473630957861012
# amp_ratio_01.0 0.7485854021267286
# iteration 11
# ['amp_01.0', 'source_receiver_distance_logkm', 'signal_dominant_amplitude', 'receiver_back_azimuth', 'amp_18.0', 'amp_02.0', 'amp_ratio_05.0', 'signal_max_amplitude', 'signal_variance', 'amp_12.0', 'amp_ratio_01.0']
# source_depth_km 0.7402103275729485
# ['amp_01.0',
#  'source_receiver_distance_logkm',
#  'signal_dominant_amplitude',
#  'receiver_back_azimuth',
#  'amp_18.0',
#  'amp_02.0',
#  'amp_ratio_05.0',
#  'signal_max_amplitude',
#  'signal_variance',
#  'amp_12.0',
#  'amp_ratio_01.0',
#  'source_depth_km']

# %%
# All selected features with lat lon result
selected_feat_lat_lon_cv = svr_cv(train_feat_df_unscaled[selected_features_lat_lon], train_y, folds)
print(selected_feat_lat_lon_cv)
print(np.mean(selected_feat_lat_lon_cv))
# Out:
# [0.76367122 0.80595787 0.74700143 0.7189451  0.78918393]
# 0.7649519108444068

# %%
# Top 5 features with lat lon 
top_feat_lat_lon_cv = svr_cv(train_feat_df_unscaled[best_features_lat_lon[0:6]], train_y, folds)
print(top_feat_lat_lon_cv )
print(np.mean(top_feat_lat_lon_cv))
# Out:
# [0.83114154 0.82873654 0.76869146 0.72428408 0.80285998]
# 0.7911427224413509

# %%
# All selected features with sr distance and back azimuth
selected_feat_sr_cv = svr_cv(train_feat_df_unscaled[selected_features_sr], train_y, folds)
print(selected_feat_sr_cv)
print(np.mean(selected_feat_sr_cv))
# Out:
# [0.75339199 0.78415758 0.70141378 0.71358455 0.74850374]
# 0.7402103275729486

# %%
# Top 5 selected features with sr distance and back azimuth
top_feat_sr_cv = svr_cv(train_feat_df_unscaled[best_features_sr[0:8]], train_y, folds)
print(top_feat_sr_cv )
print(np.mean(top_feat_sr_cv))
# Out:
# [0.81154808 0.79826168 0.75028549 0.7005768  0.74951741]
# 0.7620378948553952

# %%
selected_feat_df = train_feat_df.copy()[all_selected_features]
selected_feat_df.loc[:, "magnitude"] = train_y
corr = selected_feat_df.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_a86ae_row0_col0, #T_a86ae_row0_col2, #T_a86ae_row1_col1, #T_a86ae_row1_col2, #T_a86ae_row2_col0, #T_a86ae_row2_col1, #T_a86ae_row2_col2, #T_a86ae_row3_col3, #T_a86ae_row4_col4, #T_a86ae_row5_col5, #T_a86ae_row6_col6, #T_a86ae_row7_col7, #T_a86ae_row8_col8, #T_a86ae_row9_col9, #T_a86ae_row10_col10, #T_a86ae_row11_col11, #T_a86ae_row12_col12, #T_a86ae_row13_col13, #T_a86ae_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a86ae_row0_col1, #T_a86ae_row1_col0 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_a86ae_row0_col3, #T_a86ae_row2_col3 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_a86ae_row0_col4, #T_a86ae_row2_col7 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_a86ae_row0_col5, #T_a86ae_row13_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_a86ae_row0_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_a86ae_row0_col7, #T_a86ae_row3_col6, #T_a86ae_row3_col12, #T_a86ae_row3_col14, #T_a86ae_row5_col0, #T_a86ae_row5_col1, #T_a86ae_row5_col2, #T_a86ae_row5_col3, #T_a86ae_row5_col8, #T_a86ae_row5_col9, #T_a86ae_row5_col10, #T_a86ae_row5_col11, #T_a86ae_row5_col13, #T_a86ae_row9_col4, #T_a86ae_row9_col7, #T_a86ae_row11_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a86ae_row0_col8 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_a86ae_row0_col9 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_a86ae_row0_col10, #T_a86ae_row1_col11, #T_a86ae_row10_col0, #T_a86ae_row11_col1 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_a86ae_row0_col11, #T_a86ae_row11_col0 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_a86ae_row0_col12 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_a86ae_row0_col13, #T_a86ae_row1_col13, #T_a86ae_row2_col13 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_a86ae_row0_col14 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_a86ae_row1_col3 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_a86ae_row1_col4, #T_a86ae_row2_col5, #T_a86ae_row8_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_a86ae_row1_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a86ae_row1_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_a86ae_row1_col7, #T_a86ae_row10_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a86ae_row1_col8, #T_a86ae_row8_col10 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_a86ae_row1_col9, #T_a86ae_row9_col8 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_a86ae_row1_col10, #T_a86ae_row2_col10, #T_a86ae_row10_col1, #T_a86ae_row10_col11, #T_a86ae_row11_col10 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_a86ae_row1_col12 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_a86ae_row1_col14 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_a86ae_row2_col4, #T_a86ae_row3_col7 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a86ae_row2_col6, #T_a86ae_row7_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_a86ae_row2_col8 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_a86ae_row2_col9, #T_a86ae_row9_col0 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_a86ae_row2_col11, #T_a86ae_row11_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_a86ae_row2_col12, #T_a86ae_row6_col9 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_a86ae_row2_col14, #T_a86ae_row14_col12 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_a86ae_row3_col0 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_a86ae_row3_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_a86ae_row3_col2, #T_a86ae_row13_col8 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_a86ae_row3_col4, #T_a86ae_row5_col4, #T_a86ae_row10_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_a86ae_row3_col5, #T_a86ae_row10_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a86ae_row3_col8, #T_a86ae_row8_col12 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_a86ae_row3_col9 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_a86ae_row3_col10, #T_a86ae_row8_col13 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_a86ae_row3_col11 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_a86ae_row3_col13, #T_a86ae_row8_col14, #T_a86ae_row14_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_a86ae_row4_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_a86ae_row4_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_a86ae_row4_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_a86ae_row4_col3 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_a86ae_row4_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_a86ae_row4_col6, #T_a86ae_row5_col14 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_a86ae_row4_col7 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_a86ae_row4_col8, #T_a86ae_row7_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_a86ae_row4_col9 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_a86ae_row4_col10 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_a86ae_row4_col11, #T_a86ae_row13_col12 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_a86ae_row4_col12, #T_a86ae_row8_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_a86ae_row4_col13, #T_a86ae_row8_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_a86ae_row4_col14 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_a86ae_row5_col6, #T_a86ae_row7_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_a86ae_row5_col7, #T_a86ae_row12_col14 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_a86ae_row5_col12 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_a86ae_row6_col0, #T_a86ae_row6_col10, #T_a86ae_row6_col11 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_a86ae_row6_col1, #T_a86ae_row6_col2, #T_a86ae_row11_col14 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_a86ae_row6_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_a86ae_row6_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_a86ae_row6_col5 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_a86ae_row6_col7 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_a86ae_row6_col8, #T_a86ae_row7_col6, #T_a86ae_row14_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_a86ae_row6_col12, #T_a86ae_row6_col14 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_a86ae_row6_col13 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_a86ae_row7_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_a86ae_row7_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_a86ae_row7_col3, #T_a86ae_row12_col7 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_a86ae_row7_col5 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_a86ae_row7_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_a86ae_row7_col10 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_a86ae_row7_col11 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_a86ae_row7_col12 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_a86ae_row7_col13 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_a86ae_row7_col14 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_a86ae_row8_col0 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_a86ae_row8_col1 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_a86ae_row8_col2, #T_a86ae_row9_col11 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_a86ae_row8_col3, #T_a86ae_row14_col13 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_a86ae_row8_col7, #T_a86ae_row10_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_a86ae_row8_col9 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_a86ae_row8_col11, #T_a86ae_row10_col8 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_a86ae_row9_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_a86ae_row9_col2 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_a86ae_row9_col3 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_a86ae_row9_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_a86ae_row9_col6 {
#   backgro

# %%
def add_feat_to_base(base_features, additional_features, all_features_cv=None, top_features_cv=None):

    cv_means = []

    for cf in additional_features:
        feat_list = base_features.copy()
        feat_list.append(cf)
        cv_vals = svr_cv(train_feat_df_unscaled[feat_list], train_y, folds)
        cv_means.append(np.mean(cv_vals))

    plt.scatter(range(len(additional_features)), cv_means, marker="x")
    plt.xticks(range(len(additional_features)), labels=additional_features, rotation=45);
    if all_features_cv is not None:
        plt.axhline(np.mean(all_features_cv))
    if top_features_cv is not None:
        plt.axhline(np.mean(top_features_cv), color="C1")
    plt.show()
    
    return cv_means

# %%
base_features = ['source_longitude', "source_latitude", "amp_01.0"]

correlated_features = [ 'amp_02.0', "amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude"]

cv_means_nodepth_noampr1 = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_lat_lon_cv, 
                           top_features_cv=top_feat_lat_lon_cv)

# %%
base_features = ['source_longitude', "source_latitude",'source_depth_km', 'amp_ratio_01.0']

correlated_features = ["amp_01.0", 'amp_02.0', "amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude"]

cv_means = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_lat_lon_cv, 
                           top_features_cv=top_feat_lat_lon_cv)

# %%
base_features = ['source_longitude', "source_latitude",'source_depth_km', 'amp_ratio_01.0', "amp_01.0"]

correlated_features = ['amp_02.0', "amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude"]

cv_means_amp01  = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_lat_lon_cv, 
                           top_features_cv=top_feat_lat_lon_cv)

# %%
base_features = ['source_longitude', "source_latitude",'source_depth_km', 'amp_ratio_01.0', "amp_01.0", "amp_ratio_05.0"]

correlated_features = ['amp_02.0', "amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude"]

cv_means_amp01_ampr05  = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_lat_lon_cv, 
                           top_features_cv=top_feat_lat_lon_cv)

# %%
base_features = ['source_longitude', "source_latitude",'amp_ratio_01.0', "amp_01.0"]

correlated_features = ['amp_02.0', "amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude"]

cv_means_nodepth = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_lat_lon_cv, 
                           top_features_cv=top_feat_lat_lon_cv)

# %%
base_features = ['source_longitude','amp_ratio_01.0', "amp_01.0"]

correlated_features = ['amp_02.0', "amp_03.0","amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude"]

cv_means_nodepth_nolat = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_lat_lon_cv, 
                           top_features_cv=top_feat_lat_lon_cv)

# %%
correlated_features = ["amp_01.0", 'amp_02.0',"amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude"]

plt.scatter( range(0,len(correlated_features)), cv_means, marker="x", label="no_amp1.0")
plt.scatter( range(1,len(correlated_features)), cv_means_amp01, marker="o", label="yes_amp1.0")
plt.scatter( range(1,len(correlated_features)), cv_means_amp01_ampr05, marker="o", label="yes_amp1.0_ampr5.0")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth, marker="v", label="yes_amp1.0_no_depth")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_nolat, marker="x", label="yes_amp1.0_nodepth_nolat")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_noampr1, marker="x", label="yes_amp1.0_nodepth_noampr1")

plt.xticks(range(len(correlated_features)), labels=correlated_features, rotation=45);
plt.axhline(np.mean(selected_feat_lat_lon_cv), label="all_selected_features")
plt.axhline(np.mean(top_feat_lat_lon_cv), color="C1", label="top 5 features")
plt.legend();

# %%
fewer_features_lat_lon = ['source_longitude', "source_latitude", "amp_01.0", 
                          "signal_variance", "amp_18.0", "amp_02.0", "amp_ratio_05.0"]
fewer_feat_lat_lon_df = train_feat_df.copy()[fewer_features_lat_lon]
fewer_feat_lat_lon_df.loc[:, "magnitude"] = train_y
corr = fewer_feat_lat_lon_df.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_7db20_row0_col0, #T_7db20_row1_col1, #T_7db20_row2_col2, #T_7db20_row3_col3, #T_7db20_row4_col4, #T_7db20_row5_col5, #T_7db20_row6_col6, #T_7db20_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7db20_row0_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_7db20_row0_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_7db20_row0_col3, #T_7db20_row7_col2 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_7db20_row0_col4 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_7db20_row0_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_7db20_row0_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_7db20_row0_col7, #T_7db20_row1_col2, #T_7db20_row1_col3, #T_7db20_row1_col4, #T_7db20_row1_col5, #T_7db20_row1_col6, #T_7db20_row5_col1, #T_7db20_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7db20_row1_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_7db20_row1_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_7db20_row2_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_7db20_row2_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_7db20_row2_col3, #T_7db20_row3_col2, #T_7db20_row4_col5 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_7db20_row2_col4, #T_7db20_row4_col6 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_7db20_row2_col5 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_7db20_row2_col6 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_7db20_row2_col7 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_7db20_row3_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_7db20_row3_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_7db20_row3_col4 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_7db20_row3_col5, #T_7db20_row5_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_7db20_row3_col6 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_7db20_row3_col7 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_7db20_row4_col0 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_7db20_row4_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_7db20_row4_col2 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_7db20_row4_col3 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_7db20_row4_col7 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_7db20_row5_col0, #T_7db20_row6_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_7db20_row5_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_7db20_row5_col4 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_7db20_row5_col6 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_7db20_row5_col7 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_7db20_row6_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_7db20_row6_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_7db20_row6_col3 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_7db20_row6_col4 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_7db20_row6_col5 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_7db20_row6_col7 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_7db20_row7_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_7db20_row7_col3 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_7db20_row7_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_7db20_row7_col5 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_7db20_row7_col6 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# </style>
# <table id="T_7db20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7db20_level0_col0" class="col_heading level0 col0" >source_longitude</th>
#       <th id="T_7db20_level0_col1" class="col_heading level0 col1" >source_latitude</th>
#       <th id="T_7db20_level0_col2" class="col_heading level0 col2" >amp_01.0</th>
#       <th id="T_7db20_level0_col3" class="col_heading level0 col3" >signal_variance</th>
#       <th id="T_7db20_level0_col4" class="col_heading level0 col4" >amp_18.0</th>
#       <th id="T_7db20_level0_col5" class="col_heading level0 col5" >amp_02.0</th>
#       <th id="T_7db20_level0_col6" class="col_heading level0 col6" >amp_ratio_05.0</th>
#       <th id="T_7db20_level0_col7" class="col_heading level0 col7" >magnitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7db20_level0_row0" class="row_heading level0 row0" >source_longitude</th>
#       <td id="T_7db20_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7db20_row0_col1" class="data row0 col1" >-0.028696</td>
#       <td id="T_7db20_row0_col2" class="data row0 col2" >0.244921</td>
#       <td id="T_7db20_row0_col3" class="data row0 col3" >0.523975</td>
#       <td id="T_7db20_row0_col4" class="data row0 col4" >0.596597</td>
#       <td id="T_7db20_row0_col5" class="data row0 col5" >0.406541</td>
#       <td id="T_7db20_row0_col6" class="data row0 col6" >0.403607</td>
#       <td id="T_7db20_row0_col7" class="data row0 col7" >-0.193202</td>
#     </tr>
#     <tr>
#       <th id="T_7db20_level0_row1" class="row_heading level0 row1" >source_latitude</th>
#       <td id="T_7db20_row1_col0" class="data row1 col0" >-0.028696</td>
#       <td id="T_7db20_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7db20_row1_col2" class="data row1 col2" >-0.138278</td>
#       <td id="T_7db20_row1_col3" class="data row1 col3" >-0.153419</td>
#       <td id="T_7db20_row1_col4" class="data row1 col4" >-0.038890</td>
#       <td id="T_7db20_row1_col5" class="data row1 col5" >-0.185126</td>
#       <td id="T_7db20_row1_col6" class="data row1 col6" >-0.125305</td>
#       <td id="T_7db20_row1_col7" class="data row1 col7" >0.039468</td>
#     </tr>
#     <tr>
#       <th id="T_7db20_level0_row2" class="row_heading level0 row2" >amp_01.0</th>
#       <td id="T_7db20_row2_col0" class="data row2 col0" >0.244921</td>
#       <td id="T_7db20_row2_col1" class="data row2 col1" >-0.138278</td>
#       <td id="T_7db20_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7db20_row2_col3" class="data row2 col3" >0.833022</td>
#       <td id="T_7db20_row2_col4" class="data row2 col4" >0.699215</td>
#       <td id="T_7db20_row2_col5" class="data row2 col5" >0.910379</td>
#       <td id="T_7db20_row2_col6" class="data row2 col6" >0.605516</td>
#       <td id="T_7db20_row2_col7" class="data row2 col7" >0.529471</td>
#     </tr>
#     <tr>
#       <th id="T_7db20_level0_row3" class="row_heading level0 row3" >signal_variance</th>
#       <td id="T_7db20_row3_col0" class="data row3 col0" >0.523975</td>
#       <td id="T_7db20_row3_col1" class="data row3 col1" >-0.153419</td>
#       <td id="T_7db20_row3_col2" class="data row3 col2" >0.833022</td>
#       <td id="T_7db20_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_7db20_row3_col4" class="data row3 col4" >0.955578</td>
#       <td id="T_7db20_row3_col5" class="data row3 col5" >0.930188</td>
#       <td id="T_7db20_row3_col6" class="data row3 col6" >0.735623</td>
#       <td id="T_7db20_row3_col7" class="data row3 col7" >0.341372</td>
#     </tr>
#     <tr>
#       <th id="T_7db20_level0_row4" class="row_heading level0 row4" >amp_18.0</th>
#       <td id="T_7db20_row4_col0" class="data row4 col0" >0.596597</td>
#       <td id="T_7db20_row4_col1" class="data row4 col1" >-0.038890</td>
#       <td id="T_7db20_row4_col2" class="data row4 col2" >0.699215</td>
#       <td id="T_7db20_row4_col3" class="data row4 col3" >0.955578</td>
#       <td id="T_7db20_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_7db20_row4_col5" class="data row4 col5" >0.827080</td>
#       <td id="T_7db20_row4_col6" class="data row4 col6" >0.672064</td>
#       <td id="T_7db20_row4_col7" class="data row4 col7" >0.204048</td>
#     </tr>
#     <tr>
#       <th id="T_7db20_level0_row5" class="row_heading level0 row5" >amp_02.0</th>
#       <td id="T_7db20_row5_col0" class="data row5 col0" >0.406541</td>
#       <td id="T_7db20_row5_col1" class="data row5 col1" >-0.185126</td>
#       <td id="T_7db20_row5_col2" class="data row5 col2" >0.910379</td>

# %%
fewer_feat_lat_lon_cv = svr_cv(train_feat_df_unscaled[fewer_features_lat_lon], train_y, folds)
print(fewer_feat_lat_lon_cv)
print(np.mean(fewer_feat_lat_lon_cv))
# Out:
# [0.85231721 0.80821216 0.76737402 0.73202451 0.78991665]
# 0.7899689091164339

# %% [markdown]
# ## Closer look at features with sr features

# %%
base_features = ['source_receiver_distance_logkm','source_depth_km', "receiver_back_azimuth", 'amp_ratio_01.0']

correlated_features = ["amp_01.0", 'amp_02.0', "amp_08.0", "amp_12.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude"]

cv_means = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm','source_depth_km', "receiver_back_azimuth", 
                 'amp_ratio_01.0', "amp_01.0"]

correlated_features = ['amp_02.0',"amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude","noise_variance"]
cv_means_amp01  = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm', "receiver_back_azimuth",'amp_ratio_01.0', "amp_01.0"]

correlated_features = ['amp_02.0',"amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude","noise_variance"]

cv_means_nodepth = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm','amp_ratio_01.0', "amp_01.0"]

correlated_features = ['amp_02.0',"amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude","noise_variance"]

cv_means_nodepth_noba = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

# SR distance is important 
# base_features = ["receiver_back_azimuth",'amp_ratio_01.0', "amp_01.0"]

# correlated_features = ['amp_02.0', "amp_08.0", "amp_12.0", "amp_18.0", "signal_variance", 
#                        "signal_dominant_amplitude", "signal_max_amplitude"]

# cv_means_nodepth_nosrd = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
#                            top_features_cv=top_feat_sr_cv)

# %%
base_features = ['source_receiver_distance_logkm', "receiver_back_azimuth",'source_depth_km', 'amp_ratio_01.0', 
                 "amp_01.0", "amp_ratio_03.0"]

correlated_features = ['amp_02.0', "amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude", "noise_variance"]

cv_means_amp01_ampr03  = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

# %%
base_features = ['source_receiver_distance_logkm', "receiver_back_azimuth",'source_depth_km', 'amp_ratio_01.0', 
                 "amp_01.0", "noise_variance"]

correlated_features = ['amp_02.0', "amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude"]

cv_means_amp01_nv  = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

# %%
correlated_features = ["amp_01.0", 'amp_02.0',"amp_03.0", "amp_18.0", "signal_variance", 
                       "signal_dominant_amplitude", "signal_max_amplitude","noise_variance"]

plt.scatter( range(0,len(correlated_features)), cv_means, marker="x", label="no_amp1.0")
plt.scatter( range(1,len(correlated_features)), cv_means_amp01, marker="o", label="yes_amp1.0")
plt.scatter( range(1,len(correlated_features)), cv_means_amp01_ampr03, marker="o", label="yes_amp1.0_ampr3.0")
plt.scatter( range(1,len(correlated_features)-1), cv_means_amp01_nv, marker="o", label="yes_amp1.0_nv")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth, marker="v", label="yes_amp1.0_no_depth")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_noba, marker="x", label="yes_amp1.0_nodepth_noba")
# plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_nosrd, marker="x", label="yes_amp1.0_nodepth_nosr")

plt.xticks(range(len(correlated_features)), labels=correlated_features, rotation=45);
plt.axhline(np.mean(selected_feat_lat_lon_cv), label="all_selected_features")
plt.axhline(np.mean(top_feat_lat_lon_cv), color="C1", label="top 5 features")
plt.legend();

# %%
fewer_features_sr = ['source_receiver_distance_logkm', "receiver_back_azimuth",'amp_ratio_01.0', 
                          "amp_01.0", "signal_variance", "source_depth_km"]
fewer_feat_sr_df = train_feat_df.copy()[fewer_features_sr]
fewer_feat_sr_df.loc[:, "magnitude"] = train_y
corr = fewer_feat_sr_df.corr()
corr.style.background_gradient(cmap="coolwarm")

# %%
fewer_feat_sr_cv = svr_cv(train_feat_df_unscaled[fewer_features_sr], train_y, folds)
print(fewer_feat_sr_cv)
print(np.mean(fewer_feat_sr_cv))
