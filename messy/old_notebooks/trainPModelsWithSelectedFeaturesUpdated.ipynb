# %%
import numpy as np
import pandas as pd 
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import sys
import os
from sklearn.base import clone 
# make paths above 'notebooks/' visible for local imports.
# +----------------------------------------------------------------------------+
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.processing import GatherFeatureDatasets
from src.train import TrainStationModel, OptModelSelectionMethods
from src.plotting import plot_r2_heatmap
from src.utils import CrossValidation as cv

# %% [markdown]
# # Load Data

# %%
proc = GatherFeatureDatasets(is_p=True)

# %%
data_dir = '/uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_splits'
train = pd.read_csv(f'{data_dir}/p.train.csv')
test = pd.read_csv(f'{data_dir}/p.test.csv')
holdout = pd.read_csv(f'{data_dir}/p.2022.csv')
station_feature_dict, station_meta_dict, feature_names = proc.process_all_stations_datasets(train, 
                                                                  test, 
                                                                  holdout_df=holdout,
                                                                  scaler=False,
                                                                  linear_model=False,
                                                                  source_dist_type='dist')
feature_names
# Out:
# YHB
# X shape: (2920, 45), y shape: (2920,)
# X shape: (734, 45), y shape: (734,)
# X shape: (148, 45), y shape: (148,)
# YDC
# X shape: (2509, 45), y shape: (2509,)
# X shape: (645, 45), y shape: (645,)
# X shape: (67, 45), y shape: (67,)
# YWB
# X shape: (3069, 45), y shape: (3069,)
# X shape: (786, 45), y shape: (786,)
# X shape: (157, 45), y shape: (157,)
# MCID
# X shape: (2942, 45), y shape: (2942,)
# X shape: (771, 45), y shape: (771,)
# X shape: (142, 45), y shape: (142,)
# YHL
# X shape: (2739, 45), y shape: (2739,)
# X shape: (682, 45), y shape: (682,)
# X shape: (150, 45), y shape: (150,)
# YMR
# X shape: (3393, 45), y shape: (3393,)
# X shape: (845, 45), y shape: (845,)
# X shape: (177, 45), y shape: (177,)
# YHH
# X shape: (4005, 45), y shape: (4005,)
# X shape: (1002, 45), y shape: (1002,)
# X shape: (185, 45), y shape: (185,)
# B207
# X shape: (1609, 45), y shape: (1609,)
# X shape: (380, 45), y shape: (380,)
# YPP
# X shape: (1334, 45), y shape: (1334,)
# X shape: (338, 45), y shape: (338,)
# X shape: (89, 45), y shape: (89,)
# YPM
# X shape: (3358, 45), y shape: (3358,)
# X shape: (843, 45), y shape: (843,)
# X shape: (172, 45), y shape: (172,)
# YLT
# X shape: (1275, 45), y shape: (1275,)
# X shape: (291, 45), y shape: (291,)
# X shape: (52, 45), y shape: (52,)
# QLMT
# X shape: (792, 45), y shape: (792,)
# X shape: (190, 45), y shape: (190,)
# X shape: (1, 45), y shape: (1,)
# H17A
# X shape: (527, 45), y shape: (527,)
# X shape: (142, 45), y shape: (142,)
# B208
# X shape: (526, 45), y shape: (526,)
# X shape: (134, 45), y shape: (134,)
# LKWY
# X shape: (1016, 45), y shape: (1016,)
# X shape: (278, 45), y shape: (278,)
# FLWY
# X shape: (694, 45), y shape: (694,)
# X shape: (177, 45), y shape: (177,)
# X shape: (43, 45), y shape: (43,)
# YGC
# X shape: (1725, 45), y shape: (1725,)
# X shape: (451, 45), y shape: (451,)
# X shape: (119, 45), y shape: (119,)
# TPMT
# X shape: (408, 45), y shape: (408,)
# X shape: (97, 45), y shape: (97,)
# X shape: (16, 45), y shape: (16,)
# YMC
# X shape: (3553, 45), y shape: (3553,)
# X shape: (898, 45), y shape: (898,)
# X shape: (181, 45), y shape: (181,)
# YML
# X shape: (2678, 45), y shape: (2678,)
# X shape: (638, 45), y shape: (638,)
# X shape: (115, 45), y shape: (115,)
# B206
# X shape: (671, 45), y shape: (671,)
# X shape: (175, 45), y shape: (175,)
# B944
# X shape: (360, 45), y shape: (360,)
# X shape: (95, 45), y shape: (95,)
# YLA
# X shape: (681, 45), y shape: (681,)
# X shape: (169, 45), y shape: (169,)
# X shape: (25, 45), y shape: (25,)
# YUF
# X shape: (1433, 45), y shape: (1433,)
# X shape: (351, 45), y shape: (351,)
# X shape: (65, 45), y shape: (65,)
# YTP
# X shape: (879, 45), y shape: (879,)
# X shape: (212, 45), y shape: (212,)
# X shape: (32, 45), y shape: (32,)
# YNR
# X shape: (4009, 45), y shape: (4009,)
# X shape: (1008, 45), y shape: (1008,)
# X shape: (17, 45), y shape: (17,)
# YNM
# X shape: (852, 45), y shape: (852,)
# X shape: (209, 45), y shape: (209,)
# X shape: (53, 45), y shape: (53,)
# YFT
# X shape: (2915, 45), y shape: (2915,)
# X shape: (723, 45), y shape: (723,)
# X shape: (167, 45), y shape: (167,)
# YPC
# X shape: (343, 45), y shape: (343,)
# X shape: (78, 45), y shape: (78,)
# X shape: (11, 45), y shape: (11,)
# YJC
# X shape: (405, 45), y shape: (405,)
# X shape: (97, 45), y shape: (97,)
# YMS
# X shape: (406, 45), y shape: (406,)
# X shape: (108, 45), y shape: (108,)
# X shape: (9, 45), y shape: (9,)
# YMV
# X shape: (555, 45), y shape: (555,)
# X shape: (148, 45), y shape: (148,)
# X shape: (55, 45), y shape: (55,)
# B950
# X shape: (544, 45), y shape: (544,)
# X shape: (147, 45), y shape: (147,)
# YDD
# X shape: (497, 45), y shape: (497,)
# X shape: (116, 45), y shape: (116,)
# X shape: (60, 45), y shape: (60,)
# array(['amp_ratio_1', 'amp_ratio_2', 'amp_ratio_3', 'amp_ratio_4',
#        'amp_ratio_5', 'amp_ratio_6', 'amp_ratio_7', 'amp_ratio_8',
#        'amp_ratio_9', 'amp_ratio_10', 'amp_ratio_11', 'amp_ratio_12',
#        'amp_ratio_13', 'amp_ratio_14', 'amp_ratio_15', 'amp_ratio_16',
#        'amp_ratio_17', 'amp_ratio_18', 'amp_1', 'amp_2', 'amp_3', 'amp_4',
#        'amp_5', 'amp_6', 'amp_7', 'amp_8', 'amp_9', 'amp_10', 'amp_11',
#        'amp_12', 'amp_13', 'amp_14', 'amp_15', 'amp_16', 'amp_17',
#        'amp_18', 'signal_dominant_frequency', 'signal_dominant_amplitude',
#        'noise_max_amplitude', 'signal_max_amplitude', 'signal_variance',
#        'noise_variance', 'source_depth_km',
#        'source_receiver_distance_logkm',
#        'source_receiver_back_azimuth_deg'], dtype='<U32')

# %%
selected_features = ['amp_1', 'amp_2','signal_dominant_amplitude',
                    'signal_max_amplitude', 'signal_variance',
                    'noise_variance', 'source_depth_km',
                    'source_receiver_distance_logkm',
                    'source_receiver_back_azimuth_deg']

# %%
selected_feat_dict, selected_feature_names = proc.filter_station_dict_features(station_feature_dict,
                                                                             feature_names,
                                                                             selected_features)
# Out:
# YHB
# X_train: (2920, 9), X_test: (734, 9), X_holdout: (148, 9)
# YDC
# X_train: (2509, 9), X_test: (645, 9), X_holdout: (67, 9)
# YWB
# X_train: (3069, 9), X_test: (786, 9), X_holdout: (157, 9)
# MCID
# X_train: (2942, 9), X_test: (771, 9), X_holdout: (142, 9)
# YHL
# X_train: (2739, 9), X_test: (682, 9), X_holdout: (150, 9)
# YMR
# X_train: (3393, 9), X_test: (845, 9), X_holdout: (177, 9)
# YHH
# X_train: (4005, 9), X_test: (1002, 9), X_holdout: (185, 9)
# B207
# X_train: (1609, 9), X_test: (380, 9), X_holdout: 0
# YPP
# X_train: (1334, 9), X_test: (338, 9), X_holdout: (89, 9)
# YPM
# X_train: (3358, 9), X_test: (843, 9), X_holdout: (172, 9)
# YLT
# X_train: (1275, 9), X_test: (291, 9), X_holdout: (52, 9)
# QLMT
# X_train: (792, 9), X_test: (190, 9), X_holdout: (1, 9)
# H17A
# X_train: (527, 9), X_test: (142, 9), X_holdout: 0
# B208
# X_train: (526, 9), X_test: (134, 9), X_holdout: 0
# LKWY
# X_train: (1016, 9), X_test: (278, 9), X_holdout: 0
# FLWY
# X_train: (694, 9), X_test: (177, 9), X_holdout: (43, 9)
# YGC
# X_train: (1725, 9), X_test: (451, 9), X_holdout: (119, 9)
# TPMT
# X_train: (408, 9), X_test: (97, 9), X_holdout: (16, 9)
# YMC
# X_train: (3553, 9), X_test: (898, 9), X_holdout: (181, 9)
# YML
# X_train: (2678, 9), X_test: (638, 9), X_holdout: (115, 9)
# B206
# X_train: (671, 9), X_test: (175, 9), X_holdout: 0
# B944
# X_train: (360, 9), X_test: (95, 9), X_holdout: 0
# YLA
# X_train: (681, 9), X_test: (169, 9), X_holdout: (25, 9)
# YUF
# X_train: (1433, 9), X_test: (351, 9), X_holdout: (65, 9)
# YTP
# X_train: (879, 9), X_test: (212, 9), X_holdout: (32, 9)
# YNR
# X_train: (4009, 9), X_test: (1008, 9), X_holdout: (17, 9)
# YNM
# X_train: (852, 9), X_test: (209, 9), X_holdout: (53, 9)
# YFT
# X_train: (2915, 9), X_test: (723, 9), X_holdout: (167, 9)
# YPC
# X_train: (343, 9), X_test: (78, 9), X_holdout: (11, 9)
# YJC
# X_train: (405, 9), X_test: (97, 9), X_holdout: 0
# YMS
# X_train: (406, 9), X_test: (108, 9), X_holdout: (9, 9)
# YMV
# X_train: (555, 9), X_test: (148, 9), X_holdout: (55, 9)
# B950
# X_train: (544, 9), X_test: (147, 9), X_holdout: 0
# YDD
# X_train: (497, 9), X_test: (116, 9), X_holdout: (60, 9)

# %%
selected_features
# Out:
# ['amp_1',
#  'amp_2',
#  'signal_dominant_amplitude',
#  'signal_max_amplitude',
#  'signal_variance',
#  'noise_variance',
#  'source_depth_km',
#  'source_receiver_distance_logkm',
#  'source_receiver_back_azimuth_deg']

# %% [markdown]
# # Set Parameters

# %%
# Model parameters
model = SVR(kernel='rbf')
model_scaler = True
outdir = '/uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/p_models/selected_features_model_clone'
phase = 'P'
model_selector = OptModelSelectionMethods.select_cv_ind_min_C
model_selector_tol = 0.005

# CV Parameters
cv_random_state = 2652124
cv_folds_inner = 5
svr_C_range= 10**np.arange(-3, 5, dtype=float)
svr_gamma_range = 10**np.arange(-4, 3, dtype=float)
param_grid = [
    {'m__C': svr_C_range, 'm__gamma': svr_gamma_range},
]
scoring_method='r2'
n_jobs_inner = 5
print(param_grid)
# Out:
# [{'m__C': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04]), 'm__gamma': array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02])}]

# %% [markdown]
# # Select hyperparameters, train and evaluate the final model

# %%
stations = selected_feat_dict.keys()
results_dict_list = []

for station in stations:
    # Set up the grid search
    print(station)
    search, cv_inner = cv.setup_cv(clone(model),
                param_grid,
                model_scaler=model_scaler,
                scoring_method=scoring_method,
                n_jobs=n_jobs_inner,
                cv_folds=cv_folds_inner,
                cv_random_state=cv_random_state,
                refit_model = False)
    
    trainer = TrainStationModel(station,
                                phase,
                                selected_feat_dict[station],
                                station_meta_dict[station])
    
    opt_pipeline = cv.make_simple_pipeline(clone(model), model_scaler)
    gs_results, train_results_dict = trainer.train_model_with_cv(search,
                                                                    opt_pipeline,
                                                                    model_selector_fn=model_selector,
                                                                    model_selector_tol=model_selector_tol
                                                                    )
    all_yhat, eval_results_dict = trainer.eval_all_splits(opt_pipeline)
    results_dict = trainer.format_results_dict(train_results_dict,eval_results_dict)
    trainer.save_all_predictions(all_yhat, outdir)
    trainer.save_model(opt_pipeline, outdir)
    plot_r2_heatmap(gs_results, 
                    svr_C_range,
                    svr_gamma_range,
                    train_results_dict['cv_ind_sel'], 
                    station,
                    outdir=outdir,
                    show=True)
    
    results_dict_list.append(results_dict)

results_df = pd.DataFrame(results_dict_list)
results_df.to_csv(os.path.join(outdir, 'all.stat.results.csv'), index=False)
# Out:
# YHB
# YDC
# YWB
# MCID
# YHL
# YMR
# YHH
# B207
# YPP
# YPM
# YLT
# QLMT
# /uufs/chpc.utah.edu/common/home/u1072028/software/pkg/miniconda3/envs/featmags/lib/python3.11/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# H17A
# B208
# LKWY
# FLWY
# YGC
# TPMT
# YMC
# YML
# B206
# /uufs/chpc.utah.edu/common/home/u1072028/PycharmProjects/featmag/src/plotting.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
# B944
# YLA
# YUF
# YTP
# YNR
# YNM
# YFT
# YPC
# YJC
# YMS
# YMV
# B950
# YDD

# %%
results_dict_list
# Out:
# [{'cv_mean_best': 0.9150347003340263,
#   'cv_std_best': 0.005912428855078365,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.9121309219028844,
#   'cv_std_sel': 0.004841349130846699,
#   'C_best': 10.0,
#   'gamma_best': 0.09999999999999999,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.932,
#   'train_rmse': 0.147,
#   'test_r2': 0.915,
#   'test_rmse': 0.164,
#   'holdout_r2': 0.884,
#   'holdout_rmse': 0.198,
#   'station': 'YHB',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8214192832557959,
#   'cv_std_best': 0.018538001630406264,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.8214192832557959,
#   'cv_std_sel': 0.018538001630406264,
#   'C_best': 1.0,
#   'gamma_best': 0.09999999999999999,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.859,
#   'train_rmse': 0.211,
#   'test_r2': 0.834,
#   'test_rmse': 0.22,
#   'holdout_r2': 0.044,
#   'holdout_rmse': 0.577,
#   'station': 'YDC',
#   'phase': 'P'},
#  {'cv_mean_best': 0.9039597461230079,
#   'cv_std_best': 0.006973813814526556,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.9039597461230079,
#   'cv_std_sel': 0.006973813814526556,
#   'C_best': 1.0,
#   'gamma_best': 0.09999999999999999,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.925,
#   'train_rmse': 0.157,
#   'test_r2': 0.914,
#   'test_rmse': 0.164,
#   'holdout_r2': 0.816,
#   'holdout_rmse': 0.239,
#   'station': 'YWB',
#   'phase': 'P'},
#  {'cv_mean_best': 0.9041382559618982,
#   'cv_std_best': 0.0054490359648870015,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.9041382559618982,
#   'cv_std_sel': 0.0054490359648870015,
#   'C_best': 1.0,
#   'gamma_best': 0.09999999999999999,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.924,
#   'train_rmse': 0.153,
#   'test_r2': 0.912,
#   'test_rmse': 0.166,
#   'holdout_r2': 0.835,
#   'holdout_rmse': 0.235,
#   'station': 'MCID',
#   'phase': 'P'},
#  {'cv_mean_best': 0.9000349421847819,
#   'cv_std_best': 0.013179803212441766,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.8963419639099766,
#   'cv_std_sel': 0.011196939814450333,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.922,
#   'train_rmse': 0.157,
#   'test_r2': 0.901,
#   'test_rmse': 0.171,
#   'holdout_r2': 0.816,
#   'holdout_rmse': 0.25,
#   'station': 'YHL',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8964106075462673,
#   'cv_std_best': 0.013783990468600906,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.8921932203498193,
#   'cv_std_sel': 0.007784914331041362,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.916,
#   'train_rmse': 0.16,
#   'test_r2': 0.902,
#   'test_rmse': 0.171,
#   'holdout_r2': 0.842,
#   'holdout_rmse': 0.226,
#   'station': 'YMR',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8929403636141332,
#   'cv_std_best': 0.01290954489546247,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.889683807367063,
#   'cv_std_sel': 0.014985671897826132,
#   'C_best': 10.0,
#   'gamma_best': 0.09999999999999999,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.912,
#   'train_rmse': 0.165,
#   'test_r2': 0.888,
#   'test_rmse': 0.183,
#   'holdout_r2': 0.84,
#   'holdout_rmse': 0.23,
#   'station': 'YHH',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8945890318622561,
#   'cv_std_best': 0.0047616194318940985,
#   'cv_ind_sel': 31,
#   'cv_mean_sel': 0.8901893396393609,
#   'cv_std_sel': 0.005432795065287835,
#   'C_best': 1000.0,
#   'gamma_best': 0.01,
#   'C_sel': 10.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.936,
#   'train_rmse': 0.139,
#   'test_r2': 0.904,
#   'test_rmse': 0.159,
#   'station': 'B207',
#   'phase': 'P'},
#  {'cv_mean_best': 0.874754049947876,
#   'cv_std_best': 0.01637320236284343,
#   'cv_ind_sel': 37,
#   'cv_mean_sel': 0.8736257452899144,
#   'cv_std_sel': 0.015597887333628506,
#   'C_best': 1000.0,
#   'gamma_best': 0.01,
#   'C_sel': 100.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.892,
#   'train_rmse': 0.194,
#   'test_r2': 0.863,
#   'test_rmse': 0.212,
#   'holdout_r2': 0.871,
#   'holdout_rmse': 0.215,
#   'station': 'YPP',
#   'phase': 'P'},
#  {'cv_mean_best': 0.9061799035146626,
#   'cv_std_best': 0.0100271163974914,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.9051585599133682,
#   'cv_std_sel': 0.005369914637806423,
#   'C_best': 10.0,
#   'gamma_best': 0.09999999999999999,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.924,
#   'train_rmse': 0.158,
#   'test_r2': 0.919,
#   'test_rmse': 0.161,
#   'holdout_r2': 0.842,
#   'holdout_rmse': 0.221,
#   'station': 'YPM',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8942525041405298,
#   'cv_std_best': 0.014864167659028336,
#   'cv_ind_sel': 30,
#   'cv_mean_sel': 0.8935738860620871,
#   'cv_std_sel': 0.01237999068766344,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 10.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.902,
#   'train_rmse': 0.185,
#   'test_r2': 0.884,
#   'test_rmse': 0.195,
#   'holdout_r2': 0.788,
#   'holdout_rmse': 0.253,
#   'station': 'YLT',
#   'phase': 'P'},
#  {'cv_mean_best': 0.9172374999976414,
#   'cv_std_best': 0.0077640391032447464,
#   'cv_ind_sel': 30,
#   'cv_mean_sel': 0.9163514397243562,
#   'cv_std_sel': 0.007434015682797784,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 10.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.934,
#   'train_rmse': 0.141,
#   'test_r2': 0.906,
#   'test_rmse': 0.167,
#   'holdout_r2': nan,
#   'holdout_rmse': 0.022,
#   'station': 'QLMT',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8942658356011617,
#   'cv_std_best': 0.0253862569647874,
#   'cv_ind_sel': 37,
#   'cv_mean_sel': 0.8942658356011617,
#   'cv_std_sel': 0.0253862569647874,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 100.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.921,
#   'train_rmse': 0.176,
#   'test_r2': 0.89,
#   'test_rmse': 0.181,
#   'station': 'H17A',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8846616669164291,
#   'cv_std_best': 0.008529174954138264,
#   'cv_ind_sel': 30,
#   'cv_mean_sel': 0.880905107728559,
#   'cv_std_sel': 0.008226931579324193,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 10.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.9,
#   'train_rmse': 0.19,
#   'test_r2': 0.86,
#   'test_rmse': 0.215,
#   'station': 'B208',
#   'phase': 'P'},
#  {'cv_mean_best': 0.9060167473443463,
#   'cv_std_best': 0.00487334885837498,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.905787304644814,
#   'cv_std_sel': 0.012018305907554813,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.936,
#   'train_rmse': 0.157,
#   'test_r2': 0.907,
#   'test_rmse': 0.184,
#   'station': 'LKWY',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8609337138754632,
#   'cv_std_best': 0.03303662381562547,
#   'cv_ind_sel': 37,
#   'cv_mean_sel': 0.8597407641775977,
#   'cv_std_sel': 0.0317337144518652,
#   'C_best': 10000.0,
#   'gamma_best': 0.001,
#   'C_sel': 100.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.901,
#   'train_rmse': 0.174,
#   'test_r2': 0.835,
#   'test_rmse': 0.201,
#   'holdout_r2': 0.896,
#   'holdout_rmse': 0.199,
#   'station': 'FLWY',
#   'phase': 'P'},
#  {'cv_mean_best': 0.883559231086501,
#   'cv_std_best': 0.00963344840244253,
#   'cv_ind_sel': 31,
#   'cv_mean_sel': 0.883559231086501,
#   'cv_std_sel': 0.00963344840244253,
#   'C_best': 10.0,
#   'gamma_best': 0.09999999999999999,
#   'C_sel': 10.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.938,
#   'train_rmse': 0.144,
#   'test_r2': 0.9,
#   'test_rmse': 0.185,
#   'holdout_r2': 0.812,
#   'holdout_rmse': 0.251,
#   'station': 'YGC',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8670455004451944,
#   'cv_std_best': 0.0222012539290832,
#   'cv_ind_sel': 37,
#   'cv_mean_sel': 0.8670455004451944,
#   'cv_std_sel': 0.0222012539290832,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 100.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.918,
#   'train_rmse': 0.16,
#   'test_r2': 0.74,
#   'test_rmse': 0.234,
#   'holdout_r2': 0.546,
#   'holdout_rmse': 0.244,
#   'station': 'TPMT',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8463864126632558,
#   'cv_std_best': 0.012247616064016332,
#   'cv_ind_sel': 31,
#   'cv_mean_sel': 0.8463864126632558,
#   'cv_std_sel': 0.012247616064016332,
#   'C_best': 10.0,
#   'gamma_best': 0.09999999999999999,
#   'C_sel': 10.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.879,
#   'train_rmse': 0.198,
#   'test_r2': 0.85,
#   'test_rmse': 0.22,
#   'holdout_r2': 0.888,
#   'holdout_rmse': 0.19,
#   'station': 'YMC',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8853193010264867,
#   'cv_std_best': 0.014535045455093754,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.8822203351243239,
#   'cv_std_sel': 0.017274546311910645,
#   'C_best': 10.0,
#   'gamma_best': 0.09999999999999999,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.904,
#   'train_rmse': 0.18,
#   'test_r2': 0.897,
#   'test_rmse': 0.181,
#   'holdout_r2': 0.737,
#   'holdout_rmse': 0.296,
#   'station': 'YML',
#   'phase': 'P'},
#  {'cv_mean_best': 0.902361027805196,
#   'cv_std_best': 0.02770344320144413,
#   'cv_ind_sel': 30,
#   'cv_mean_sel': 0.8994613808346992,
#   'cv_std_sel': 0.011596263828674397,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 10.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.919,
#   'train_rmse': 0.166,
#   'test_r2': 0.905,
#   'test_rmse': 0.16,
#   'station': 'B206',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8200865918986299,
#   'cv_std_best': 0.030377460936196518,
#   'cv_ind_sel': 37,
#   'cv_mean_sel': 0.8200865918986299,
#   'cv_std_sel': 0.030377460936196518,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 100.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.85,
#   'train_rmse': 0.228,
#   'test_r2': 0.853,
#   'test_rmse': 0.21,
#   'station': 'B944',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8338790048976465,
#   'cv_std_best': 0.016377143973680015,
#   'cv_ind_sel': 31,
#   'cv_mean_sel': 0.8338790048976465,
#   'cv_std_sel': 0.016377143973680015,
#   'C_best': 10.0,
#   'gamma_best': 0.09999999999999999,
#   'C_sel': 10.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.933,
#   'train_rmse': 0.137,
#   'test_r2': 0.864,
#   'test_rmse': 0.196,
#   'holdout_r2': 0.452,
#   'holdout_rmse': 0.455,
#   'station': 'YLA',
#   'phase': 'P'},
#  {'cv_mean_best': 0.90241143341181,
#   'cv_std_best': 0.011594864821386566,
#   'cv_ind_sel': 31,
#   'cv_mean_sel': 0.898687241345781,
#   'cv_std_sel': 0.008663408061142805,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 10.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.947,
#   'train_rmse': 0.141,
#   'test_r2': 0.912,
#   'test_rmse': 0.174,
#   'holdout_r2': 0.738,
#   'holdout_rmse': 0.271,
#   'station': 'YUF',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8418409681729679,
#   'cv_std_best': 0.029759725977364804,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.8397778155758505,
#   'cv_std_sel': 0.020668019150013994,
#   'C_best': 10.0,
#   'gamma_best': 0.09999999999999999,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.9,
#   'train_rmse': 0.168,
#   'test_r2': 0.887,
#   'test_rmse': 0.181,
#   'holdout_r2': 0.344,
#   'holdout_rmse': 0.494,
#   'station': 'YTP',
#   'phase': 'P'},
#  {'cv_mean_best': 0.9048174890184596,
#   'cv_std_best': 0.004551411005813853,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.9023924696571408,
#   'cv_std_sel': 0.004952710393915459,
#   'C_best': 1000.0,
#   'gamma_best': 0.01,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.921,
#   'train_rmse': 0.159,
#   'test_r2': 0.905,
#   'test_rmse': 0.172,
#   'holdout_r2': 0.869,
#   'holdout_rmse': 0.19,
#   'station': 'YNR',
#   'phase': 'P'},
#  {'cv_mean_best': 0.9270895869345249,
#   'cv_std_best': 0.012445294038148211,
#   'cv_ind_sel': 30,
#   'cv_mean_sel': 0.9270895869345249,
#   'cv_std_sel': 0.012445294038148211,
#   'C_best': 10.0,
#   'gamma_best': 0.01,
#   'C_sel': 10.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.938,
#   'train_rmse': 0.15,
#   'test_r2': 0.909,
#   'test_rmse': 0.158,
#   'holdout_r2': 0.905,
#   'holdout_rmse': 0.199,
#   'station': 'YNM',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8830959558827571,
#   'cv_std_best': 0.006536828778396945,
#   'cv_ind_sel': 37,
#   'cv_mean_sel': 0.8814456001066014,
#   'cv_std_sel': 0.006164208619687571,
#   'C_best': 1000.0,
#   'gamma_best': 0.01,
#   'C_sel': 100.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.894,
#   'train_rmse': 0.179,
#   'test_r2': 0.885,
#   'test_rmse': 0.18,
#   'holdout_r2': 0.82,
#   'holdout_rmse': 0.217,
#   'station': 'YFT',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8687825605459374,
#   'cv_std_best': 0.014631300438532375,
#   'cv_ind_sel': 30,
#   'cv_mean_sel': 0.8687825605459374,
#   'cv_std_sel': 0.014631300438532375,
#   'C_best': 10.0,
#   'gamma_best': 0.01,
#   'C_sel': 10.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.906,
#   'train_rmse': 0.158,
#   'test_r2': 0.883,
#   'test_rmse': 0.175,
#   'holdout_r2': 0.862,
#   'holdout_rmse': 0.27,
#   'station': 'YPC',
#   'phase': 'P'},
#  {'cv_mean_best': 0.887602174677786,
#   'cv_std_best': 0.023863648018822174,
#   'cv_ind_sel': 30,
#   'cv_mean_sel': 0.887602174677786,
#   'cv_std_sel': 0.023863648018822174,
#   'C_best': 10.0,
#   'gamma_best': 0.01,
#   'C_sel': 10.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.915,
#   'train_rmse': 0.203,
#   'test_r2': 0.887,
#   'test_rmse': 0.209,
#   'station': 'YJC',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8328173558332026,
#   'cv_std_best': 0.024074294763794815,
#   'cv_ind_sel': 30,
#   'cv_mean_sel': 0.8316039674280006,
#   'cv_std_sel': 0.02180965721945945,
#   'C_best': 1000.0,
#   'gamma_best': 0.001,
#   'C_sel': 10.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.871,
#   'train_rmse': 0.168,
#   'test_r2': 0.804,
#   'test_rmse': 0.23,
#   'holdout_r2': 0.859,
#   'holdout_rmse': 0.293,
#   'station': 'YMS',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8754205046777773,
#   'cv_std_best': 0.07478275401335716,
#   'cv_ind_sel': 24,
#   'cv_mean_sel': 0.8739658501805385,
#   'cv_std_sel': 0.06911696450771787,
#   'C_best': 10000.0,
#   'gamma_best': 9.999999999999999e-05,
#   'C_sel': 1.0,
#   'gamma_sel': 0.09999999999999999,
#   'train_r2': 0.923,
#   'train_rmse': 0.163,
#   'test_r2': 0.857,
#   'test_rmse': 0.201,
#   'holdout_r2': 0.803,
#   'holdout_rmse': 0.221,
#   'station': 'YMV',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8659844829437308,
#   'cv_std_best': 0.03635759548889866,
#   'cv_ind_sel': 37,
#   'cv_mean_sel': 0.8659844829437308,
#   'cv_std_sel': 0.03635759548889866,
#   'C_best': 100.0,
#   'gamma_best': 0.01,
#   'C_sel': 100.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.899,
#   'train_rmse': 0.157,
#   'test_r2': 0.893,
#   'test_rmse': 0.163,
#   'station': 'B950',
#   'phase': 'P'},
#  {'cv_mean_best': 0.8825024104441057,
#   'cv_std_best': 0.022416192618169,
#   'cv_ind_sel': 37,
#   'cv_mean_sel': 0.8794246783855801,
#   'cv_std_sel': 0.021716716763418242,
#   'C_best': 10000.0,
#   'gamma_best': 0.001,
#   'C_sel': 100.0,
#   'gamma_sel': 0.01,
#   'train_r2': 0.912,
#   'train_rmse': 0.16,
#   'test_r2': 0.904,
#   'test_rmse': 0.16,
#   'holdout_r2': 0.874,
#   'holdout_rmse': 0.201,
#   'station': 'YDD',
#   'phase': 'P'}]
