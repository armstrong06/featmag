# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pygmt
from obspy.core import UTCDateTime

# %%
# Read in features, look at names & datatypes
df_original = pd.read_csv('../s_features.csv', dtype={'location_code': str})
print(len(df_original))
print(df_original.dtypes)
# Out:
# 14152
# arrival_identifier                        int64
# channel1                                 object
# channel2                                 object
# event_identifier                          int64
# location_code                            object
#                                          ...
# transverse_signal_dominant_amplitude    float64
# transverse_signal_dominant_frequency    float64
# transverse_signal_maximum_value         float64
# transverse_signal_minimum_value         float64
# transverse_signal_variance              float64
# Length: 106, dtype: object

# %%
# Get metadata for 1 and 3c stations
eq_meta_onec = pd.read_csv("../currentEarthquakeArrivalInformation1CWithGains.csv")
eq_meta_threec = pd.read_csv("../currentEarthquakeArrivalInformation3CWithGains.csv")
eq_meta_all = pd.concat([eq_meta_onec, eq_meta_threec])

# Reduce to just location information
all_eq_locs = eq_meta_all.drop_duplicates("evid")[["evid", "event_lat", "event_lon", "origin_time"]]
all_eq_locs.columns = ["event_identifier", "event_lat", "event_lon", "origin_time"]

# Reduce to events in the dataset 
eq_locs_df = all_eq_locs[np.isin(all_eq_locs.event_identifier, df_original.event_identifier.unique())]
# Make date column for filtering
eq_locs_df.loc[:, "date"] = eq_locs_df.origin_time.apply(lambda x: int(UTCDateTime(x).strftime("%y%m%d")))
# Out:
# /tmp/ipykernel_5402/187499698.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   eq_meta_threec = pd.read_csv("../currentEarthquakeArrivalInformation3CWithGains.csv")
# /tmp/ipykernel_5402/187499698.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eq_locs_df.loc[:, "date"] = eq_locs_df.origin_time.apply(lambda x: int(UTCDateTime(x).strftime("%y%m%d")))

# %%
# Set filter bounds
lat_min = 44.680
lat_max = 44.870
lon_max = 110.850
lon_min = 110.640
date_min = 130901  # YYMMDD
date_max = 140630  # YYMMDD
bounds = {"lat_min": lat_min,
          "lat_max": lat_max,
          "lon_max": lon_max,
          "lon_min": lon_min,
          "date_min": date_min,
          "date_max": date_max}

# Get ngb event ids
ngb_event_locs = eq_locs_df.loc[
        (eq_locs_df["date"] >= bounds["date_min"]) & (eq_locs_df["date"] <= bounds["date_max"]) & (eq_locs_df["event_lat"] >= bounds["lat_min"])
        & (eq_locs_df["event_lat"] <= bounds["lat_max"]) & (-1 * eq_locs_df["event_lon"] >= bounds["lon_min"]) & (
                    -1 * eq_locs_df["event_lon"] <= bounds["lon_max"])]

# %%
df_ngb_removed = df_original[~np.isin(df_original.event_identifier, ngb_event_locs.event_identifier)]
df_ngb = df_original[np.isin(df_original.event_identifier, ngb_event_locs.event_identifier)]
np.where(np.isin(df_ngb_removed.event_identifier, df_ngb.event_identifier))
# Out:
# (array([], dtype=int64),)

# %%
# Read in park and caldera boundaries
utahnet_path = "../../maps/utahnet"
ys_border = pd.read_csv(f"{utahnet_path}/yell.border.g", delimiter=" ", names=["Longitude", "Latitude"], dtype=np.float64)
caldera = pd.read_csv(f"{utahnet_path}/caldera.ys", sep="\s+", names=["Latitude", "Longitude"], dtype=np.float64)

caldera = caldera.drop(caldera[caldera["Longitude"]==0].index)
caldera = caldera[["Longitude", "Latitude"]]
caldera["Longitude"] = caldera["Longitude"]*-1

# %%
# Lat/lon bounding box I could use to scale the source locations
bb_lat_min = ys_border.Latitude.min() - 0.2
bb_lat_max = ys_border.Latitude.max()
bb_lon_min = ys_border.Longitude.min() - 0.15
bb_lon_max = ys_border.Longitude.max()
ys_bb = [[bb_lon_max, bb_lat_max], [bb_lon_max, bb_lat_min], [bb_lon_min, bb_lat_min], [bb_lon_min, bb_lat_max], [bb_lon_max, bb_lat_max]]

# %%
#Draw event map 
region = [
    eq_locs_df.event_lon.min() - 0.2,
    eq_locs_df.event_lon.max() + 0.2,
    eq_locs_df.event_lat.min() - 0.1,
    eq_locs_df.event_lat.max() + 0.2,
]

unique_locations = df_ngb_removed[["source_longitude", "source_latitude"]].drop_duplicates()
unique_ngb_locations = df_ngb[["source_longitude", "source_latitude"]].drop_duplicates()

fig = pygmt.Figure()
fig.basemap(region=region, projection="M15c", frame=True)
fig.coast(land="white", borders=2, water="skyblue")
fig.plot(data=ys_border, pen="1.0p,black")
fig.plot(data=caldera, pen='1.0p,black')
fig.plot(x=unique_ngb_locations.source_longitude, y=unique_ngb_locations.source_latitude, style="c0.2c", pen="0.2p,red")
fig.plot(x=unique_locations.source_longitude, y=unique_locations.source_latitude, style="c0.2c", pen="0.2p,black")
fig.plot(ys_bb, pen="0.6p,blue")
fig.show()

# %%
# Keep stations with more than 200 observations
stat_counts = df_original.value_counts("station").to_frame().reset_index()
stat_counts.columns = ["Station", "Count"]
df_org_filtcounts = df_ngb_removed[np.isin(df_ngb_removed.station, stat_counts[stat_counts.Count >= 200])]

# %%
stat_counts
# Out:
#    Station  Count
# 0      YNR   2238
# 1      YMR   1596
# 2      YMC   1463
# 3      YHB   1169
# 4      YHH   1097
# 5      YFT    929
# 6      YUF    915
# 7      YHL    582
# 8      YML    528
# 9      YTP    476
# 10     YNM    396
# 11    B207    395
# 12    FLWY    388
# 13     YDD    274
# 14    LKWY    256
# 15    B206    255
# 16     YPP    201
# 17    B950    184
# 18     YJC    142
# 19    B208    141
# 20    B945    133
# 21    H17A    121
# 22    B944    118
# 23     IMW     35
# 24     YPK     32
# 25     YNE     29
# 26     YHR     14
# 27     YEE     13
# 28    LOHW     11
# 29    MOOW      9
# 30     YMP      8
# 31    SNOW      2
# 32    TPAW      1
# 33    RLMT      1

# %% [markdown]
# ## Feature selection?

# %%
# Make train and test datasets

test_size = 0.2
station = "YNR"

station_df = df_org_filtcounts[df_org_filtcounts.station == station]

evids = np.unique(station_df.event_identifier)
train_evids, test_evids = train_test_split(evids, test_size = test_size, random_state = 843823)

train_inds = np.isin(station_df.event_identifier, train_evids)
train_df = station_df[train_inds]
test_df = station_df[~train_inds]

assert len(train_df.event_identifier.unique()) == len(train_evids)
assert len(test_df.event_identifier.unique()) == len(test_evids)
assert len(test_df) + len(train_df) == len(station_df)

# %%
df_org_filtcounts.source_receiver_back_azimuth
# Out:
# 0         79.885217
# 1        141.914754
# 2        317.579447
# 3        262.065224
# 4        310.504241
#             ...
# 14147     42.664489
# 14148     70.900113
# 14149    124.067453
# 14150    231.711248
# 14151    290.611070
# Name: source_receiver_back_azimuth, Length: 11850, dtype: float64

# %%
# ?np.sin

# %%
# Computes the feature matrix from a dataframe
def compute_feature_matrix(df, scaler = True):
    # Loosely speaking empirical magnitudes look like:
    # M = log10(A) + Q(Delta) 
    # where A is the amplitude and Q a distance dependent correction term.
    # Additionally, the difference between log10 and log amounts to a scalar
    # that a machine can learn.
    # Basically, I'm interested in features that:
    #   (1) Measure size in, potentially, different amplitudes.
    # different `passbands' deviates from the noise, 
    n_rows = len(df)
    n_columns = 34
    X = np.zeros([n_rows, n_columns])
    # Get a proxy on size
    w1 = 0.5
    w2 = 1 - w1
    # These are effectively amplitude ratios.  Note,
    # log(a/b) = log(a) - log(b)
    X[:,0]  = w1*(np.log(df['radial_avg_signal_1.00']) - np.log(df['radial_avg_noise_1.00'])) \
            + w2*(np.log(df['transverse_avg_signal_1.00']) - np.log(df['transverse_avg_noise_1.00']))
    X[:,1]  = w1*(np.log(df['radial_avg_signal_2.00']) - np.log(df['radial_avg_noise_2.00'])) \
            + w2*(np.log(df['transverse_avg_signal_2.00']) - np.log(df['transverse_avg_noise_2.00']))
    X[:,2]  = w1*(np.log(df['radial_avg_signal_3.00']) - np.log(df['radial_avg_noise_3.00'])) \
            + w2*(np.log(df['transverse_avg_signal_3.00']) - np.log(df['transverse_avg_noise_3.00']))
    X[:,3]  = w1*(np.log(df['radial_avg_signal_4.00']) - np.log(df['radial_avg_noise_4.00'])) \
            + w2*(np.log(df['transverse_avg_signal_4.00']) - np.log(df['transverse_avg_noise_4.00']))
    X[:,4]  = w1*(np.log(df['radial_avg_signal_5.00']) - np.log(df['radial_avg_noise_5.00'])) \
            + w2*(np.log(df['transverse_avg_signal_5.00']) - np.log(df['transverse_avg_noise_5.00']))
    X[:,5]  = w1*(np.log(df['radial_avg_signal_6.00']) - np.log(df['radial_avg_noise_6.00'])) \
            + w2*(np.log(df['transverse_avg_signal_6.00']) - np.log(df['transverse_avg_noise_6.00']))
    X[:,6]  = w1*(np.log(df['radial_avg_signal_7.00']) - np.log(df['radial_avg_noise_7.00'])) \
            + w2*(np.log(df['transverse_avg_signal_7.00']) - np.log(df['transverse_avg_noise_7.00']))
    X[:,7]  = w1*(np.log(df['radial_avg_signal_8.00']) - np.log(df['radial_avg_noise_8.00'])) \
            + w2*(np.log(df['transverse_avg_signal_8.00']) - np.log(df['transverse_avg_noise_8.00']))
    X[:,8]  = w1*(np.log(df['radial_avg_signal_9.00']) - np.log(df['radial_avg_noise_9.00'])) \
            + w2*(np.log(df['transverse_avg_signal_9.00']) - np.log(df['transverse_avg_noise_9.00']))
    X[:,9]  = w1*(np.log(df['radial_avg_signal_10.00']) - np.log(df['radial_avg_noise_10.00'])) \
            + w2*(np.log(df['transverse_avg_signal_10.00']) - np.log(df['transverse_avg_noise_10.00']))
    X[:,10]  = w1*(np.log(df['radial_avg_signal_11.00']) - np.log(df['radial_avg_noise_11.00'])) \
             + w2*(np.log(df['transverse_avg_signal_11.00']) - np.log(df['transverse_avg_noise_11.00']))
    X[:,11]  = w1*(np.log(df['radial_avg_signal_12.00']) - np.log(df['radial_avg_noise_12.00'])) \
             + w2*(np.log(df['transverse_avg_signal_12.00']) - np.log(df['transverse_avg_noise_12.00']))
    
    # Look at amplitudes
    X[:,12] = w1*np.log(df['radial_avg_signal_1.00']) + w2*np.log(df['transverse_avg_signal_1.00']) 
    X[:,13] = w1*np.log(df['radial_avg_signal_2.00']) + w2*np.log(df['transverse_avg_signal_2.00']) 
    X[:,14] = w1*np.log(df['radial_avg_signal_3.00']) + w2*np.log(df['transverse_avg_signal_3.00']) 
    X[:,15] = w1*np.log(df['radial_avg_signal_4.00']) + w2*np.log(df['transverse_avg_signal_4.00']) 
    X[:,16] = w1*np.log(df['radial_avg_signal_5.00']) + w2*np.log(df['transverse_avg_signal_5.00']) 
    X[:,17] = w1*np.log(df['radial_avg_signal_6.00']) + w2*np.log(df['transverse_avg_signal_6.00']) 
    X[:,18] = w1*np.log(df['radial_avg_signal_7.00']) + w2*np.log(df['transverse_avg_signal_7.00']) 
    X[:,19] = w1*np.log(df['radial_avg_signal_8.00']) + w2*np.log(df['transverse_avg_signal_8.00']) 
    X[:,20] = w1*np.log(df['radial_avg_signal_9.00']) + w2*np.log(df['transverse_avg_signal_9.00']) 
    X[:,21] = w1*np.log(df['radial_avg_signal_10.00']) + w2*np.log(df['transverse_avg_signal_10.00']) 
    X[:,22] = w1*np.log(df['radial_avg_signal_11.00']) + w2*np.log(df['transverse_avg_signal_11.00'])
    X[:,23] = w1*np.log(df['radial_avg_signal_12.00']) + w2*np.log(df['transverse_avg_signal_12.00']) 

 
    # Frequency and max amplitude
    X[:,24] = w1*np.log(df['radial_signal_dominant_frequency']) \
            + w2*np.log(df['transverse_signal_dominant_frequency'])
    X[:,25] = w1*np.log(df['radial_signal_dominant_amplitude']) \
            + w2*np.log(df['transverse_signal_dominant_amplitude'])
    # Time-based featuers: Look at max amplitudes of noise/signal
    X[:,26] = w1*(np.log(df['radial_noise_maximum_value'] - df['radial_noise_minimum_value'])) \
            + w2*(np.log(df['transverse_noise_maximum_value'] - df['transverse_noise_minimum_value']))
    X[:,27] = w1*(np.log(df['radial_signal_maximum_value'] - df['radial_signal_minimum_value'])) \
            + w2*(np.log(df['transverse_signal_maximum_value'] - df['transverse_signal_minimum_value']))
    X[:,28] = w1*np.log(df['radial_signal_variance']) + w2*np.log(df['transverse_signal_variance'])
    X[:,29] = w1*np.log(df['radial_noise_variance']) + w2*np.log(df['transverse_noise_variance'])
    # Source/recv distance (take log to flatten this)
    X[:,30] = np.log(df['source_receiver_distance_km'])
    X[:,31] = df['source_depth_km']
    # Caution - not a great features for linear methods b/c 359 and 361 are similar
    X[:, 32] = np.sin(df['source_receiver_back_azimuth']*np.pi/180)
    X[:,33] = df['source_receiver_back_azimuth']

    # Standardize features
    if (scaler):
        scaler = StandardScaler()
        scaler = scaler.fit(X)
        X = scaler.transform(X)
        return X, scaler
    
    return X

# %%
train_feat_matrix_scaled, scaler = compute_feature_matrix(train_df)
train_feat_matrix_unscaled = compute_feature_matrix(train_df, scaler=False)

train_y = train_df.magnitude.values

# %%
train_feat_matrix_scaled[0], train_feat_matrix_unscaled[0]
# Out:
# (array([ 0.41534968, -1.53778409, -1.91561279, -1.05519206,  0.10515481,
#          0.474014  ,  0.45826493,  0.68062931,  0.94016241,  0.97438241,
#          0.79453401,  0.56146447,  2.62625646,  1.64049539,  1.29408072,
#          1.40944392,  1.64369884,  1.7309443 ,  1.67805213,  1.60597956,
#          1.49621496,  1.3351226 ,  1.15681235,  0.9940772 , -0.57549799,
#          1.36467416,  1.31492837,  1.2030196 ,  1.34118164,  1.48611197,
#          1.57525072,  0.63419343,  0.19171667, -0.63793996]),
#  array([  1.60651363,   1.16030933,   1.12069313,   1.77386418,
#           2.45750364,   2.66968227,   2.64732779,   2.68699593,
#           2.70816898,   2.61705314,   2.45374496,   2.29454467,
#           0.7041083 ,   0.67054612,   0.60523929,   0.75965486,
#           1.09197254,   1.23529413,   1.16881132,   1.05902453,
#           0.90886348,   0.70386894,   0.471539  ,   0.2384853 ,
#           1.86883481,  -0.84246601,   2.32297915,   3.72090876,
#           3.85273759,   1.67403897,   3.83699892,   8.91      ,
#          -0.63324723, 219.29010553]))

# %%
train_y
# Out:
# array([3.1 , 1.76, 0.54, ..., 1.92, 1.63, 1.79])

# %%
for col in df_org_filtcounts.columns:
    print(col)
# Out:
# arrival_identifier
# channel1
# channel2
# event_identifier
# location_code
# magnitude
# magnitude_type
# network
# radial_avg_noise_1.00
# radial_avg_noise_10.00
# radial_avg_noise_11.00
# radial_avg_noise_12.00
# radial_avg_noise_13.00
# radial_avg_noise_14.00
# radial_avg_noise_15.00
# radial_avg_noise_16.00
# radial_avg_noise_17.00
# radial_avg_noise_18.00
# radial_avg_noise_2.00
# radial_avg_noise_3.00
# radial_avg_noise_4.00
# radial_avg_noise_5.00
# radial_avg_noise_6.00
# radial_avg_noise_7.00
# radial_avg_noise_8.00
# radial_avg_noise_9.00
# radial_avg_signal_1.00
# radial_avg_signal_10.00
# radial_avg_signal_11.00
# radial_avg_signal_12.00
# radial_avg_signal_13.00
# radial_avg_signal_14.00
# radial_avg_signal_15.00
# radial_avg_signal_16.00
# radial_avg_signal_17.00
# radial_avg_signal_18.00
# radial_avg_signal_2.00
# radial_avg_signal_3.00
# radial_avg_signal_4.00
# radial_avg_signal_5.00
# radial_avg_signal_6.00
# radial_avg_signal_7.00
# radial_avg_signal_8.00
# radial_avg_signal_9.00
# radial_noise_dominant_amplitude
# radial_noise_dominant_frequency
# radial_noise_maximum_value
# radial_noise_minimum_value
# radial_noise_variance
# radial_signal_dominant_amplitude
# radial_signal_dominant_frequency
# radial_signal_maximum_value
# radial_signal_minimum_value
# radial_signal_variance
# source_depth_km
# source_latitude
# source_longitude
# source_receiver_back_azimuth
# source_receiver_distance_km
# station
# transverse_avg_noise_1.00
# transverse_avg_noise_10.00
# transverse_avg_noise_11.00
# transverse_avg_noise_12.00
# transverse_avg_noise_13.00
# transverse_avg_noise_14.00
# transverse_avg_noise_15.00
# transverse_avg_noise_16.00
# transverse_avg_noise_17.00
# transverse_avg_noise_18.00
# transverse_avg_noise_2.00
# transverse_avg_noise_3.00
# transverse_avg_noise_4.00
# transverse_avg_noise_5.00
# transverse_avg_noise_6.00
# transverse_avg_noise_7.00
# transverse_avg_noise_8.00
# transverse_avg_noise_9.00
# transverse_avg_signal_1.00
# transverse_avg_signal_10.00
# transverse_avg_signal_11.00
# transverse_avg_signal_12.00
# transverse_avg_signal_13.00
# transverse_avg_signal_14.00
# transverse_avg_signal_15.00
# transverse_avg_signal_16.00
# transverse_avg_signal_17.00
# transverse_avg_signal_18.00
# transverse_avg_signal_2.00
# transverse_avg_signal_3.00
# transverse_avg_signal_4.00
# transverse_avg_signal_5.00
# transverse_avg_signal_6.00
# transverse_avg_signal_7.00
# transverse_avg_signal_8.00
# transverse_avg_signal_9.00
# transverse_noise_dominant_amplitude
# transverse_noise_dominant_frequency
# transverse_noise_maximum_value
# transverse_noise_minimum_value
# transverse_noise_variance
# transverse_signal_dominant_amplitude
# transverse_signal_dominant_frequency
# transverse_signal_maximum_value
# transverse_signal_minimum_value
# transverse_signal_variance

# %%
columns = ["amp_ratio_01.0", "amp_ratio_02.0", "amp_ratio_03.0", "amp_ratio_04.0", 
             "amp_ratio_05.0", "amp_ratio_06.0", "amp_ratio_07.0", "amp_ratio_08.0",
             "amp_ratio_09.0", "amp_ratio_10.0", "amp_ratio_11.0", "amp_ratio_12.0", 
             "amp_01.0", "amp_02.0", "amp_03.0", "amp_04.0", 
             "amp_05.0", "amp_06.0", "amp_07.0", "amp_08.0",
             "amp_09.0", "amp_10.0", "amp_11.0", "amp_12.0", 
             "signal_dominant_frequency", "signal_dominant_amplitude", 
             "noise_max_amplitude", "signal_max_amplitude", "signal_variance", "noise_variance",
             "source_receiver_distance_logkm", "source_depth_km", "sin_receiver_back_azimuth", 
             "receiver_back_azimuth"]
train_feat_df = pd.DataFrame(train_feat_matrix_scaled, columns=columns)

# %%
train_feat_df_unscaled = pd.DataFrame(train_feat_matrix_unscaled, columns=columns)

# %%
feat_target_df = train_feat_df.copy()
feat_target_df.loc[:, "magnitude"] = train_y
corr = feat_target_df.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_48e18_row0_col0, #T_48e18_row1_col1, #T_48e18_row2_col2, #T_48e18_row3_col3, #T_48e18_row4_col4, #T_48e18_row5_col5, #T_48e18_row6_col6, #T_48e18_row7_col7, #T_48e18_row8_col8, #T_48e18_row9_col9, #T_48e18_row10_col10, #T_48e18_row11_col11, #T_48e18_row12_col12, #T_48e18_row13_col13, #T_48e18_row14_col14, #T_48e18_row15_col15, #T_48e18_row16_col16, #T_48e18_row16_col17, #T_48e18_row17_col16, #T_48e18_row17_col17, #T_48e18_row17_col18, #T_48e18_row18_col17, #T_48e18_row18_col18, #T_48e18_row18_col19, #T_48e18_row19_col18, #T_48e18_row19_col19, #T_48e18_row19_col20, #T_48e18_row20_col19, #T_48e18_row20_col20, #T_48e18_row20_col21, #T_48e18_row20_col22, #T_48e18_row21_col20, #T_48e18_row21_col21, #T_48e18_row21_col22, #T_48e18_row21_col23, #T_48e18_row21_col28, #T_48e18_row22_col21, #T_48e18_row22_col22, #T_48e18_row22_col23, #T_48e18_row23_col21, #T_48e18_row23_col22, #T_48e18_row23_col23, #T_48e18_row24_col24, #T_48e18_row25_col25, #T_48e18_row25_col27, #T_48e18_row26_col26, #T_48e18_row26_col29, #T_48e18_row27_col25, #T_48e18_row27_col27, #T_48e18_row27_col28, #T_48e18_row28_col21, #T_48e18_row28_col27, #T_48e18_row28_col28, #T_48e18_row29_col26, #T_48e18_row29_col29, #T_48e18_row30_col30, #T_48e18_row31_col31, #T_48e18_row32_col32, #T_48e18_row33_col33, #T_48e18_row34_col34 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_48e18_row0_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_48e18_row0_col2, #T_48e18_row1_col14, #T_48e18_row1_col15, #T_48e18_row2_col22, #T_48e18_row2_col28, #T_48e18_row13_col2, #T_48e18_row21_col0, #T_48e18_row22_col0, #T_48e18_row23_col0, #T_48e18_row28_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_48e18_row0_col3, #T_48e18_row1_col20, #T_48e18_row1_col25, #T_48e18_row3_col20, #T_48e18_row13_col3, #T_48e18_row13_col32, #T_48e18_row16_col2, #T_48e18_row16_col32, #T_48e18_row17_col2, #T_48e18_row17_col32, #T_48e18_row18_col2, #T_48e18_row18_col32, #T_48e18_row19_col2, #T_48e18_row20_col2, #T_48e18_row27_col32 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_48e18_row0_col4, #T_48e18_row4_col10, #T_48e18_row4_col16, #T_48e18_row4_col18, #T_48e18_row4_col19, #T_48e18_row22_col4, #T_48e18_row23_col4, #T_48e18_row33_col31 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_48e18_row0_col5, #T_48e18_row1_col9, #T_48e18_row2_col0, #T_48e18_row5_col33, #T_48e18_row11_col33, #T_48e18_row22_col5, #T_48e18_row23_col5, #T_48e18_row32_col1, #T_48e18_row32_col26 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_48e18_row0_col6, #T_48e18_row1_col11, #T_48e18_row5_col29, #T_48e18_row20_col33, #T_48e18_row23_col33 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_48e18_row0_col7, #T_48e18_row9_col15, #T_48e18_row12_col6, #T_48e18_row18_col8, #T_48e18_row21_col8, #T_48e18_row22_col8 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_48e18_row0_col8, #T_48e18_row8_col29, #T_48e18_row16_col8 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_48e18_row0_col9, #T_48e18_row5_col24, #T_48e18_row8_col30, #T_48e18_row16_col9, #T_48e18_row20_col10, #T_48e18_row22_col11, #T_48e18_row23_col11, #T_48e18_row24_col5, #T_48e18_row29_col6, #T_48e18_row31_col7, #T_48e18_row33_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_48e18_row0_col10, #T_48e18_row16_col10, #T_48e18_row16_col11, #T_48e18_row29_col31, #T_48e18_row31_col3, #T_48e18_row31_col4, #T_48e18_row33_col27 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_48e18_row0_col11, #T_48e18_row19_col24, #T_48e18_row31_col1, #T_48e18_row31_col16 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_48e18_row0_col12 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_48e18_row0_col13, #T_48e18_row0_col18, #T_48e18_row15_col3 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_48e18_row0_col14, #T_48e18_row0_col29, #T_48e18_row2_col8, #T_48e18_row14_col3, #T_48e18_row26_col32 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_48e18_row0_col15, #T_48e18_row11_col4, #T_48e18_row17_col3, #T_48e18_row27_col3, #T_48e18_row28_col3 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_48e18_row0_col16, #T_48e18_row0_col17, #T_48e18_row0_col25, #T_48e18_row2_col32, #T_48e18_row4_col9, #T_48e18_row5_col11, #T_48e18_row8_col1, #T_48e18_row10_col2, #T_48e18_row16_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_48e18_row0_col19, #T_48e18_row0_col27, #T_48e18_row3_col8, #T_48e18_row10_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_48e18_row0_col20, #T_48e18_row0_col28, #T_48e18_row1_col6, #T_48e18_row33_col30 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_48e18_row0_col21, #T_48e18_row0_col22, #T_48e18_row0_col23 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_48e18_row0_col24, #T_48e18_row6_col30, #T_48e18_row24_col18, #T_48e18_row32_col7, #T_48e18_row33_col1, #T_48e18_row33_col24 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_48e18_row0_col26, #T_48e18_row1_col32, #T_48e18_row3_col32, #T_48e18_row13_col1, #T_48e18_row18_col3, #T_48e18_row19_col3, #T_48e18_row20_col3, #T_48e18_row21_col3, #T_48e18_row22_col3, #T_48e18_row23_col3, #T_48e18_row25_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_48e18_row0_col30, #T_48e18_row4_col31, #T_48e18_row17_col10, #T_48e18_row31_col20 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_48e18_row0_col31, #T_48e18_row14_col9, #T_48e18_row23_col31, #T_48e18_row28_col24, #T_48e18_row31_col21, #T_48e18_row31_col22, #T_48e18_row32_col6, #T_48e18_row33_col4, #T_48e18_row33_col5, #T_48e18_row33_col6, #T_48e18_row34_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_48e18_row0_col32, #T_48e18_row1_col13, #T_48e18_row1_col16, #T_48e18_row1_col17, #T_48e18_row1_col18, #T_48e18_row2_col23, #T_48e18_row3_col15, #T_48e18_row3_col16, #T_48e18_row3_col17, #T_48e18_row3_col18, #T_48e18_row14_col0, #T_48e18_row16_col4, #T_48e18_row17_col4, #T_48e18_row18_col0, #T_48e18_row19_col0, #T_48e18_row20_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_48e18_row0_col33, #T_48e18_row9_col22, #T_48e18_row9_col23, #T_48e18_row9_col25, #T_48e18_row34_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_48e18_row0_col34, #T_48e18_row29_col2, #T_48e18_row32_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_48e18_row1_col0, #T_48e18_row1_col19, #T_48e18_row3_col19, #T_48e18_row9_col1, #T_48e18_row14_col32, #T_48e18_row15_col0, #T_48e18_row16_col0, #T_48e18_row17_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_48e18_row1_col2, #T_48e18_row3_col5, #T_48e18_row21_col34, #T_48e18_row25_col34, #T_48e18_row34_col26 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_48e18_row1_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_48e18_row1_col4, #T_48e18_row2_col5, #T_48e18_row4_col1, #T_48e18_row9_col5, #T_48e18_row11_col7 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_48e18_row1_col5, #T_48e18_row8_col3, #T_48e18_row30_col31 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_48e18_row1_col7, #T_48e18_row2_col27, #T_48e18_row4_col32, #T_48e18_row11_col2, #T_48e18_row25_col32 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_48e18_row1_col8, #T_48e18_row2_col15, #T_48e18_row2_col17, #T_48e18_row12_col2, #T_48e18_row26_col0, #T_48e18_row29_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_48e18_row1_col10, #T_48e18_row1_col33, #T_48e18_row6_col14, #T_48e18_row9_col19, #T_48e18_row20_col6, #T_48e18_row32_col18 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_48e18_row1_col12, #T_48e18_row4_col14, #T_48e18_row5_col17, #T_48e18_row8_col32, #T_48e18_row9_col32, #T_48e18_row11_col32, #T_48e18_row12_col4 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_48e18_row1_col21, #T_48e18_row3_col28, #T_48e18_row18_col1, #T_48e18_row19_col1, #T_48e18_row20_col1, #T_48e18_row21_col1, #T_48e18_row22_col1, #T_48e18_row23_col1, #T_48e18_row23_col2, #T_48e18_row25_col2, #T_48e18_row27_col1, #T_48e18_row28_col32, #T_48e18_row29_col32 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_48e18_row1_col22, #T_48e1

# %%
from sklearn.feature_selection import mutual_info_regression, SequentialFeatureSelector, RFE

# %%
mutual_reg = mutual_info_regression(train_feat_matrix_scaled, train_y, random_state=843824)
mutual_reg
# Out:
# array([0.07831248, 0.02359383, 0.06008108, 0.05044436, 0.02978004,
#        0.0304089 , 0.01906042, 0.01563625, 0.        , 0.00089026,
#        0.        , 0.        , 0.64048197, 0.68704088, 0.68718031,
#        0.70861652, 0.68893111, 0.71649394, 0.73275963, 0.68246109,
#        0.63945206, 0.61063313, 0.61587518, 0.60565665, 0.02142666,
#        0.57930336, 0.52289205, 0.57233234, 0.6638553 , 0.54410568,
#        0.06865039, 0.01785002, 0.0733639 , 0.10109387])

# %%
train_feat_df.columns[np.argsort(mutual_reg, axis=0)]
# Out:
# Index(['amp_ratio_09.0', 'amp_ratio_11.0', 'amp_ratio_12.0', 'amp_ratio_10.0',
#        'amp_ratio_08.0', 'source_depth_km', 'amp_ratio_07.0',
#        'signal_dominant_frequency', 'amp_ratio_02.0', 'amp_ratio_05.0',
#        'amp_ratio_06.0', 'amp_ratio_04.0', 'amp_ratio_03.0',
#        'source_receiver_distance_logkm', 'sin_receiver_back_azimuth',
#        'amp_ratio_01.0', 'receiver_back_azimuth', 'noise_max_amplitude',
#        'noise_variance', 'signal_max_amplitude', 'signal_dominant_amplitude',
#        'amp_12.0', 'amp_10.0', 'amp_11.0', 'amp_09.0', 'amp_01.0',
#        'signal_variance', 'amp_08.0', 'amp_02.0', 'amp_03.0', 'amp_05.0',
#        'amp_04.0', 'amp_06.0', 'amp_07.0'],
#       dtype='object')

# %%
# Make cross validation splits across evids

from sklearn.model_selection import KFold
evids = train_df.event_identifier.unique()
kf = KFold(n_splits=5, shuffle=True, random_state=843824)
folds = []
for train_index, test_index in kf.split(evids):
    # Get the evids corresponding to the split indicies
    fold_train_evids = evids[train_index]
    fold_test_evids = evids[test_index]
    # Get rows of training dataset that correspond to split evids
    fold_train_inds = np.where(np.isin(train_df.event_identifier, fold_train_evids))[0]
    fold_test_inds = np.where(np.isin(train_df.event_identifier, fold_test_evids))[0]
    
    folds.append((fold_train_inds, fold_test_inds))

# %%
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, cross_validate
from sklearn.metrics import r2_score

# %% [markdown]
# ## RFE
#
# from RFECV, know that most of the gain comes from 5-10 features. Use RFE to find 8 "best" features

# %%
# CV performace with these all features in linear model
svr = SVR(C=1.0, epsilon=0.1, kernel="linear")
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:, :-1], train_y, cv=folds, scoring="r2")
# Out:
# {'fit_time': array([0.76021838, 0.65208149, 0.70170712, 0.68397093, 0.70959592]),
#  'score_time': array([0.00708318, 0.00572276, 0.00562739, 0.0057683 , 0.00618291]),
#  'test_score': array([0.88484374, 0.87572702, 0.79951987, 0.90572202, 0.85228464])}

# %%
train_feat_df.columns[:-1]
# Out:
# Index(['amp_ratio_01.0', 'amp_ratio_02.0', 'amp_ratio_03.0', 'amp_ratio_04.0',
#        'amp_ratio_05.0', 'amp_ratio_06.0', 'amp_ratio_07.0', 'amp_ratio_08.0',
#        'amp_ratio_09.0', 'amp_ratio_10.0', 'amp_ratio_11.0', 'amp_ratio_12.0',
#        'amp_01.0', 'amp_02.0', 'amp_03.0', 'amp_04.0', 'amp_05.0', 'amp_06.0',
#        'amp_07.0', 'amp_08.0', 'amp_09.0', 'amp_10.0', 'amp_11.0', 'amp_12.0',
#        'signal_dominant_frequency', 'signal_dominant_amplitude',
#        'noise_max_amplitude', 'signal_max_amplitude', 'signal_variance',
#        'noise_variance', 'source_receiver_distance_logkm', 'source_depth_km',
#        'sin_receiver_back_azimuth'],
#       dtype='object')

# %%
# Find best features for whole training dataset
estimator = SVR(kernel="linear")
selector = RFE(estimator, n_features_to_select=8, step=1)
selector = selector.fit(train_feat_matrix_scaled[:, :-1], train_y)

train_feat_df.columns[:-1][selector.support_]
# Out:
# Index(['amp_ratio_11.0', 'amp_02.0', 'amp_03.0', 'amp_05.0', 'amp_07.0',
#        'noise_max_amplitude', 'noise_variance',
#        'source_receiver_distance_logkm'],
#       dtype='object')

# %%
# Sort features by importance - first 8 are in no particular order
train_feat_df.columns[:-1][np.argsort(selector.ranking_)]
# Out:
# Index(['amp_05.0', 'source_receiver_distance_logkm', 'noise_variance',
#        'noise_max_amplitude', 'amp_ratio_11.0', 'amp_07.0', 'amp_03.0',
#        'amp_02.0', 'amp_ratio_10.0', 'amp_ratio_09.0',
#        'signal_dominant_amplitude', 'signal_variance', 'amp_12.0', 'amp_10.0',
#        'sin_receiver_back_azimuth', 'amp_08.0', 'amp_01.0', 'amp_11.0',
#        'signal_max_amplitude', 'amp_ratio_07.0', 'amp_ratio_01.0', 'amp_06.0',
#        'amp_ratio_06.0', 'source_depth_km', 'amp_ratio_05.0', 'amp_ratio_04.0',
#        'amp_04.0', 'amp_ratio_03.0', 'amp_ratio_02.0', 'amp_ratio_08.0',
#        'signal_dominant_frequency', 'amp_ratio_12.0', 'amp_09.0'],
#       dtype='object')

# %%
# Training performace with these 8 features in the linear model 
r2_score(selector.predict(train_feat_matrix_scaled[:, :-1]), train_y)
# Out:
# 0.8464475996464265

# %%
# CV performace with these 8 features in non-linear model
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:, :-1][:, selector.support_], train_y, cv=folds, scoring="r2")
# Out:
# {'fit_time': array([0.02939987, 0.02880168, 0.02670908, 0.02834296, 0.02610636]),
#  'score_time': array([0.00419188, 0.00400329, 0.00415301, 0.00419092, 0.00394654]),
#  'test_score': array([0.90712938, 0.84787403, 0.89426513, 0.89729535, 0.86353425])}

# %%
# Get best RFE features for various folds and evaluate 
for fold in folds:
    # Pipeline for choosing features for fold
    estimator = SVR(kernel="linear")
    selector = RFE(estimator, n_features_to_select=8, step=1)
    pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('selector', selector)])
    
    # Fold data - exclude receiver_back_azimuth since linear model
    cv_train_X = train_feat_matrix_unscaled[fold[0], :-1]
    cv_train_y = train_y[fold[0]]
    cv_test_X = train_feat_matrix_unscaled[fold[1], :-1]
    cv_test_y = train_y[fold[1]]
    
    # Fit selector to fold training data
    s = pipeline.fit(cv_train_X, cv_train_y)
    # Make predictions on the fold test data
    preds = s.predict(cv_test_X)
    # Get the features for this model
    support = s.named_steps.selector.support_
    # Print the features
    print(train_feat_df.columns[:-1][support])
    # Print the test R^2 score
    print("Linear performance:", r2_score(cv_test_y, preds))
    
    # Use this features in a non-linear model. Cross validate over all the folds
    svr = SVR(C=1.0, epsilon=0.2)
    nl_pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
    rbf_cv = cross_validate(nl_pipeline, train_feat_matrix_unscaled[:, :-1][:, support],
                         train_y, cv=folds, scoring="r2")["test_score"]
    print(rbf_cv)
    print(np.mean(rbf_cv))
# Out:
# Index(['amp_02.0', 'amp_06.0', 'amp_07.0', 'amp_09.0', 'amp_10.0', 'amp_12.0',
#        'noise_variance', 'source_receiver_distance_logkm'],
#       dtype='object')
# Linear performance: 0.8847563381414918
# [0.9088676  0.85409926 0.89818383 0.90046359 0.86251446]
# 0.8848257467386598
# Index(['amp_ratio_10.0', 'amp_ratio_11.0', 'amp_02.0', 'amp_07.0',
#        'signal_dominant_amplitude', 'signal_variance', 'noise_variance',
#        'source_receiver_distance_logkm'],
#       dtype='object')
# Linear performance: 0.858997437311229
# [0.90460911 0.84744019 0.89571364 0.89277181 0.86339478]
# 0.8807859061961247
# Index(['amp_02.0', 'amp_03.0', 'amp_05.0', 'amp_07.0', 'amp_09.0', 'amp_12.0',
#        'noise_variance', 'source_receiver_distance_logkm'],
#       dtype='object')
# Linear performance: 0.7888742379942472
# [0.91089015 0.85564142 0.89856361 0.9014321  0.86465875]
# 0.886237205286133
# Index(['amp_ratio_10.0', 'amp_ratio_11.0', 'amp_02.0', 'amp_03.0', 'amp_05.0',
#        'amp_07.0', 'noise_variance', 'source_receiver_distance_logkm'],
#       dtype='object')
# Linear performance: 0.8969398688152352
# [0.90384369 0.846894   0.89346886 0.89528784 0.8596569 ]
# 0.8798302566952309
# Index(['amp_02.0', 'amp_04.0', 'amp_05.0', 'amp_07.0',
#        'signal_dominant_amplitude', 'signal_variance', 'noise_variance',
#        'source_receiver_distance_logkm'],
#       dtype='object')
# Linear performance: 0.8270389281874033
# [0.91235093 0.85217569 0.89920169 0.90439656 0.86873586]
# 0.8873721471688771

# %% [markdown]
# ## Sequential Feature Selection.
# Forward selection until change in score is less than 1e-4 or reach half of the features. Slightly better CV performace with 13 features than 46 for non-linear SVR. Pretty comparable performace between the 13 and 46 features in linear SVR.

# %%
no_sin_ba_feat_inds = np.delete(np.arange(train_feat_matrix_unscaled.shape[1]), -2)

# %%
train_feat_df.columns[no_sin_ba_feat_inds]
# Out:
# Index(['amp_ratio_01.0', 'amp_ratio_02.0', 'amp_ratio_03.0', 'amp_ratio_04.0',
#        'amp_ratio_05.0', 'amp_ratio_06.0', 'amp_ratio_07.0', 'amp_ratio_08.0',
#        'amp_ratio_09.0', 'amp_ratio_10.0', 'amp_ratio_11.0', 'amp_ratio_12.0',
#        'amp_01.0', 'amp_02.0', 'amp_03.0', 'amp_04.0', 'amp_05.0', 'amp_06.0',
#        'amp_07.0', 'amp_08.0', 'amp_09.0', 'amp_10.0', 'amp_11.0', 'amp_12.0',
#        'signal_dominant_frequency', 'signal_dominant_amplitude',
#        'noise_max_amplitude', 'signal_max_amplitude', 'signal_variance',
#        'noise_variance', 'source_receiver_distance_logkm', 'source_depth_km',
#        'receiver_back_azimuth'],
#       dtype='object')

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
sfs = SequentialFeatureSelector(pipeline, n_features_to_select="auto", tol=1e-3, scoring="r2", 
                                cv=folds, n_jobs=3).fit(train_feat_matrix_unscaled[:,no_sin_ba_feat_inds], train_y)

sfs.get_feature_names_out(train_feat_df.columns[no_sin_ba_feat_inds])
# Out:
# array(['amp_02.0', 'amp_10.0', 'noise_max_amplitude',
#        'source_receiver_distance_logkm', 'receiver_back_azimuth'],
#       dtype=object)

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:,no_sin_ba_feat_inds][:, sfs.get_support()], train_y, cv=folds)
# Out:
# {'fit_time': array([0.04236579, 0.04246902, 0.03082204, 0.02839231, 0.02993655]),
#  'score_time': array([0.00599504, 0.00561213, 0.00370836, 0.00380135, 0.00384021]),
#  'test_score': array([0.9131064 , 0.86815814, 0.90631056, 0.92209507, 0.89997278])}

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
sfs = SequentialFeatureSelector(pipeline, n_features_to_select="auto", tol=1e-4, scoring="r2", 
                                cv=folds, n_jobs=3).fit(train_feat_matrix_unscaled[:,no_sin_ba_feat_inds], train_y)

sfs.get_feature_names_out(train_feat_df.columns[no_sin_ba_feat_inds])
# Out:
# array(['amp_02.0', 'amp_04.0', 'amp_08.0', 'amp_10.0',
#        'noise_max_amplitude', 'source_receiver_distance_logkm',
#        'receiver_back_azimuth'], dtype=object)

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:,no_sin_ba_feat_inds][:, sfs.get_support()], train_y, cv=folds)
# Out:
# {'fit_time': array([0.02393985, 0.02304053, 0.02378297, 0.02546692, 0.02505589]),
#  'score_time': array([0.00345206, 0.00375915, 0.00351739, 0.00351715, 0.00363994]),
#  'test_score': array([0.91475365, 0.87221264, 0.91071437, 0.9236662 , 0.89733333])}

# %%
# Performance when using all features
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:, no_sin_ba_feat_inds], train_y, cv=folds)
# Out:
# {'fit_time': array([0.04098511, 0.03850174, 0.03878403, 0.03727508, 0.0383296 ]),
#  'score_time': array([0.00661588, 0.00652671, 0.00631499, 0.0060966 , 0.00635839]),
#  'test_score': array([0.89710784, 0.8531267 , 0.89419054, 0.90517038, 0.88310399])}

# %% [markdown]
# ## Sequential Feature Selection Linear

# %%
svr = SVR(C=1.0, epsilon=0.2, kernel="linear")
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
sfs = SequentialFeatureSelector(pipeline, n_features_to_select="auto", tol=1e-3, scoring="r2", 
                                cv=folds, n_jobs=3).fit(train_feat_matrix_unscaled[:,:-1], train_y)

sfs.get_feature_names_out(train_feat_df.columns[:-1])
# Out:
# array(['amp_ratio_02.0', 'amp_02.0', 'signal_dominant_amplitude',
#        'noise_max_amplitude', 'source_receiver_distance_logkm',
#        'source_depth_km', 'sin_receiver_back_azimuth'], dtype=object)

# %%
svr = SVR(C=1.0, epsilon=0.2, kernel="linear")
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
all_feats_rbf_cv = cross_validate(pipeline, train_feat_matrix_unscaled[:,no_sin_ba_feat_inds][:, sfs.get_support()], train_y, cv=folds)
print(all_feats_rbf_cv["test_score"])
print(np.mean(all_feats_rbf_cv['test_score']))
# Out:
# [0.8805131  0.8751788  0.8183848  0.90065838 0.84888243]
# 0.8647235033035509

# %% [markdown]
# # Go more in-depth into the effect of the more important features

# %%
selected_features_sr = ['amp_02.0', 'amp_04.0', 'amp_07.0', 'amp_10.0', 'amp_ratio_01.0',
                       'signal_dominant_amplitude', 'signal_variance', 'noise_variance', 
                       'source_receiver_distance_logkm', 'noise_max_amplitude', 'receiver_back_azimuth', 
                        'source_depth_km', 'signal_max_amplitude']

fewer_features_sr = ['amp_02.0','signal_max_amplitude', 'signal_variance', 'noise_variance', 
                       'source_receiver_distance_logkm', 'noise_max_amplitude', 'receiver_back_azimuth', 
                     'source_depth_km']

# %%
def svr_cv(X, y, folds, kernel="rbf", C=1.0, epsilon=0.2, degree=3):
    svr = SVR(C=C, epsilon=epsilon, kernel=kernel, degree=degree)
    pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
    cv_scores = cross_validate(pipeline, X, y, scoring="r2", cv=folds)["test_score"]
    
    return cv_scores

# %%
def seq_feature_importance(selected_features, train_feat_df_unscaled, starting_features=None, kernel="rbf"):
    feat_selection = np.copy(selected_features)
    r2_maxs = []
    r2_mins = []
    r2_means = []
    
    best_features = []
    
    plot_start_ind = 1
    if starting_features is not None:
        best_features = starting_features
        train_X = train_feat_df_unscaled[best_features].values
        cv_scores = svr_cv(train_X, train_y, folds, kernel=kernel)
        mean_cv = np.mean(cv_scores)
        print(best_features, mean_cv)
        r2_means.append(mean_cv)
        r2_mins.append(mean_cv)
        r2_maxs.append(mean_cv)
        plot_start_ind = 0

    for it in range(len(selected_features)):
        print("iteration", it)
        print(best_features)

        it_r2_vals = []
    #     best_feat_ind = -1

        for feature_ind in range(len(feat_selection)):
            features = [feat_selection[feature_ind]]
            if len(best_features) == 0:
                train_X = train_feat_df_unscaled[features].values.reshape(-1, 1)
            else:
                features = np.concatenate([best_features, features])
                train_X = train_feat_df_unscaled[features].values

            cv_scores = svr_cv(train_X, train_y, folds, kernel=kernel)

            mean_cv = np.mean(cv_scores)
            print(features[-1], mean_cv)
    #         if mean_cv > max_r2:
    #             best_feat_ind = feature_ind
    #             max_r2 = mean_cv

            it_r2_vals.append(mean_cv)

        best_feat_ind = np.argmax(it_r2_vals)
        best_features.append(feat_selection[best_feat_ind])
        r2_means.append(np.mean(it_r2_vals))
        r2_mins.append(np.min(it_r2_vals))
        r2_maxs.append(np.max(it_r2_vals))

        feat_selection = np.delete(feat_selection, best_feat_ind)

    
    n_features = np.arange(plot_start_ind, len(selected_features)+1)
    plt.plot(n_features, r2_means, linestyle="--", color="k", label="mean")
    plt.plot(n_features, r2_mins, color="k", label="min")
    plt.fill_between(n_features, r2_maxs, r2_mins, color="gray")
    plt.plot(n_features, r2_maxs, marker="x", color="r", label="max")
    plt.xticks(n_features) #, labels=n_features[::-1]) #, labels=best_features, rotation=45);
    plt.grid()
    plt.xlabel("N Features") #("N Features to Choose From");
    plt.ylabel(r"Mean $R^2$ of 5-fold CV");
    plt.legend();
    
    return best_features

# %%
best_features_sr = seq_feature_importance(selected_features_sr, train_feat_df_unscaled)
best_features_sr
# Out:
# iteration 0
# []
# amp_02.0 0.7069855064637622
# amp_04.0 0.6967314888762102
# amp_07.0 0.6642279588808512
# amp_10.0 0.6092125254915504
# amp_ratio_01.0 0.11343843515542029
# signal_dominant_amplitude 0.6090317143045709
# signal_variance 0.6263468682188215
# noise_variance 0.5868620666440278
# source_receiver_distance_logkm 0.02585632529485098
# noise_max_amplitude 0.562844438608477
# receiver_back_azimuth 0.045781021380562524
# source_depth_km 0.01342851133170191
# signal_max_amplitude 0.5903232958985141
# iteration 1
# ['amp_02.0']
# amp_04.0 0.7096626068178042
# amp_07.0 0.7063573196297487
# amp_10.0 0.7113471148857062
# amp_ratio_01.0 0.7090865413028549
# signal_dominant_amplitude 0.707897293132244
# signal_variance 0.7124110110481601
# noise_variance 0.7124768795965806
# source_receiver_distance_logkm 0.8658884072633641
# noise_max_amplitude 0.7139567946343544
# receiver_back_azimuth 0.7784264000889752
# source_depth_km 0.7566973336255591
# signal_max_amplitude 0.7143639225545778
# iteration 2
# ['amp_02.0', 'source_receiver_distance_logkm']
# amp_04.0 0.8741680774680335
# amp_07.0 0.8805052591569267
# amp_10.0 0.8838404785497133
# amp_ratio_01.0 0.8555423537233239
# signal_dominant_amplitude 0.8792495439844693
# signal_variance 0.8821832183293769
# noise_variance 0.8782578291812351
# noise_max_amplitude 0.8773632236583925
# receiver_back_azimuth 0.8806841582495674
# source_depth_km 0.862132756004504
# signal_max_amplitude 0.8789148681144798
# iteration 3
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0']
# amp_04.0 0.883869449373534
# amp_07.0 0.8836373265015757
# amp_ratio_01.0 0.8743900217409102
# signal_dominant_amplitude 0.8842600033985948
# signal_variance 0.8840685465807516
# noise_variance 0.8837980122989009
# noise_max_amplitude 0.8837895789400043
# receiver_back_azimuth 0.9009117941511207
# source_depth_km 0.8808278633991969
# signal_max_amplitude 0.8835780354217455
# iteration 4
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth']
# amp_04.0 0.9018584972974135
# amp_07.0 0.9005784207790217
# amp_ratio_01.0 0.8955556055066023
# signal_dominant_amplitude 0.9001068986874026
# signal_variance 0.901176806835927
# noise_variance 0.9019176149550912
# noise_max_amplitude 0.901928590357113
# source_depth_km 0.8992558421660155
# signal_max_amplitude 0.900319471928999
# iteration 5
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'noise_max_amplitude']
# amp_04.0 0.9028968049623476
# amp_07.0 0.902124248886534
# amp_ratio_01.0 0.8966249292212293
# signal_dominant_amplitude 0.9005869461759911
# signal_variance 0.9015916911946421
# noise_variance 0.901780759013648
# source_depth_km 0.8995643960229882
# signal_max_amplitude 0.9008985136391671
# iteration 6
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'noise_max_amplitude', 'amp_04.0']
# amp_07.0 0.9036446661250663
# amp_ratio_01.0 0.8976852117652996
# signal_dominant_amplitude 0.9024399807487049
# signal_variance 0.9029382581887464
# noise_variance 0.9029584432790119
# source_depth_km 0.9008997826685329
# signal_max_amplitude 0.9022857968094822
# iteration 7
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'noise_max_amplitude', 'amp_04.0', 'amp_07.0']
# amp_ratio_01.0 0.9001964478375211
# signal_dominant_amplitude 0.9030011543434509
# signal_variance 0.9036373228264818
# noise_variance 0.9037808538241883
# source_depth_km 0.9017143850764798
# signal_max_amplitude 0.9031617475759491
# iteration 8
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'noise_max_amplitude', 'amp_04.0', 'amp_07.0', 'noise_variance']
# amp_ratio_01.0 0.901018990124052
# signal_dominant_amplitude 0.9032006581171114
# signal_variance 0.903633957132523
# source_depth_km 0.9015309555657947
# signal_max_amplitude 0.9033813440989243
# iteration 9
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'noise_max_amplitude', 'amp_04.0', 'amp_07.0', 'noise_variance', 'signal_variance']
# amp_ratio_01.0 0.9016812211653559
# signal_dominant_amplitude 0.90333543002211
# source_depth_km 0.9019434074903743
# signal_max_amplitude 0.903538324897266
# iteration 10
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'noise_max_amplitude', 'amp_04.0', 'amp_07.0', 'noise_variance', 'signal_variance', 'signal_max_amplitude']
# amp_ratio_01.0 0.9020147586417039
# signal_dominant_amplitude 0.9034783311723069
# source_depth_km 0.9024621951695506
# iteration 11
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'noise_max_amplitude', 'amp_04.0', 'amp_07.0', 'noise_variance', 'signal_variance', 'signal_max_amplitude', 'signal_dominant_amplitude']
# amp_ratio_01.0 0.9018903662153649
# source_depth_km 0.902893278847197
# iteration 12
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'noise_max_amplitude', 'amp_04.0', 'amp_07.0', 'noise_variance', 'signal_variance', 'signal_max_amplitude', 'signal_dominant_amplitude', 'source_depth_km']
# amp_ratio_01.0 0.8997238911216773
# ['amp_02.0',
#  'source_receiver_distance_logkm',
#  'amp_10.0',
#  'receiver_back_azimuth',
#  'noise_max_amplitude',
#  'amp_04.0',
#  'amp_07.0',
#  'noise_variance',
#  'signal_variance',
#  'signal_max_amplitude',
#  'signal_dominant_amplitude',
#  'source_depth_km',
#  'amp_ratio_01.0']

# %%
# All selected features with sr distance and back azimuth
selected_feat_sr_cv = svr_cv(train_feat_df_unscaled[selected_features_sr], train_y, folds)
print(selected_feat_sr_cv)
print(np.mean(selected_feat_sr_cv))
# Out:
# [0.91311697 0.86831817 0.90584658 0.9200343  0.89130344]
# 0.8997238911216773

# %%
# Top 4 selected features with sr distance and back azimuth
top_feat_sr_cv = svr_cv(train_feat_df_unscaled[best_features_sr[0:4]], train_y, folds)
print(top_feat_sr_cv )
print(np.mean(top_feat_sr_cv))
# Out:
# [0.91457573 0.87393254 0.90269891 0.92115162 0.89220016]
# 0.9009117941511207

# %%
best_fewer_features_sr = seq_feature_importance(fewer_features_sr, train_feat_df_unscaled)
best_fewer_features_sr
# Out:
# iteration 0
# []
# amp_02.0 0.7069855064637622
# signal_max_amplitude 0.5903232958985141
# signal_variance 0.6263468682188215
# noise_variance 0.5868620666440278
# source_receiver_distance_logkm 0.02585632529485098
# noise_max_amplitude 0.562844438608477
# receiver_back_azimuth 0.045781021380562524
# source_depth_km 0.01342851133170191
# iteration 1
# ['amp_02.0']
# signal_max_amplitude 0.7143639225545778
# signal_variance 0.7124110110481601
# noise_variance 0.7124768795965806
# source_receiver_distance_logkm 0.8658884072633641
# noise_max_amplitude 0.7139567946343544
# receiver_back_azimuth 0.7784264000889752
# source_depth_km 0.7566973336255591
# iteration 2
# ['amp_02.0', 'source_receiver_distance_logkm']
# signal_max_amplitude 0.8789148681144798
# signal_variance 0.8821832183293769
# noise_variance 0.8782578291812351
# noise_max_amplitude 0.8773632236583925
# receiver_back_azimuth 0.8806841582495674
# source_depth_km 0.862132756004504
# iteration 3
# ['amp_02.0', 'source_receiver_distance_logkm', 'signal_variance']
# signal_max_amplitude 0.8827410804065872
# noise_variance 0.883431475563853
# noise_max_amplitude 0.883262298885996
# receiver_back_azimuth 0.9007766397303513
# source_depth_km 0.8799701314153637
# iteration 4
# ['amp_02.0', 'source_receiver_distance_logkm', 'signal_variance', 'receiver_back_azimuth']
# signal_max_amplitude 0.900325306955183
# noise_variance 0.9019016506735238
# noise_max_amplitude 0.9019803237718215
# source_depth_km 0.8984688217760359
# iteration 5
# ['amp_02.0', 'source_receiver_distance_logkm', 'signal_variance', 'receiver_back_azimuth', 'noise_max_amplitude']
# signal_max_amplitude 0.900851257511561
# noise_variance 0.9017934084122855
# source_depth_km 0.8996209771973698
# iteration 6
# ['amp_02.0', 'source_receiver_distance_logkm', 'signal_variance', 'receiver_back_azimuth', 'noise_max_amplitude', 'noise_variance']
# signal_max_amplitude 0.9014899063425684
# source_depth_km 0.8988157149128273
# iteration 7
# ['amp_02.0', 'source_receiver_distance_logkm', 'signal_variance', 'receiver_back_azimuth', 'noise_max_amplitude', 'noise_variance', 'signal_max_amplitude']
# source_depth_km 0.8996519241791889
# ['amp_02.0',
#  'source_receiver_distance_logkm',
#  'signal_variance',
#  'receiver_back_azimuth',
#  'noise_max_amplitude',
#  'noise_variance',
#  'signal_max_amplitude',
#  'source_depth_km']

# %%
# All fewer features
fewer_feat_sr_cv = svr_cv(train_feat_df_unscaled[fewer_features_sr], train_y, folds)
print(fewer_feat_sr_cv)
print(np.mean(fewer_feat_sr_cv))
# Out:
# [0.91221459 0.86378107 0.90288415 0.92437372 0.8950061 ]
# 0.8996519241791889

# %%
# Top 4 fewer features
top_fewer_feat_sr_cv = svr_cv(train_feat_df_unscaled[best_fewer_features_sr[0:4]], train_y, folds)
print(top_fewer_feat_sr_cv)
print(np.mean(top_fewer_feat_sr_cv))
# Out:
# [0.91408192 0.87079242 0.9031196  0.92274083 0.89314843]
# 0.9007766397303513

# %%
selected_feat_df = train_feat_df.copy()[selected_features_sr]
selected_feat_df.loc[:, "magnitude"] = train_y
corr = selected_feat_df.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_a64e5_row0_col0, #T_a64e5_row1_col1, #T_a64e5_row2_col2, #T_a64e5_row3_col3, #T_a64e5_row3_col6, #T_a64e5_row4_col4, #T_a64e5_row5_col5, #T_a64e5_row5_col12, #T_a64e5_row6_col3, #T_a64e5_row6_col6, #T_a64e5_row6_col12, #T_a64e5_row7_col7, #T_a64e5_row7_col9, #T_a64e5_row8_col8, #T_a64e5_row9_col7, #T_a64e5_row9_col9, #T_a64e5_row10_col10, #T_a64e5_row11_col11, #T_a64e5_row12_col5, #T_a64e5_row12_col6, #T_a64e5_row12_col12, #T_a64e5_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a64e5_row0_col1, #T_a64e5_row1_col0, #T_a64e5_row2_col5, #T_a64e5_row2_col12, #T_a64e5_row5_col2 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_a64e5_row0_col2, #T_a64e5_row6_col7, #T_a64e5_row7_col6 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_a64e5_row0_col3, #T_a64e5_row0_col5, #T_a64e5_row0_col12, #T_a64e5_row1_col7, #T_a64e5_row2_col9, #T_a64e5_row3_col0, #T_a64e5_row5_col0, #T_a64e5_row7_col2 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_a64e5_row0_col4 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_a64e5_row0_col6, #T_a64e5_row1_col3, #T_a64e5_row1_col5, #T_a64e5_row2_col0, #T_a64e5_row3_col7, #T_a64e5_row3_col9, #T_a64e5_row5_col1, #T_a64e5_row6_col0, #T_a64e5_row6_col9, #T_a64e5_row7_col3, #T_a64e5_row9_col3, #T_a64e5_row9_col6 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_a64e5_row0_col7, #T_a64e5_row1_col9 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_a64e5_row0_col8, #T_a64e5_row10_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_a64e5_row0_col9, #T_a64e5_row7_col0, #T_a64e5_row9_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_a64e5_row0_col10, #T_a64e5_row1_col10, #T_a64e5_row2_col10, #T_a64e5_row12_col10 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a64e5_row0_col11, #T_a64e5_row1_col8, #T_a64e5_row4_col10 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_a64e5_row0_col13, #T_a64e5_row13_col6 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_a64e5_row1_col2, #T_a64e5_row1_col6, #T_a64e5_row2_col1, #T_a64e5_row12_col2 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_a64e5_row1_col4 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_a64e5_row1_col11, #T_a64e5_row2_col11, #T_a64e5_row10_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_a64e5_row1_col12, #T_a64e5_row3_col1, #T_a64e5_row5_col7, #T_a64e5_row7_col12, #T_a64e5_row9_col12, #T_a64e5_row12_col1, #T_a64e5_row12_col7, #T_a64e5_row12_col9 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_a64e5_row1_col13, #T_a64e5_row13_col3, #T_a64e5_row13_col5 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_a64e5_row2_col3, #T_a64e5_row2_col6, #T_a64e5_row3_col2, #T_a64e5_row3_col5, #T_a64e5_row3_col12, #T_a64e5_row5_col3, #T_a64e5_row6_col2, #T_a64e5_row12_col3 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_a64e5_row2_col4 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_a64e5_row2_col7, #T_a64e5_row5_col9, #T_a64e5_row7_col5, #T_a64e5_row9_col5 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_a64e5_row2_col8 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_a64e5_row2_col13, #T_a64e5_row13_col9 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_a64e5_row3_col4, #T_a64e5_row6_col4 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_a64e5_row3_col8 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a64e5_row3_col10, #T_a64e5_row8_col0, #T_a64e5_row8_col1, #T_a64e5_row8_col2, #T_a64e5_row8_col3, #T_a64e5_row8_col4, #T_a64e5_row8_col5, #T_a64e5_row8_col6, #T_a64e5_row8_col7, #T_a64e5_row8_col9, #T_a64e5_row8_col12, #T_a64e5_row9_col8, #T_a64e5_row9_col10, #T_a64e5_row9_col11, #T_a64e5_row10_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a64e5_row3_col11, #T_a64e5_row11_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_a64e5_row3_col13, #T_a64e5_row5_col13 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_a64e5_row4_col0, #T_a64e5_row4_col2, #T_a64e5_row10_col8 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_a64e5_row4_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_a64e5_row4_col3 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_a64e5_row4_col5 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_a64e5_row4_col6 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_a64e5_row4_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_a64e5_row4_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_a64e5_row4_col9 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_a64e5_row4_col11 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_a64e5_row4_col12 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_a64e5_row4_col13 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_a64e5_row5_col4, #T_a64e5_row12_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_a64e5_row5_col6, #T_a64e5_row6_col5 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_a64e5_row5_col8, #T_a64e5_row6_col8 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a64e5_row5_col10 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_a64e5_row5_col11 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_a64e5_row6_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_a64e5_row6_col10, #T_a64e5_row7_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_a64e5_row6_col11, #T_a64e5_row12_col11 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a64e5_row6_col13 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_a64e5_row7_col1, #T_a64e5_row9_col2, #T_a64e5_row12_col0 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_a64e5_row7_col4, #T_a64e5_row9_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_a64e5_row7_col10, #T_a64e5_row7_col11 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_a64e5_row7_col13, #T_a64e5_row12_col13 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_a64e5_row8_col10 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_a64e5_row8_col11 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_a64e5_row8_col13, #T_a64e5_row10_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_a64e5_row9_col0 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_a64e5_row9_col13 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_a64e5_row10_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_a64e5_row10_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_a64e5_row10_col5, #T_a64e5_row11_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_a64e5_row10_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_a64e5_row10_col7, #T_a64e5_row10_col9 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_a64e5_row10_col11 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_a64e5_row10_col12 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_a64e5_row11_col1, #T_a64e5_row11_col7, #T_a64e5_row11_col9 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a64e5_row11_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_a64e5_row11_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_a64e5_row11_col5 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_a64e5_row11_col6, #T_a64e5_row11_col13 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_a64e5_row11_col8 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_a64e5_row11_col10 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_a64e5_row11_col12 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_a64e5_row12_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_a64e5_row13_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_a64e5_row13_col1 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_a64e5_row13_col2 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_a64e5_row13_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_a64e5_row13_col7, #T_a64e5_row13_col12 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_a64e5_row13_col8 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_a64e5_row13_col10 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_a64e5_row13_c

# %% [markdown]
# ## Add required starting features

# %%
additional_features_sr = ['amp_02.0', 'amp_04.0', 'amp_07.0', 'amp_10.0', 'amp_ratio_01.0',
                       'signal_max_amplitude', 'signal_variance', 'noise_variance', 'noise_max_amplitude']
starting_features = ['source_receiver_distance_logkm','receiver_back_azimuth', 'source_depth_km']
best_features_with_start = seq_feature_importance(additional_features_sr, train_feat_df_unscaled,
                                                  starting_features=starting_features)
best_features_with_start
# Out:
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km'] 0.09066649345907526
# iteration 0
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km']
# amp_02.0 0.8813239776887933
# amp_04.0 0.8838319201164306
# amp_07.0 0.8838723771690644
# amp_10.0 0.876213585235584
# amp_ratio_01.0 0.25840988622617383
# signal_max_amplitude 0.8715081787835167
# signal_variance 0.890818349244098
# noise_variance 0.8608847774775047
# noise_max_amplitude 0.850332620861477
# iteration 1
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance']
# amp_02.0 0.8984688217760359
# amp_04.0 0.8967753244267378
# amp_07.0 0.8897819185786071
# amp_10.0 0.8902849507125824
# amp_ratio_01.0 0.8854087944250392
# signal_max_amplitude 0.8908234300068194
# noise_variance 0.8930852151634943
# noise_max_amplitude 0.8919748299869801
# iteration 2
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0']
# amp_04.0 0.8996089520087125
# amp_07.0 0.8995816775962158
# amp_10.0 0.8992477703879047
# amp_ratio_01.0 0.8937579025685631
# signal_max_amplitude 0.8987414613995279
# noise_variance 0.8995384434428996
# noise_max_amplitude 0.89962097719737
# iteration 3
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'noise_max_amplitude']
# amp_04.0 0.9008198595916873
# amp_07.0 0.900726883357677
# amp_10.0 0.9002158869297958
# amp_ratio_01.0 0.8957558876255589
# signal_max_amplitude 0.9001172942298954
# noise_variance 0.8988157149128272
# iteration 4
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'noise_max_amplitude', 'amp_04.0']
# amp_07.0 0.9017679654348851
# amp_10.0 0.9013542158020524
# amp_ratio_01.0 0.8963413353478508
# signal_max_amplitude 0.901216358871982
# noise_variance 0.9001753554771457
# iteration 5
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'noise_max_amplitude', 'amp_04.0', 'amp_07.0']
# amp_10.0 0.9022365036076044
# amp_ratio_01.0 0.8980466401587748
# signal_max_amplitude 0.9022274120474387
# noise_variance 0.9015306433392706
# iteration 6
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'noise_max_amplitude', 'amp_04.0', 'amp_07.0', 'amp_10.0']
# amp_ratio_01.0 0.8989779021007352
# signal_max_amplitude 0.9028501710535594
# noise_variance 0.9019434074903743
# iteration 7
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'noise_max_amplitude', 'amp_04.0', 'amp_07.0', 'amp_10.0', 'signal_max_amplitude']
# amp_ratio_01.0 0.8995474451081146
# noise_variance 0.9024621951695506
# iteration 8
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'noise_max_amplitude', 'amp_04.0', 'amp_07.0', 'amp_10.0', 'signal_max_amplitude', 'noise_variance']
# amp_ratio_01.0 0.899406115152862
# ['source_receiver_distance_logkm',
#  'receiver_back_azimuth',
#  'source_depth_km',
#  'signal_variance',
#  'amp_02.0',
#  'noise_max_amplitude',
#  'amp_04.0',
#  'amp_07.0',
#  'amp_10.0',
#  'signal_max_amplitude',
#  'noise_variance',
#  'amp_ratio_01.0']

# %%
np.mean(svr_cv(train_feat_df_unscaled[best_features_with_start[0:4]], train_y, folds))
# Out:
# 0.890818349244098

# %%
np.mean(svr_cv(train_feat_df_unscaled[best_features_with_start[0:5]], train_y, folds))
# Out:
# 0.8984688217760359

# %% [markdown]
# ## Require starting features - linear model

# %%
additional_features_sr = ['amp_02.0', 'amp_04.0', 'amp_07.0', 'amp_10.0', 'amp_ratio_01.0',
                       'signal_max_amplitude', 'signal_dominant_frequency', 'signal_variance', 
                          'noise_variance', 'noise_max_amplitude', 'signal_max_amplitude']
starting_features = ['source_receiver_distance_logkm','sin_receiver_back_azimuth', 'source_depth_km']
best_features_with_start_linear = seq_feature_importance(additional_features_sr, train_feat_df_unscaled,
                                                  starting_features=starting_features, kernel="linear")
best_features_with_start_linear
# Out:
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km'] 0.02405202805008997
# iteration 0
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km']
# amp_02.0 0.8441674445338254
# amp_04.0 0.8426152485298403
# amp_07.0 0.8341016223586386
# amp_10.0 0.8192739333452798
# amp_ratio_01.0 0.15980325421291217
# signal_max_amplitude 0.8255997899211351
# signal_dominant_frequency 0.09247541566603759
# signal_variance 0.8414763640344429
# noise_variance 0.8207696904042402
# noise_max_amplitude 0.8150408995172924
# signal_max_amplitude 0.8255997899211351
# iteration 1
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'amp_02.0']
# amp_04.0 0.8509254531936378
# amp_07.0 0.8564947388631439
# amp_10.0 0.8572385499756086
# amp_ratio_01.0 0.8466378651223403
# signal_max_amplitude 0.8595120100715882
# signal_dominant_frequency 0.8477711179899403
# signal_variance 0.8594523047575826
# noise_variance 0.8627820079883545
# noise_max_amplitude 0.8633315080564687
# signal_max_amplitude 0.8595120100715882
# iteration 2
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'amp_02.0', 'noise_max_amplitude']
# amp_04.0 0.8638638609249568
# amp_07.0 0.8650051277752497
# amp_10.0 0.8640396809630412
# amp_ratio_01.0 0.8644697932202374
# signal_max_amplitude 0.8657922732257667
# signal_dominant_frequency 0.863294208898689
# signal_variance 0.8651230078039939
# noise_variance 0.863042163714295
# signal_max_amplitude 0.8657922732257667
# iteration 3
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'amp_02.0', 'noise_max_amplitude', 'signal_max_amplitude']
# amp_04.0 0.866124674978345
# amp_07.0 0.8657771582162483
# amp_10.0 0.8653493263926105
# amp_ratio_01.0 0.8663103994291059
# signal_dominant_frequency 0.8662898953951255
# signal_variance 0.8654623197712393
# noise_variance 0.8656672034940849
# signal_max_amplitude 0.8657674258720199
# iteration 4
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'amp_02.0', 'noise_max_amplitude', 'signal_max_amplitude', 'amp_ratio_01.0']
# amp_04.0 0.8666377177175635
# amp_07.0 0.8667478855285744
# amp_10.0 0.8657461506963025
# signal_dominant_frequency 0.8667057339237294
# signal_variance 0.8650802414301365
# noise_variance 0.8661053989967226
# signal_max_amplitude 0.8662734248351507
# iteration 5
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'amp_02.0', 'noise_max_amplitude', 'signal_max_amplitude', 'amp_ratio_01.0', 'amp_07.0']
# amp_04.0 0.8668724075884352
# amp_10.0 0.8669794323609109
# signal_dominant_frequency 0.86678767435338
# signal_variance 0.8663556567911244
# noise_variance 0.8666146367600728
# signal_max_amplitude 0.8666673319157916
# iteration 6
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'amp_02.0', 'noise_max_amplitude', 'signal_max_amplitude', 'amp_ratio_01.0', 'amp_07.0', 'amp_10.0']
# amp_04.0 0.8670111277207928
# signal_dominant_frequency 0.8667940848246337
# signal_variance 0.8664083673703594
# noise_variance 0.8667881135347295
# signal_max_amplitude 0.8669833374128354
# iteration 7
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'amp_02.0', 'noise_max_amplitude', 'signal_max_amplitude', 'amp_ratio_01.0', 'amp_07.0', 'amp_10.0', 'amp_04.0']
# signal_dominant_frequency 0.8668221856194872
# signal_variance 0.8666878338888709
# noise_variance 0.8669376376982709
# signal_max_amplitude 0.867036611180696
# iteration 8
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'amp_02.0', 'noise_max_amplitude', 'signal_max_amplitude', 'amp_ratio_01.0', 'amp_07.0', 'amp_10.0', 'amp_04.0', 'signal_max_amplitude']
# signal_dominant_frequency 0.8667583045886982
# signal_variance 0.8667046092982573
# noise_variance 0.8669798178684927
# iteration 9
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'amp_02.0', 'noise_max_amplitude', 'signal_max_amplitude', 'amp_ratio_01.0', 'amp_07.0', 'amp_10.0', 'amp_04.0', 'signal_max_amplitude', 'noise_variance']
# signal_dominant_frequency 0.8668300764719635
# signal_variance 0.8664857520110392
# iteration 10
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'amp_02.0', 'noise_max_amplitude', 'signal_max_amplitude', 'amp_ratio_01.0', 'amp_07.0', 'amp_10.0', 'amp_04.0', 'signal_max_amplitude', 'noise_variance', 'signal_dominant_frequency']
# signal_variance 0.8663678136512285
# ['source_receiver_distance_logkm',
#  'sin_receiver_back_azimuth',
#  'source_depth_km',
#  'amp_02.0',
#  'noise_max_amplitude',
#  'signal_max_amplitude',
#  'amp_ratio_01.0',
#  'amp_07.0',
#  'amp_10.0',
#  'amp_04.0',
#  'signal_max_amplitude',
#  'noise_variance',
#  'signal_dominant_frequency',
#  'signal_variance']

# %%
np.mean(svr_cv(train_feat_df_unscaled[best_features_with_start_linear[0:4]], train_y, folds, kernel='linear'))
# Out:
# 0.8441674445338254

# %%
np.mean(svr_cv(train_feat_df_unscaled[best_features_with_start_linear[0:6]], train_y, folds, kernel="linear"))
# Out:
# 0.8657922732257667

# %%
linear_features = ['source_receiver_distance_logkm',
 'sin_receiver_back_azimuth',
 'source_depth_km',
 'amp_02.0',
 'noise_max_amplitude',
 'signal_max_amplitude',
 'signal_variance',
 'noise_variance', 
 'amp_ratio_01.0']

np.mean(svr_cv(train_feat_df_unscaled[linear_features], train_y, folds, kernel='linear', epsilon=0.1))
# Out:
# 0.8625813106275245

# %%
rbf_linear_features = ['source_receiver_distance_logkm',
 'receiver_back_azimuth',
 'source_depth_km',
 'amp_02.0',
 'noise_max_amplitude',
 'signal_max_amplitude',
 'signal_variance',
 'noise_variance', 
 'amp_ratio_01.0']

np.mean(svr_cv(train_feat_df_unscaled[rbf_linear_features], train_y, folds, epsilon=0.1))
# Out:
# 0.9041213771625044

# %%
linear_feat_df = train_feat_df.copy()[linear_features]
linear_feat_df.loc[:, "magnitude"] = train_y
corr = linear_feat_df.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_1ece6_row0_col0, #T_1ece6_row1_col1, #T_1ece6_row2_col2, #T_1ece6_row3_col3, #T_1ece6_row4_col4, #T_1ece6_row4_col7, #T_1ece6_row5_col5, #T_1ece6_row5_col6, #T_1ece6_row6_col5, #T_1ece6_row6_col6, #T_1ece6_row7_col4, #T_1ece6_row7_col7, #T_1ece6_row8_col8, #T_1ece6_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1ece6_row0_col1, #T_1ece6_row0_col3, #T_1ece6_row0_col4, #T_1ece6_row0_col5, #T_1ece6_row0_col6, #T_1ece6_row0_col7, #T_1ece6_row0_col8, #T_1ece6_row0_col9, #T_1ece6_row1_col2, #T_1ece6_row1_col9, #T_1ece6_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1ece6_row0_col2 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_1ece6_row1_col0, #T_1ece6_row2_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_1ece6_row1_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_1ece6_row1_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_1ece6_row1_col5 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_1ece6_row1_col6, #T_1ece6_row5_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_1ece6_row1_col7, #T_1ece6_row3_col1 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_1ece6_row1_col8 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_1ece6_row2_col0 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_1ece6_row2_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_1ece6_row2_col4, #T_1ece6_row2_col7 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_1ece6_row2_col5, #T_1ece6_row5_col2, #T_1ece6_row6_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_1ece6_row2_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_1ece6_row2_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_1ece6_row2_col9 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_1ece6_row3_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_1ece6_row3_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_1ece6_row3_col4, #T_1ece6_row7_col3 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_1ece6_row3_col5 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_1ece6_row3_col6, #T_1ece6_row4_col6, #T_1ece6_row6_col3, #T_1ece6_row6_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_1ece6_row3_col7 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_1ece6_row3_col8 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_1ece6_row3_col9, #T_1ece6_row9_col4 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_1ece6_row4_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_1ece6_row4_col2, #T_1ece6_row8_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_1ece6_row4_col3 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_1ece6_row4_col5, #T_1ece6_row5_col4, #T_1ece6_row5_col7, #T_1ece6_row7_col5 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_1ece6_row4_col8, #T_1ece6_row7_col8 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_1ece6_row4_col9 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_1ece6_row5_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_1ece6_row5_col3 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_1ece6_row5_col8 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_1ece6_row5_col9, #T_1ece6_row7_col9 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_1ece6_row6_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_1ece6_row6_col1, #T_1ece6_row7_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_1ece6_row6_col7, #T_1ece6_row7_col6 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_1ece6_row6_col8 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_1ece6_row6_col9 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_1ece6_row7_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_1ece6_row7_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_1ece6_row8_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_1ece6_row8_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_1ece6_row8_col3 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_1ece6_row8_col4 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_1ece6_row8_col5 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_1ece6_row8_col6 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_1ece6_row8_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_1ece6_row8_col9 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_1ece6_row9_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_1ece6_row9_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_1ece6_row9_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_1ece6_row9_col3 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_1ece6_row9_col5, #T_1ece6_row9_col7 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_1ece6_row9_col6 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_1ece6_row9_col8 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# </style>
# <table id="T_1ece6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ece6_level0_col0" class="col_heading level0 col0" >source_receiver_distance_logkm</th>
#       <th id="T_1ece6_level0_col1" class="col_heading level0 col1" >sin_receiver_back_azimuth</th>
#       <th id="T_1ece6_level0_col2" class="col_heading level0 col2" >source_depth_km</th>
#       <th id="T_1ece6_level0_col3" class="col_heading level0 col3" >amp_02.0</th>
#       <th id="T_1ece6_level0_col4" class="col_heading level0 col4" >noise_max_amplitude</th>
#       <th id="T_1ece6_level0_col5" class="col_heading level0 col5" >signal_max_amplitude</th>
#       <th id="T_1ece6_level0_col6" class="col_heading level0 col6" >signal_variance</th>
#       <th id="T_1ece6_level0_col7" class="col_heading level0 col7" >noise_variance</th>
#       <th id="T_1ece6_level0_col8" class="col_heading level0 col8" >amp_ratio_01.0</th>
#       <th id="T_1ece6_level0_col9" class="col_heading level0 col9" >magnitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ece6_level0_row0" class="row_heading level0 row0" >source_receiver_distance_logkm</th>
#       <td id="T_1ece6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1ece6_row0_col1" class="data row0 col1" >-0.437910</td>
#       <td id="T_1ece6_row0_col2" class="data row0 col2" >0.555717</td>
#       <td id="T_1ece6_row0_col3" class="data row0 col3" >-0.307769</td>
#       <td id="T_1ece6_row0_col4" class="data row0 col4" >-0.444907</td>
#       <td id="T_1ece6_row0_col5" class="data row0 col5" >-0.428955</td>
#       <td id="T_1ece6_row0_col6" class="data row0 col6" >-0.408622</td>
#       <td id="T_1ece6_row0_col7" class="data row0 col7" >-0.421466</td>
#       <td id="T_1ece6_row0_col8" class="data row0 col8" >-0.213702</td>
#       <td id="T_1ece6_row0_col9" class="data row0 col9" >0.074047</td>
#     </tr>
#     <tr>
#       <th id="T_1ece6_level0_row1" class="row_heading level0 row1" >sin_receiver_back_azimuth</th>
#       <td id="T_1ece6_row1_col0" class="data row1 col0" >-0.437910</td>
#       <td id="T_1ece6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_1ece6_row1_col2" class="data row1 col2" >-0.430831</td>
#       <td id="T_1ece6_row1_col3" class="data row1 col3" >0.180990</td>
#       <td id="T_1ece6_row1_col4" class="data row1 col4" >0.211859</td>
#       <td id="T_1ece6_row1_col5" class="data row1 col5" >0.176359</td>
#       <td id="T_1ece6_row1_col6" class="data row1 col6" >0.191381</td>
#       <td id="T_1ece6_row1_col7" class="data row1 col7" >0.193741</td>
#       <td id="T_1ece6_row1_col8" class="data row1 col8" >0.151793</td>
#       <td id="T_1ece6_row1_col9" class="data row1 col9" >0.070983</td>
#     </tr>
#     <tr>
#       <th id="T_1ece6_level0_row2" class="row_heading level0 row2" >source_depth_km</th>
#       <td id="T_1ece6_row2_col0" class="data row2 col0" >0.555717</td>
#       <td id="T_1ece6_row2_col1" class="data row2 col1" >-0.430831</td>
#       <td id="T_1ece6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_1ece6_row2_col3" class="data row2 col3" >-0.098022</td>
#       <td id="T_1ece6_row2_col4" class=

# %% [markdown]
# ## Make predictions on test set

# %%
test_feat_matrix_unscaled = compute_feature_matrix(test_df, scaler=False)
test_feat_matrix_scaled = scaler.transform(test_feat_matrix_unscaled)
test_feat_df_scaled = pd.DataFrame(test_feat_matrix_scaled, columns=columns)
test_y = test_df.magnitude.values

test_feat_df_scaled.head()
# Out:
#    amp_ratio_01.0  amp_ratio_02.0  amp_ratio_03.0  amp_ratio_04.0  \
# 0        1.884879       -1.934609       -1.806787       -1.375098
# 1        1.576373        1.958000        1.718404        1.547593
# 2        0.282801        0.878538        0.356402       -0.008501
# 3       -0.483793        0.233661       -0.200057       -1.013458
# 4        1.179195        1.293821        0.109128       -0.130238
#
#    amp_ratio_05.0  amp_ratio_06.0  amp_ratio_07.0  amp_ratio_08.0  \
# 0        0.012427        0.445931        0.894836        1.452256
# 1        1.206930        1.338294        1.266580        1.011869
# 2       -0.295859       -0.422829       -0.302799        0.097232
# 3       -0.669278       -0.326033        0.173180        0.669893
# 4       -0.034386        0.042902        0.060084        0.361703
#
#    amp_ratio_09.0  amp_ratio_10.0  ...  signal_dominant_frequency  \
# 0        1.762266        1.668660  ...                  -0.220209
# 1        0.558704       -0.005267  ...                  -1.266627
# 2        0.568953        0.980913  ...                   0.590918
# 3        0.924363        1.175967  ...                   0.365750
# 4        0.651683        0.580613  ...                   0.937601
#
#    signal_dominant_amplitude  noise_max_amplitude  signal_max_amplitude  \
# 0                   0.602113             0.245848              0.417205
# 1                   1.435989             1.330315              1.446534
# 2                  -0.461564            -0.457922             -0.449907
# 3                  -0.929408            -1.592585             -0.977538
# 4                  -1.080958            -0.913572             -1.010085
#
#    signal_variance  noise_variance  source_receiver_distance_logkm  \
# 0         0.439678        0.380755                        1.532463
# 1         1.630265        1.360239                       -1.027570
# 2        -0.342384       -0.493489                       -0.306463
# 3        -1.113169       -1.567816                        0.523605
# 4        -0.930809       -1.034982                        0.535218
#
#    source_depth_km  sin_receiver_back_azimuth  receiver_back_azimuth
# 0         2.155411                   0.229602              -0.661465
# 1        -0.648812                   1.779067              -1.459373
# 2        -1.718680                   3.360995              -2.589647
# 3        -0.527616                  -0.377817               0.585366
# 4         0.554789                  -0.211859              -0.343300
#
# [5 rows x 34 columns]

# %%
svr_linear = SVR(C=1.0, epsilon=0.1, kernel="linear")
svr_linear.fit(train_feat_df[linear_features], train_y)

y_est_linear = svr_linear.predict(test_feat_df_scaled[linear_features])
linear_test_r2 =r2_score(test_y, y_est_linear) 
print(linear_test_r2)
train_est_linear = svr_linear.predict(train_feat_df[linear_features]) 
print(r2_score(train_y, train_est_linear))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 svr_linear = SVR(C=1.0, epsilon=0.1, kernel="linear")
# ----> 2 svr_linear.fit(train_feat_df[linear_features], train_y)
#       4 y_est_linear = svr_linear.predict(test_feat_df_scaled[linear_features])
#       5 linear_test_r2 =r2_score(test_y, y_est_linear)
#
# NameError: name 'linear_features' is not defined

# %%
svr_rbf = SVR(C=1.0, epsilon=0.1, kernel="rbf")
svr_rbf.fit(train_feat_df[rbf_linear_features], train_y)

y_est_rbf = svr_rbf.predict(test_feat_df_scaled[rbf_linear_features])
rbf_test_r2 = r2_score(test_y, y_est_rbf)
print(rbf_test_r2)
train_est_rbf = svr_rbf.predict(train_feat_df[rbf_linear_features]) 
print(r2_score(train_y, train_est_rbf))
# Out:
# 0.9141629917050005
# 0.9389779660903993

# %%
plt.scatter(test_y, y_est_linear, alpha=0.5)
plt.plot(np.arange(0, 4.0, 0.5), np.arange(0, 4.0, 0.5), color="red")
plt.xlabel(r"Actual $M_L$", fontsize=16, labelpad=10)
plt.ylabel(r"Predicted $M_L$", fontsize=16, labelpad=10)
plt.text(0, 3.0, f'{r"$R^2$="} {linear_test_r2:.02f}', fontsize=14)
plt.text(0, 2.65, f'N={test_feat_df_scaled.shape[0]}', fontsize=14)
plt.title("S Magnitudes - SVR Linear", fontsize=20, y=1.05)
# Out:
# Text(0.5, 1.05, 'S Magnitudes - SVR Linear')

# %%
plt.scatter(test_y, y_est_rbf, alpha=0.5)
plt.plot(np.arange(0, 4.0, 0.5), np.arange(0, 4.0, 0.5), color="red")
plt.xlabel(r"Actual $M_L$", fontsize=16, labelpad=10)
plt.ylabel(r"Predicted $M_L$", fontsize=16, labelpad=10)
plt.text(0, 3.0, f'{r"$R^2$="} {rbf_test_r2:.02f}', fontsize=14)
plt.text(0, 2.65, f'N={test_feat_df_scaled.shape[0]}', fontsize=14)
plt.title(r"$M_L$ using S-arrival features", fontsize=20, y=1.05)
# Out:
# Text(0.5, 1.05, '$M_L$ using S-arrival features')

# %%
train_feat_df.shape
# Out:
# (1699, 34)

# %%
test_feat_df_scaled.shape
# Out:
# (425, 34)

# %% [markdown]
# ## Closer look at features with sr features

# %%
def add_feat_to_base(base_features, additional_features, all_features_cv=None, top_features_cv=None):

    cv_means = []

    for cf in additional_features:
        feat_list = base_features.copy()
        feat_list.append(cf)
        cv_vals = svr_cv(train_feat_df_unscaled[feat_list], train_y, folds)
        cv_means.append(np.mean(cv_vals))

    plt.scatter(range(len(additional_features)), cv_means, marker="x")
    plt.xticks(range(len(additional_features)), labels=additional_features, rotation=45);
    if all_features_cv is not None:
        plt.axhline(np.mean(all_features_cv))
    if top_features_cv is not None:
        plt.axhline(np.mean(top_features_cv), color="C1")
    plt.show()
    
    return cv_means

# %%
base_features = ['source_receiver_distance_logkm','source_depth_km', "receiver_back_azimuth"]

correlated_features = ['amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_variance',
                     'signal_dominant_amplitude']

cv_means = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm','source_depth_km', "receiver_back_azimuth", 'amp_02.0']

correlated_features = ['amp_10.0',
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_variance',
                     'signal_dominant_amplitude']

cv_means_amp02  = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm', "receiver_back_azimuth", 'amp_02.0']

correlated_features = ['amp_10.0',
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_variance',
                     'signal_dominant_amplitude']

cv_means_nodepth = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm', 'amp_02.0']

correlated_features = ['amp_10.0',
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_variance',
                     'signal_dominant_amplitude']


cv_means_nodepth_noba = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

# SR distance is important 
# base_features = ["receiver_back_azimuth",'amp_ratio_01.0', "amp_01.0"]

# correlated_features = ['amp_02.0', "amp_08.0", "amp_12.0", "amp_18.0", "signal_variance", 
#                        "signal_dominant_amplitude", "signal_max_amplitude"]

# cv_means_nodepth_nosrd = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
#                            top_features_cv=top_feat_sr_cv)

# %%
base_features = ['source_receiver_distance_logkm','source_depth_km', "receiver_back_azimuth"]

correlated_features = ['signal_variance', 'amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_dominant_amplitude']

cv_means = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm','source_depth_km', "receiver_back_azimuth", 'signal_variance']

correlated_features = ['amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_dominant_amplitude']

cv_means_amp02  = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm', "receiver_back_azimuth", 'signal_variance']

correlated_features = ['amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_dominant_amplitude']


cv_means_nodepth = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm', 'signal_variance']

correlated_features = ['amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_dominant_amplitude']

cv_means_nodepth_noba = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

# SR distance is important 
# base_features = ["receiver_back_azimuth",'amp_ratio_01.0', "amp_01.0"]

# correlated_features = ['amp_02.0', "amp_08.0", "amp_12.0", "amp_18.0", "signal_variance", 
#                        "signal_dominant_amplitude", "signal_max_amplitude"]

# cv_means_nodepth_nosrd = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
#                            top_features_cv=top_feat_sr_cv)

# %%
correlated_features = ['amp_02.0', 'amp_10.0',
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_variance',
                     'signal_dominant_amplitude']

plt.scatter( range(0,len(correlated_features)), cv_means, marker="x", label="no_amp2.0")
plt.scatter( range(1,len(correlated_features)), cv_means_amp02, marker="o", label="yes_amp2.0")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth, marker="v", label="yes_amp2.0_no_depth")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_noba, marker="x", label="yes_amp2.0_nodepth_noba")
# plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_nosrd, marker="x", label="yes_amp1.0_nodepth_nosr")

plt.xticks(range(len(correlated_features)), labels=correlated_features, rotation=45);
plt.axhline(np.mean(selected_feat_sr_cv), label="all_selected_features")
plt.axhline(np.mean(top_feat_sr_cv), color="C1", label="top 5 features")
plt.legend();

# %%
correlated_features = ['signal_variance', 'amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_dominant_amplitude']

plt.scatter( range(0,len(correlated_features)), cv_means, marker="x", label="no_sv")
plt.scatter( range(1,len(correlated_features)), cv_means_amp02, marker="o", label="yes_sv")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth, marker="v", label="yes_sv_no_depth")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_noba, marker="x", label="yes_sv_nodepth_noba")
# plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_nosrd, marker="x", label="yes_amp1.0_nodepth_nosr")

plt.xticks(range(len(correlated_features)), labels=correlated_features, rotation=45);
plt.axhline(np.mean(selected_feat_sr_cv), label="all_selected_features")
plt.axhline(np.mean(top_feat_sr_cv), color="C1", label="top 5 features")
plt.legend();

# %%
fewer_features_sr = ['source_receiver_distance_logkm', "receiver_back_azimuth", "source_depth_km",'amp_02.0', 
                          "amp_10.0", "signal_variance"]
fewer_feat_sr_df = train_feat_df.copy()[fewer_features_sr]
fewer_feat_sr_df.loc[:, "magnitude"] = train_y
corr = fewer_feat_sr_df.corr()
corr.style.background_gradient(cmap="coolwarm")

# %%
fewer_feat_sr_cv = svr_cv(train_feat_df_unscaled[fewer_features_sr], train_y, folds)
print(fewer_feat_sr_cv)
print(np.mean(fewer_feat_sr_cv))

# %%
fewest_features_sr = ['source_receiver_distance_logkm', "receiver_back_azimuth", "source_depth_km","signal_variance"]
fewest_feat_sr_df = train_feat_df.copy()[fewest_features_sr]
fewest_feat_sr_df.loc[:, "magnitude"] = train_y
corr = fewest_feat_sr_df.corr()
corr.style.background_gradient(cmap="coolwarm")

# %%
fewest_feat_sr_cv = svr_cv(train_feat_df_unscaled[fewest_features_sr], train_y, folds)
print(fewest_feat_sr_cv)
print(np.mean(fewest_feat_sr_cv))

# %%
linear_features_sr = ['source_receiver_distance_logkm', "sin_receiver_back_azimuth", "source_depth_km",
                      "signal_variance"]
                      #,'amp_02.0', "amp_10.0", "noise_variance"]

linear_feat_sr_cv = svr_cv(train_feat_df_unscaled[linear_features_sr], train_y, folds, kernel="linear")
print(linear_feat_sr_cv)
print(np.mean(linear_feat_sr_cv))

# %% [markdown]
# ## Default C, gamma, and epsilon seem to work well for SVR with RBF

# %%
#C_range = [1.0]#np.logspace(-2, 10, 5)
gamma_range = [7.4e-05, 0.1, 0.2, 0.3, 0.4, 5e-1, 1, "scale", "auto"]#np.logspace(-9, 3, 5)
epsilon_range = [5e-3, 1e-2, 5e-2, 1e-1, 2e-1]
param_grid = {"svr__gamma":gamma_range,  "svr__epsilon":epsilon_range} #"svr__C":C_range,
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', SVR(C=1.0))])
grid = GridSearchCV(pipeline, param_grid=param_grid, scoring="r2", n_jobs=3, cv=folds)
svr_cv_results = grid.fit(train_feat_df_unscaled[fewer_features_sr], train_y)

# %%
scores = grid.cv_results_["mean_test_score"].reshape(len(epsilon_range), len(gamma_range))
plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(
    scores,
    interpolation="nearest",
    cmap=plt.cm.viridis,
    #norm=MidpointNormalize(vmin=0.2, midpoint=0.92),
)
plt.xlabel("Gamma")
plt.ylabel("Epsilon")
plt.colorbar()
plt.xticks(np.arange(len(gamma_range)), gamma_range, rotation=45)
plt.yticks(np.arange(len(epsilon_range)), epsilon_range)
plt.title("Validation accuracy")
plt.show()

# %% [markdown]
# ## XGBoost
#
# Try more hyperparameters, try with limited features

# %%
from xgboost import XGBRegressor
from xgboost import DMatrix
import xgboost

# %%
from sklearn.utils.fixes import loguniform
import scipy.stats as stats

# %%
xgb = XGBRegressor(objective='reg:squarederror', eval_metric='rmse').fit(
                                    train_feat_matrix_unscaled[folds[0][0]], train_y[folds[0][0]])
xgb.score(train_feat_matrix_unscaled[folds[0][1]], train_y[folds[0][1]])

# %%
train_feat_df.columns[43]

# %%
fig, ax = plt.subplots(1, figsize=(10, 20))
xgboost.plot_importance(xgb, ax=ax)

# %%
feat_bool = np.isin(train_feat_df.columns, fewer_features_sr)
xgb = XGBRegressor(objective='reg:squarederror', eval_metric='rmse').fit(
                                    train_feat_matrix_unscaled[folds[0][0]][:, feat_bool], train_y[folds[0][0]])
xgb.score(train_feat_matrix_unscaled[folds[0][1]][:, feat_bool], train_y[folds[0][1]])

# %%
xgboost.plot_importance(xgb)

# %%
feat_bool = np.isin(train_feat_df.columns, fewer_features_lat_lon)
xgb = XGBRegressor(objective='reg:squarederror', eval_metric='rmse').fit(
                                    train_feat_matrix_unscaled[folds[0][0]][:, feat_bool], train_y[folds[0][0]])
xgb.score(train_feat_matrix_unscaled[folds[0][1]][:, feat_bool], train_y[folds[0][1]])

# %%
xgboost.plot_importance(xgb)

# %%
grid_params = {'max_depth': [1, 2, 3, 5, 10], 
          'eta': [0.05, 0.1, 0.2, 0.3, 0.5],
          'gamma': [0, 0.2, 0.5, 1, 1.5, 2, 5], 
         'min_child_weight':[0, 0.5, 1, 2], 
         'max_delta_step': [0, 1, 2], 
          'subsample': [0.5, 1]}

params = {'max_depth': stats.randint(3, 18),
          'gamma': stats.uniform(0, 5),
          'learning_rate': loguniform(1e-2, 1e0),
          'subsample': np.arange(0.5, 1.0, 0.1),
          'colsample_bytree':stats.uniform(0.5,1),
          'min_child_weight':stats.randint(0, 10), 
          'n_estimators': [100, 250, 500, 750],
          }
    
# params = {'objective': 'reg:squarederror'}
# params['eval_metric'] = 'rmse'
# params['nthread'] = 2

# %%
xgb = XGBRegressor(objective='reg:squarederror', eval_metric='rmse') #, topnthread=2
# grid_search = GridSearchCV(xgb, param_grid=grid_params, scoring="r2", 
#                            n_jobs=3, cv=folds).fit(train_feat_matrix_unscaled, train_y)
rand_search = RandomizedSearchCV(xgb, param_distributions=params, scoring="r2", 
                           n_jobs=3, cv=folds).fit(train_feat_matrix_unscaled[:, feat_bool], train_y)

# %%
rand_search.best_estimator_

# %%
# {'eta': 0.1,
#  'gamma': 0.5,
#  'max_delta_step': 1,
#  'max_depth': 5,
#  'min_child_weight': 0.5}

# 0.8620877350386309

# %%
rand_search.best_params_

# %%
rand_search.best_score_

# %%
results_df = pd.DataFrame(grid_search.cv_results_)
results_df.sort_values("rank_test_score")

# %%
num_round = 100
dtrain = DMatrix(train_feat_matrix_unscaled, label=train_y, feature_names=train_feat_df_unscaled.columns)
bst_cv = xgboost.cv(param, dtrain, num_round, folds=folds, early_stopping_rounds=3, 
               callbacks=[xgb.callback.EvaluationMonitor(show_stdv=True)])

# %%
x_ticks = range(1, len(bst_cv)+1)
plt.plot(x_ticks, bst_cv["train-rmse-mean"], color="k")
plt.plot(x_ticks, bst_cv["train-rmse-mean"]+bst_cv["train-rmse-std"], linestyle="--", color="C0")
plt.plot(x_ticks, bst_cv["train-rmse-mean"]-bst_cv["train-rmse-std"], linestyle="--", color="C0")
plt.fill_between(x_ticks,bst_cv["train-rmse-mean"]+bst_cv["train-rmse-std"], 
                 bst_cv["train-rmse-mean"]-bst_cv["train-rmse-std"], color="C0", alpha=0.5, label="train")

plt.plot(x_ticks, bst_cv["test-rmse-mean"], color="k")
plt.plot(x_ticks, bst_cv["test-rmse-mean"]+bst_cv["test-rmse-std"], linestyle="--", color="C1")
plt.plot(x_ticks, bst_cv["test-rmse-mean"]-bst_cv["test-rmse-std"], linestyle="--", color="C1")
plt.fill_between(x_ticks, bst_cv["test-rmse-mean"]+bst_cv["test-rmse-std"], 
                 bst_cv["test-rmse-mean"]-bst_cv["test-rmse-std"], color="C1", alpha=0.5, label="test")

plt.ylabel("RMSE")
plt.xlabel("Iteration")

#plt.xticks(x_ticks)
plt.legend()
