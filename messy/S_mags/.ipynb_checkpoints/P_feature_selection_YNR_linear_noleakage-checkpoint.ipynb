# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pygmt
from obspy.core import UTCDateTime

# %%
# Read in features, look at names & datatypes
df_original = pd.read_csv('../P_station_analysis/p_features.csv', dtype={'location_code': str})
print(len(df_original))
print(df_original.dtypes)
# Out:
# 72952
# arrival_identifier                int64
# avg_noise_1.00                  float64
# avg_noise_10.00                 float64
# avg_noise_11.00                 float64
# avg_noise_12.00                 float64
# avg_noise_13.00                 float64
# avg_noise_14.00                 float64
# avg_noise_15.00                 float64
# avg_noise_16.00                 float64
# avg_noise_17.00                 float64
# avg_noise_18.00                 float64
# avg_noise_2.00                  float64
# avg_noise_3.00                  float64
# avg_noise_4.00                  float64
# avg_noise_5.00                  float64
# avg_noise_6.00                  float64
# avg_noise_7.00                  float64
# avg_noise_8.00                  float64
# avg_noise_9.00                  float64
# avg_signal_1.00                 float64
# avg_signal_10.00                float64
# avg_signal_11.00                float64
# avg_signal_12.00                float64
# avg_signal_13.00                float64
# avg_signal_14.00                float64
# avg_signal_15.00                float64
# avg_signal_16.00                float64
# avg_signal_17.00                float64
# avg_signal_18.00                float64
# avg_signal_2.00                 float64
# avg_signal_3.00                 float64
# avg_signal_4.00                 float64
# avg_signal_5.00                 float64
# avg_signal_6.00                 float64
# avg_signal_7.00                 float64
# avg_signal_8.00                 float64
# avg_signal_9.00                 float64
# channel                          object
# event_identifier                  int64
# location_code                    object
# magnitude                       float64
# magnitude_type                   object
# network                          object
# noise_dominant_amplitude        float64
# noise_dominant_frequency        float64
# noise_maximum_value             float64
# noise_minimum_value             float64
# noise_variance                  float64
# signal_dominant_amplitude       float64
# signal_dominant_frequency       float64
# signal_maximum_value            float64
# signal_minimum_value            float64
# signal_variance                 float64
# source_depth_km                 float64
# source_latitude                 float64
# source_longitude                float64
# source_receiver_back_azimuth    float64
# source_receiver_distance_km     float64
# station                          object
# dtype: object

# %%
# Get metadata for 1 and 3c stations
eq_meta_onec = pd.read_csv("../currentEarthquakeArrivalInformation1CWithGains.csv")
eq_meta_threec = pd.read_csv("../currentEarthquakeArrivalInformation3CWithGains.csv")
eq_meta_all = pd.concat([eq_meta_onec, eq_meta_threec])

# Reduce to just location information
all_eq_locs = eq_meta_all.drop_duplicates("evid")[["evid", "event_lat", "event_lon", "origin_time"]]
all_eq_locs.columns = ["event_identifier", "event_lat", "event_lon", "origin_time"]

# Reduce to events in the dataset 
eq_locs_df = all_eq_locs[np.isin(all_eq_locs.event_identifier, df_original.event_identifier.unique())]
# Make date column for filtering
eq_locs_df.loc[:, "date"] = eq_locs_df.origin_time.apply(lambda x: int(UTCDateTime(x).strftime("%y%m%d")))
# Out:
# /tmp/ipykernel_73983/187499698.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   eq_meta_threec = pd.read_csv("../currentEarthquakeArrivalInformation3CWithGains.csv")
# /tmp/ipykernel_73983/187499698.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eq_locs_df.loc[:, "date"] = eq_locs_df.origin_time.apply(lambda x: int(UTCDateTime(x).strftime("%y%m%d")))

# %%
# Set filter bounds
lat_min = 44.680
lat_max = 44.870
lon_max = 110.850
lon_min = 110.640
date_min = 130901  # YYMMDD
date_max = 140630  # YYMMDD
bounds = {"lat_min": lat_min,
          "lat_max": lat_max,
          "lon_max": lon_max,
          "lon_min": lon_min,
          "date_min": date_min,
          "date_max": date_max}

# Get ngb event ids
ngb_event_locs = eq_locs_df.loc[
        (eq_locs_df["date"] >= bounds["date_min"]) & (eq_locs_df["date"] <= bounds["date_max"]) & (eq_locs_df["event_lat"] >= bounds["lat_min"])
        & (eq_locs_df["event_lat"] <= bounds["lat_max"]) & (-1 * eq_locs_df["event_lon"] >= bounds["lon_min"]) & (
                    -1 * eq_locs_df["event_lon"] <= bounds["lon_max"])]

# %%
df_ngb_removed = df_original[~np.isin(df_original.event_identifier, ngb_event_locs.event_identifier)]
df_ngb = df_original[np.isin(df_original.event_identifier, ngb_event_locs.event_identifier)]
np.where(np.isin(df_ngb_removed.event_identifier, df_ngb.event_identifier))
# Out:
# (array([], dtype=int64),)

# %%
# Read in park and caldera boundaries
utahnet_path = "../../maps/utahnet"
ys_border = pd.read_csv(f"{utahnet_path}/yell.border.g", delimiter=" ", names=["Longitude", "Latitude"], dtype=np.float64)
caldera = pd.read_csv(f"{utahnet_path}/caldera.ys", sep="\s+", names=["Latitude", "Longitude"], dtype=np.float64)

caldera = caldera.drop(caldera[caldera["Longitude"]==0].index)
caldera = caldera[["Longitude", "Latitude"]]
caldera["Longitude"] = caldera["Longitude"]*-1

# %%
# Lat/lon bounding box I could use to scale the source locations
bb_lat_min = ys_border.Latitude.min() - 0.2
bb_lat_max = ys_border.Latitude.max()
bb_lon_min = ys_border.Longitude.min() - 0.15
bb_lon_max = ys_border.Longitude.max()
ys_bb = [[bb_lon_max, bb_lat_max], [bb_lon_max, bb_lat_min], [bb_lon_min, bb_lat_min], [bb_lon_min, bb_lat_max], [bb_lon_max, bb_lat_max]]

# %%
#Draw event map 
region = [
    eq_locs_df.event_lon.min() - 0.2,
    eq_locs_df.event_lon.max() + 0.2,
    eq_locs_df.event_lat.min() - 0.1,
    eq_locs_df.event_lat.max() + 0.2,
]

unique_locations = df_ngb_removed[["source_longitude", "source_latitude"]].drop_duplicates()
unique_ngb_locations = df_ngb[["source_longitude", "source_latitude"]].drop_duplicates()

fig = pygmt.Figure()
fig.basemap(region=region, projection="M15c", frame=True)
fig.coast(land="white", borders=2, water="skyblue")
fig.plot(data=ys_border, pen="1.0p,black")
fig.plot(data=caldera, pen='1.0p,black')
fig.plot(x=unique_ngb_locations.source_longitude, y=unique_ngb_locations.source_latitude, style="c0.2c", pen="0.2p,red")
fig.plot(x=unique_locations.source_longitude, y=unique_locations.source_latitude, style="c0.2c", pen="0.2p,black")
fig.plot(ys_bb, pen="0.6p,blue")
fig.show()

# %%
# Keep stations with more than 350 observations
stat_counts = df_original.value_counts("station").to_frame().reset_index()
stat_counts.columns = ["Station", "Count"]
df_org_filtcounts = df_ngb_removed[np.isin(df_ngb_removed.station, stat_counts[stat_counts.Count >= 350])]

# %%
stat_counts
# Out:
#    Station  Count
# 0      YNR   5017
# 1      YHH   5007
# 2      YMC   4451
# 3      YMR   4238
# 4      YPM   4201
# 5      YWB   3855
# 6     MCID   3714
# 7      YHB   3654
# 8      YFT   3638
# 9      YHL   3421
# 10     YML   3316
# 11     YDC   3154
# 12     YGC   2176
# 13    B207   1989
# 14     YUF   1784
# 15     YPP   1673
# 16     YLT   1567
# 17    LKWY   1294
# 18     YTP   1092
# 19     YNM   1061
# 20    QLMT    982
# 21    FLWY    871
# 22     YLA    851
# 23    B206    846
# 24     YMV    703
# 25    B950    691
# 26    H17A    669
# 27    B208    660
# 28     YDD    614
# 29     YMS    515
# 30    TPMT    505
# 31     YJC    502
# 32    B944    455
# 33     YPC    421
# 34     YPK    358
# 35    B945    354
# 36     YNE    314
# 37     IMW    310
# 38     BOZ    271
# 39     YSB    267
# 40    CRMT    266
# 41    LOHW    209
# 42    BGMT    181
# 43     YMP    165
# 44    SNOW    119
# 45    MOOW    113
# 46     YEE     88
# 47    TPAW     68
# 48     YHR     68
# 49    BZMT     60
# 50    MOMT     59
# 51    REDW     51
# 52    RLMT     15
# 53    BW06     11
# 54    AHID     11
# 55    HHAI      2
# 56     PTI      2
# 57    ECRI      1
# 58    GRRI      1
# 59    ID08      1

# %% [markdown]
# ## Feature selection?

# %%
# Make train and test datasets

test_size = 0.2
station = "YNR"

station_df = df_org_filtcounts[df_org_filtcounts.station == station]

evids = np.unique(df_org_filtcounts.event_identifier)
train_evids, test_evids = train_test_split(evids, test_size = test_size, random_state = 843823)

train_inds = np.isin(station_df.event_identifier, train_evids)
train_df = station_df[train_inds]
test_df = station_df[~train_inds]

# assert len(train_df.event_identifier.unique()) == len(train_evids)
# assert len(test_df.event_identifier.unique()) == len(test_evids)
assert len(test_df) + len(train_df) == len(station_df)

# %%
# Computes the feature matrix from a dataframe
# Computes the feature matrix from a dataframe
def compute_feature_matrix(df, scaler = True):
    # Loosely speaking empirical magnitudes look like:
    # M = log10(A) + Q(Delta) 
    # where A is the amplitude and Q a distance dependent correction term.
    # Additionally, the difference between log10 and log amounts to a scalar
    # that a machine can learn.
    # Basically, I'm interested in features that:
    #   (1) Measure size in, potentially, different amplitudes.
    # different `passbands' deviates from the noise, 
    n_rows = len(df)
    n_columns = 46
    X = np.zeros([n_rows, n_columns])
    # Get a proxy on size
    
    # These are effectively amplitude ratios.  Note,
    # log(a/b) = log(a) - log(b)
    X[:,0]  = np.log(df['avg_signal_1.00']) - np.log(df['avg_noise_1.00'])
    X[:,1]  = np.log(df['avg_signal_2.00']) - np.log(df['avg_noise_2.00'])
    X[:,2]  = np.log(df['avg_signal_3.00']) - np.log(df['avg_noise_3.00'])
    X[:,3]  = np.log(df['avg_signal_4.00']) - np.log(df['avg_noise_4.00'])
    X[:,4]  = np.log(df['avg_signal_5.00']) - np.log(df['avg_noise_5.00'])
    X[:,5]  = np.log(df['avg_signal_6.00']) - np.log(df['avg_noise_6.00'])
    X[:,6]  = np.log(df['avg_signal_7.00']) - np.log(df['avg_noise_7.00'])
    X[:,7]  = np.log(df['avg_signal_8.00']) - np.log(df['avg_noise_8.00'])
    X[:,8]  = np.log(df['avg_signal_9.00']) - np.log(df['avg_noise_9.00'])
    X[:,9]  = np.log(df['avg_signal_10.00']) - np.log(df['avg_noise_10.00'])
    X[:,10] = np.log(df['avg_signal_11.00']) - np.log(df['avg_noise_11.00'])
    X[:,11] = np.log(df['avg_signal_12.00']) - np.log(df['avg_noise_12.00'])
    X[:,12] = np.log(df['avg_signal_13.00']) - np.log(df['avg_noise_13.00'])
    X[:,13] = np.log(df['avg_signal_14.00']) - np.log(df['avg_noise_14.00'])
    X[:,14] = np.log(df['avg_signal_15.00']) - np.log(df['avg_noise_15.00'])
    X[:,15] = np.log(df['avg_signal_16.00']) - np.log(df['avg_noise_16.00'])
    X[:,16] = np.log(df['avg_signal_17.00']) - np.log(df['avg_noise_17.00'])
    X[:,17] = np.log(df['avg_signal_18.00']) - np.log(df['avg_noise_18.00'])
    # Look at amplitudes
    X[:,18] = np.log(df['avg_signal_1.00']) 
    X[:,19] = np.log(df['avg_signal_2.00']) 
    X[:,20] = np.log(df['avg_signal_3.00']) 
    X[:,21] = np.log(df['avg_signal_4.00']) 
    X[:,22] = np.log(df['avg_signal_5.00'])
    X[:,23] = np.log(df['avg_signal_6.00'])
    X[:,24] = np.log(df['avg_signal_7.00'])
    X[:,25] = np.log(df['avg_signal_8.00'])
    X[:,26] = np.log(df['avg_signal_9.00'])
    X[:,27] = np.log(df['avg_signal_10.00'])
    X[:,28] = np.log(df['avg_signal_11.00'])
    X[:,29] = np.log(df['avg_signal_12.00'])
    X[:,30] = np.log(df['avg_signal_13.00'])
    X[:,31] = np.log(df['avg_signal_14.00'])
    X[:,32] = np.log(df['avg_signal_15.00'])
    X[:,33] = np.log(df['avg_signal_16.00'])
    X[:,34] = np.log(df['avg_signal_17.00'])
    X[:,35] = np.log(df['avg_signal_18.00'])
    # Frequency and max amplitude
    X[:,36] = np.log(df['signal_dominant_frequency'])
    X[:,37] = np.log(df['signal_dominant_amplitude'])
    # Time-based featuers: Look at max amplitudes of noise/signal
    X[:,38] = np.log(df['noise_maximum_value']  - df['noise_minimum_value'])
    X[:,39] = np.log(df['signal_maximum_value'] - df['signal_minimum_value'])
    X[:,40] = np.log(df['signal_variance'])
    X[:,41] = np.log(df['noise_variance'])
    # Source/recv distance (take log to flatten this)
    X[:,42] = np.log(df['source_receiver_distance_km'])
    X[:,43] = df['source_depth_km']
    # Single stations can learn location
#     X[:,44] = df['source_latitude']
#     X[:,45] = df['source_longitude']
    X[:,44] = np.sin(df['source_receiver_back_azimuth']*np.pi/180)
    X[:,45] = df['source_receiver_back_azimuth']

    # Standardize features
    if (scaler):
        scaler = StandardScaler()
        scaler = scaler.fit(X)
        X = scaler.transform(X)
        return X, scaler
    
    return X

# %%
train_feat_matrix_scaled, scaler = compute_feature_matrix(train_df)
train_feat_matrix_unscaled = compute_feature_matrix(train_df, scaler=False)

train_y = train_df.magnitude.values

# %%
train_feat_matrix_scaled[0], train_feat_matrix_unscaled[0]
# Out:
# (array([ 1.7309722 ,  0.7503704 ,  2.24253539,  0.97560227,  0.3316085 ,
#          0.68518342,  0.93831933,  0.56807253,  0.19673972, -0.01025141,
#         -0.14557287, -0.24136743, -0.33058859, -0.41827197, -0.47283815,
#         -0.49934215, -0.5101774 , -0.51454434,  2.90131982,  1.56620097,
#          1.70315303,  1.23046818,  0.84094018,  0.90940298,  1.00175076,
#          0.88543198,  0.71187802,  0.57618137,  0.47097854,  0.36575325,
#          0.25391638,  0.16259534,  0.10253445,  0.0644062 ,  0.0394687 ,
#          0.01978009, -4.00557711,  0.83245677,  1.15014856,  0.70560897,
#          0.74949872,  1.05481164,  1.5402138 ,  0.65303117, -0.08634129,
#         -0.31409782]),
#  array([  2.80520353,   2.2919585 ,   4.01970957,   3.19738553,
#           2.81836216,   3.4000582 ,   3.93061725,   3.85167983,
#           3.7250727 ,   3.6992148 ,   3.70529771,   3.72709997,
#           3.7201053 ,   3.67546395,   3.64402469,   3.63045885,
#           3.62557686,   3.62132271,  -0.32561442,  -1.4020008 ,
#          -0.85803843,  -1.22862512,  -1.63222306,  -1.48758246,
#          -1.31548711,  -1.39670887,  -1.57860608,  -1.74483035,
#          -1.86715152,  -1.9666721 ,  -2.07273695,  -2.17534186,
#          -2.27136354,  -2.37318723,  -2.48714996,  -2.61739031,
#           0.        ,  -2.64143426,  -1.03503045,   1.98308752,
#           0.30179533,  -5.14505926,   3.83699892,   8.91      ,
#          -0.63324723, 219.29010553]))

# %%
train_y
# Out:
# array([3.1 , 2.  , 0.9 , ..., 2.37, 1.93, 1.63])

# %%
for col in df_org_filtcounts.columns:
    print(col)
# Out:
# arrival_identifier
# avg_noise_1.00
# avg_noise_10.00
# avg_noise_11.00
# avg_noise_12.00
# avg_noise_13.00
# avg_noise_14.00
# avg_noise_15.00
# avg_noise_16.00
# avg_noise_17.00
# avg_noise_18.00
# avg_noise_2.00
# avg_noise_3.00
# avg_noise_4.00
# avg_noise_5.00
# avg_noise_6.00
# avg_noise_7.00
# avg_noise_8.00
# avg_noise_9.00
# avg_signal_1.00
# avg_signal_10.00
# avg_signal_11.00
# avg_signal_12.00
# avg_signal_13.00
# avg_signal_14.00
# avg_signal_15.00
# avg_signal_16.00
# avg_signal_17.00
# avg_signal_18.00
# avg_signal_2.00
# avg_signal_3.00
# avg_signal_4.00
# avg_signal_5.00
# avg_signal_6.00
# avg_signal_7.00
# avg_signal_8.00
# avg_signal_9.00
# channel
# event_identifier
# location_code
# magnitude
# magnitude_type
# network
# noise_dominant_amplitude
# noise_dominant_frequency
# noise_maximum_value
# noise_minimum_value
# noise_variance
# signal_dominant_amplitude
# signal_dominant_frequency
# signal_maximum_value
# signal_minimum_value
# signal_variance
# source_depth_km
# source_latitude
# source_longitude
# source_receiver_back_azimuth
# source_receiver_distance_km
# station

# %%
columns=["amp_ratio_01.0", "amp_ratio_02.0", "amp_ratio_03.0", "amp_ratio_04.0", 
                                 "amp_ratio_05.0", "amp_ratio_06.0", "amp_ratio_07.0", "amp_ratio_08.0",
                                 "amp_ratio_09.0", "amp_ratio_10.0", "amp_ratio_11.0", "amp_ratio_12.0", 
                                 "amp_ratio_13.0", "amp_ratio_14.0", "amp_ratio_15.0", "amp_ratio_16.0", 
                                 "amp_ratio_17.0", "amp_ratio_18.0", 
                                 "amp_01.0", "amp_02.0", "amp_03.0", "amp_04.0", 
                                 "amp_05.0", "amp_06.0", "amp_07.0", "amp_08.0",
                                 "amp_09.0", "amp_10.0", "amp_11.0", "amp_12.0", 
                                 "amp_13.0", "amp_14.0", "amp_15.0", "amp_16.0", 
                                 "amp_17.0", "amp_18.0",
                                 "signal_dominant_frequency", "signal_dominant_amplitude", 
                                 "noise_max_amplitude", "signal_max_amplitude", "signal_variance", "noise_variance",
                                 "source_receiver_distance_logkm", "source_depth_km", 
                                 "sin_receiver_back_azimuth", "receiver_back_azimuth"]
train_feat_df = pd.DataFrame(train_feat_matrix_scaled, columns=columns)

# %%
train_feat_df_unscaled = pd.DataFrame(train_feat_matrix_unscaled, columns=columns)

# %%
feat_target_df = train_feat_df.copy()
feat_target_df.loc[:, "magnitude"] = train_y
corr = feat_target_df.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_a3cf0_row0_col0, #T_a3cf0_row1_col1, #T_a3cf0_row2_col2, #T_a3cf0_row3_col3, #T_a3cf0_row4_col4, #T_a3cf0_row5_col5, #T_a3cf0_row6_col6, #T_a3cf0_row7_col7, #T_a3cf0_row8_col8, #T_a3cf0_row9_col9, #T_a3cf0_row10_col10, #T_a3cf0_row11_col11, #T_a3cf0_row11_col12, #T_a3cf0_row12_col11, #T_a3cf0_row12_col12, #T_a3cf0_row12_col13, #T_a3cf0_row13_col12, #T_a3cf0_row13_col13, #T_a3cf0_row13_col14, #T_a3cf0_row13_col15, #T_a3cf0_row14_col13, #T_a3cf0_row14_col14, #T_a3cf0_row14_col15, #T_a3cf0_row14_col16, #T_a3cf0_row14_col17, #T_a3cf0_row15_col13, #T_a3cf0_row15_col14, #T_a3cf0_row15_col15, #T_a3cf0_row15_col16, #T_a3cf0_row15_col17, #T_a3cf0_row16_col14, #T_a3cf0_row16_col15, #T_a3cf0_row16_col16, #T_a3cf0_row16_col17, #T_a3cf0_row17_col14, #T_a3cf0_row17_col15, #T_a3cf0_row17_col16, #T_a3cf0_row17_col17, #T_a3cf0_row18_col18, #T_a3cf0_row19_col19, #T_a3cf0_row20_col20, #T_a3cf0_row21_col21, #T_a3cf0_row22_col22, #T_a3cf0_row23_col23, #T_a3cf0_row23_col24, #T_a3cf0_row24_col23, #T_a3cf0_row24_col24, #T_a3cf0_row24_col25, #T_a3cf0_row25_col24, #T_a3cf0_row25_col25, #T_a3cf0_row25_col26, #T_a3cf0_row26_col25, #T_a3cf0_row26_col26, #T_a3cf0_row26_col27, #T_a3cf0_row27_col26, #T_a3cf0_row27_col27, #T_a3cf0_row27_col28, #T_a3cf0_row28_col27, #T_a3cf0_row28_col28, #T_a3cf0_row28_col29, #T_a3cf0_row29_col28, #T_a3cf0_row29_col29, #T_a3cf0_row29_col30, #T_a3cf0_row29_col31, #T_a3cf0_row30_col29, #T_a3cf0_row30_col30, #T_a3cf0_row30_col31, #T_a3cf0_row30_col32, #T_a3cf0_row30_col33, #T_a3cf0_row30_col34, #T_a3cf0_row31_col29, #T_a3cf0_row31_col30, #T_a3cf0_row31_col31, #T_a3cf0_row31_col32, #T_a3cf0_row31_col33, #T_a3cf0_row31_col34, #T_a3cf0_row31_col35, #T_a3cf0_row32_col30, #T_a3cf0_row32_col31, #T_a3cf0_row32_col32, #T_a3cf0_row32_col33, #T_a3cf0_row32_col34, #T_a3cf0_row32_col35, #T_a3cf0_row33_col30, #T_a3cf0_row33_col31, #T_a3cf0_row33_col32, #T_a3cf0_row33_col33, #T_a3cf0_row33_col34, #T_a3cf0_row33_col35, #T_a3cf0_row34_col30, #T_a3cf0_row34_col31, #T_a3cf0_row34_col32, #T_a3cf0_row34_col33, #T_a3cf0_row34_col34, #T_a3cf0_row34_col35, #T_a3cf0_row35_col31, #T_a3cf0_row35_col32, #T_a3cf0_row35_col33, #T_a3cf0_row35_col34, #T_a3cf0_row35_col35, #T_a3cf0_row36_col36, #T_a3cf0_row37_col37, #T_a3cf0_row38_col38, #T_a3cf0_row39_col39, #T_a3cf0_row40_col40, #T_a3cf0_row41_col41, #T_a3cf0_row42_col42, #T_a3cf0_row43_col43, #T_a3cf0_row44_col44, #T_a3cf0_row45_col45, #T_a3cf0_row46_col46 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a3cf0_row0_col1, #T_a3cf0_row1_col3, #T_a3cf0_row2_col19, #T_a3cf0_row2_col25, #T_a3cf0_row2_col40, #T_a3cf0_row12_col3, #T_a3cf0_row15_col20, #T_a3cf0_row16_col4, #T_a3cf0_row18_col37, #T_a3cf0_row19_col2, #T_a3cf0_row21_col2, #T_a3cf0_row32_col3, #T_a3cf0_row33_col3 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_a3cf0_row0_col2, #T_a3cf0_row1_col7, #T_a3cf0_row6_col1, #T_a3cf0_row21_col46, #T_a3cf0_row28_col18, #T_a3cf0_row31_col2, #T_a3cf0_row46_col27 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_a3cf0_row0_col3, #T_a3cf0_row0_col18, #T_a3cf0_row1_col27, #T_a3cf0_row3_col18, #T_a3cf0_row7_col18, #T_a3cf0_row14_col2, #T_a3cf0_row18_col9, #T_a3cf0_row23_col46, #T_a3cf0_row33_col18, #T_a3cf0_row46_col6, #T_a3cf0_row46_col33, #T_a3cf0_row46_col34 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_a3cf0_row0_col4, #T_a3cf0_row0_col20, #T_a3cf0_row1_col32, #T_a3cf0_row18_col0 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_a3cf0_row0_col5, #T_a3cf0_row1_col10, #T_a3cf0_row40_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_a3cf0_row0_col6, #T_a3cf0_row0_col22, #T_a3cf0_row18_col15, #T_a3cf0_row26_col1, #T_a3cf0_row28_col46, #T_a3cf0_row39_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_a3cf0_row0_col7, #T_a3cf0_row0_col26, #T_a3cf0_row0_col39, #T_a3cf0_row1_col12, #T_a3cf0_row5_col46, #T_a3cf0_row12_col18, #T_a3cf0_row19_col44, #T_a3cf0_row46_col16, #T_a3cf0_row46_col17 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_a3cf0_row0_col8, #T_a3cf0_row0_col29, #T_a3cf0_row1_col14, #T_a3cf0_row15_col18, #T_a3cf0_row18_col1, #T_a3cf0_row20_col0, #T_a3cf0_row31_col1, #T_a3cf0_row34_col46, #T_a3cf0_row35_col46 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_a3cf0_row0_col9, #T_a3cf0_row0_col44, #T_a3cf0_row12_col46, #T_a3cf0_row21_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_a3cf0_row0_col10, #T_a3cf0_row2_col44, #T_a3cf0_row6_col44, #T_a3cf0_row13_col1, #T_a3cf0_row14_col46, #T_a3cf0_row46_col1 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_a3cf0_row0_col11, #T_a3cf0_row25_col0, #T_a3cf0_row40_col44, #T_a3cf0_row41_col18 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_a3cf0_row0_col12, #T_a3cf0_row1_col46, #T_a3cf0_row8_col0, #T_a3cf0_row26_col0, #T_a3cf0_row38_col25, #T_a3cf0_row38_col26, #T_a3cf0_row38_col27, #T_a3cf0_row38_col28, #T_a3cf0_row38_col29, #T_a3cf0_row41_col23, #T_a3cf0_row41_col25, #T_a3cf0_row41_col37, #T_a3cf0_row41_col39 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_a3cf0_row0_col13, #T_a3cf0_row38_col21, #T_a3cf0_row41_col21, #T_a3cf0_row41_col31, #T_a3cf0_row41_col32, #T_a3cf0_row41_col33, #T_a3cf0_row41_col34, #T_a3cf0_row41_col35 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_a3cf0_row0_col14, #T_a3cf0_row27_col44, #T_a3cf0_row38_col20, #T_a3cf0_row45_col43 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_a3cf0_row0_col15, #T_a3cf0_row8_col44, #T_a3cf0_row28_col44, #T_a3cf0_row36_col35, #T_a3cf0_row41_col20 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_a3cf0_row0_col16, #T_a3cf0_row9_col0, #T_a3cf0_row28_col0, #T_a3cf0_row36_col34 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_a3cf0_row0_col17, #T_a3cf0_row29_col44, #T_a3cf0_row36_col33, #T_a3cf0_row38_col44, #T_a3cf0_row41_col44, #T_a3cf0_row45_col42 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_a3cf0_row0_col19, #T_a3cf0_row2_col0, #T_a3cf0_row5_col18, #T_a3cf0_row6_col18, #T_a3cf0_row32_col18, #T_a3cf0_row46_col4, #T_a3cf0_row46_col8, #T_a3cf0_row46_col32 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_a3cf0_row0_col21, #T_a3cf0_row0_col23, #T_a3cf0_row0_col24, #T_a3cf0_row2_col18, #T_a3cf0_row18_col14, #T_a3cf0_row37_col1, #T_a3cf0_row46_col12 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_a3cf0_row0_col25, #T_a3cf0_row11_col18, #T_a3cf0_row18_col44, #T_a3cf0_row27_col1, #T_a3cf0_row43_col45 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_a3cf0_row0_col27, #T_a3cf0_row10_col1, #T_a3cf0_row29_col1 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_a3cf0_row0_col28, #T_a3cf0_row1_col13, #T_a3cf0_row1_col18, #T_a3cf0_row30_col1, #T_a3cf0_row32_col46 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_a3cf0_row0_col30, #T_a3cf0_row1_col15, #T_a3cf0_row1_col16, #T_a3cf0_row1_col44, #T_a3cf0_row11_col46, #T_a3cf0_row17_col18, #T_a3cf0_row33_col1, #T_a3cf0_row43_col42 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_a3cf0_row0_col31, #T_a3cf0_row1_col17, #T_a3cf0_row34_col1, #T_a3cf0_row35_col1 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_a3cf0_row0_col32, #T_a3cf0_row4_col44, #T_a3cf0_row5_col0, #T_a3cf0_row22_col44, #T_a3cf0_row42_col45, #T_a3cf0_row46_col44 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_a3cf0_row0_col33, #T_a3cf0_row0_col34, #T_a3cf0_row0_col35, #T_a3cf0_row20_col44, #T_a3cf0_row21_col44 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_a3cf0_row0_col36, #T_a3cf0_row38_col0, #T_a3cf0_row41_col1, #T_a3cf0_row46_col36 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_a3cf0_row0_col37, #T_a3cf0_row6_col46, #T_a3cf0_row28_col1, #T_a3cf0_row46_col15 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_a3cf0_row0_col38, #T_a3cf0_row0_col41 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_a3cf0_row0_col40, #T_a3cf0_row3_col46, #T_a3cf0_row9_col46, #T_a3cf0_row29_col46, #T_a3cf0_row46_col14 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_a3cf0_row0_col42, #T_a3cf0_row12_col43, #T_a3cf0_row13_col43, #T_a3cf0_row14_col43, #T_a3cf0_row15_col43

# %%
from sklearn.feature_selection import mutual_info_regression, SequentialFeatureSelector, RFE

# %%
mutual_reg = mutual_info_regression(train_feat_matrix_scaled, train_y, random_state=843824)
mutual_reg
# Out:
# array([0.11725816, 0.13499876, 0.16479814, 0.20656066, 0.21300093,
#        0.21118016, 0.20667286, 0.24228417, 0.25510182, 0.22337451,
#        0.23619377, 0.21159997, 0.18998475, 0.19580074, 0.17886075,
#        0.17663993, 0.16696442, 0.16815349, 0.34482968, 0.36972197,
#        0.35121113, 0.34366541, 0.30809237, 0.30719165, 0.31433718,
#        0.3296922 , 0.32061313, 0.31552148, 0.3030055 , 0.3044952 ,
#        0.28641599, 0.27571726, 0.28703643, 0.27022001, 0.27874452,
#        0.29203596, 0.04035337, 0.27856693, 0.0361488 , 0.28805315,
#        0.31105948, 0.02804586, 0.09007663, 0.0244131 , 0.08025473,
#        0.10823192])

# %%
train_feat_df.columns[np.argsort(mutual_reg, axis=0)]
# Out:
# Index(['source_depth_km', 'noise_variance', 'noise_max_amplitude',
#        'signal_dominant_frequency', 'sin_receiver_back_azimuth',
#        'source_receiver_distance_logkm', 'receiver_back_azimuth',
#        'amp_ratio_01.0', 'amp_ratio_02.0', 'amp_ratio_03.0', 'amp_ratio_17.0',
#        'amp_ratio_18.0', 'amp_ratio_16.0', 'amp_ratio_15.0', 'amp_ratio_13.0',
#        'amp_ratio_14.0', 'amp_ratio_04.0', 'amp_ratio_07.0', 'amp_ratio_06.0',
#        'amp_ratio_12.0', 'amp_ratio_05.0', 'amp_ratio_10.0', 'amp_ratio_11.0',
#        'amp_ratio_08.0', 'amp_ratio_09.0', 'amp_16.0', 'amp_14.0',
#        'signal_dominant_amplitude', 'amp_17.0', 'amp_13.0', 'amp_15.0',
#        'signal_max_amplitude', 'amp_18.0', 'amp_11.0', 'amp_12.0', 'amp_06.0',
#        'amp_05.0', 'signal_variance', 'amp_07.0', 'amp_10.0', 'amp_09.0',
#        'amp_08.0', 'amp_04.0', 'amp_01.0', 'amp_03.0', 'amp_02.0'],
#       dtype='object')

# %%
# Make cross validation splits across evids

from sklearn.model_selection import KFold
evids = train_df.event_identifier.unique()
kf = KFold(n_splits=5, shuffle=True, random_state=843824)
folds = []
for train_index, test_index in kf.split(evids):
    # Get the evids corresponding to the split indicies
    fold_train_evids = evids[train_index]
    fold_test_evids = evids[test_index]
    # Get rows of training dataset that correspond to split evids
    fold_train_inds = np.where(np.isin(train_df.event_identifier, fold_train_evids))[0]
    fold_test_inds = np.where(np.isin(train_df.event_identifier, fold_test_evids))[0]
    
    folds.append((fold_train_inds, fold_test_inds))

# %%
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, cross_validate
from sklearn.metrics import r2_score

# %% [markdown]
# ## RFE
#
# from RFECV, know that most of the gain comes from 5-10 features. Use RFE to find 8 "best" features

# %%
# CV performace with these all features in linear model
svr = SVR(C=1.0, epsilon=0.1, kernel="linear")
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:, :-1], train_y, cv=folds, scoring="r2")
# Out:
# {'fit_time': array([2.70757961, 2.55004454, 2.62357688, 2.46768069, 2.48162031]),
#  'score_time': array([0.04412365, 0.04320908, 0.04328156, 0.04406023, 0.04507685]),
#  'test_score': array([0.77823021, 0.776396  , 0.70144203, 0.79344752, 0.80099884])}

# %%
train_feat_df.columns[:-1]
# Out:
# Index(['amp_ratio_01.0', 'amp_ratio_02.0', 'amp_ratio_03.0', 'amp_ratio_04.0',
#        'amp_ratio_05.0', 'amp_ratio_06.0', 'amp_ratio_07.0', 'amp_ratio_08.0',
#        'amp_ratio_09.0', 'amp_ratio_10.0', 'amp_ratio_11.0', 'amp_ratio_12.0',
#        'amp_ratio_13.0', 'amp_ratio_14.0', 'amp_ratio_15.0', 'amp_ratio_16.0',
#        'amp_ratio_17.0', 'amp_ratio_18.0', 'amp_01.0', 'amp_02.0', 'amp_03.0',
#        'amp_04.0', 'amp_05.0', 'amp_06.0', 'amp_07.0', 'amp_08.0', 'amp_09.0',
#        'amp_10.0', 'amp_11.0', 'amp_12.0', 'amp_13.0', 'amp_14.0', 'amp_15.0',
#        'amp_16.0', 'amp_17.0', 'amp_18.0', 'signal_dominant_frequency',
#        'signal_dominant_amplitude', 'noise_max_amplitude',
#        'signal_max_amplitude', 'signal_variance', 'noise_variance',
#        'source_receiver_distance_logkm', 'source_depth_km',
#        'sin_receiver_back_azimuth'],
#       dtype='object')

# %%
# Find best features for whole training dataset
estimator = SVR(kernel="linear")
selector = RFE(estimator, n_features_to_select=8, step=1)
selector = selector.fit(train_feat_matrix_scaled[:, :-1], train_y)

train_feat_df.columns[:-1][selector.support_]
# Out:
# Index(['amp_08.0', 'amp_10.0', 'amp_12.0', 'amp_14.0', 'amp_17.0',
#        'signal_max_amplitude', 'signal_variance',
#        'source_receiver_distance_logkm'],
#       dtype='object')

# %%
# Sort features by importance - first 8 are in no particular order
train_feat_df.columns[:-1][np.argsort(selector.ranking_)]
# Out:
# Index(['amp_10.0', 'source_receiver_distance_logkm', 'signal_variance',
#        'amp_08.0', 'signal_max_amplitude', 'amp_12.0', 'amp_17.0', 'amp_14.0',
#        'amp_16.0', 'amp_09.0', 'amp_15.0', 'sin_receiver_back_azimuth',
#        'amp_ratio_13.0', 'amp_ratio_11.0', 'amp_ratio_15.0', 'amp_ratio_17.0',
#        'amp_13.0', 'amp_ratio_18.0', 'amp_01.0', 'amp_ratio_14.0',
#        'amp_ratio_12.0', 'amp_ratio_09.0', 'amp_ratio_08.0', 'amp_ratio_04.0',
#        'amp_03.0', 'amp_02.0', 'noise_max_amplitude', 'amp_04.0', 'amp_05.0',
#        'amp_06.0', 'amp_ratio_06.0', 'amp_ratio_10.0', 'amp_ratio_05.0',
#        'amp_ratio_16.0', 'signal_dominant_amplitude', 'amp_07.0', 'amp_18.0',
#        'noise_variance', 'source_depth_km', 'amp_ratio_07.0', 'amp_ratio_02.0',
#        'signal_dominant_frequency', 'amp_11.0', 'amp_ratio_01.0',
#        'amp_ratio_03.0'],
#       dtype='object')

# %%
# Training performace with these 8 features in the linear model 
r2_score(selector.predict(train_feat_matrix_scaled[:, :-1]), train_y)
# Out:
# 0.7059357075861596

# %%
# CV performace with these 8 features in non-linear model
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:, :-1][:, selector.support_], train_y, cv=folds, scoring="r2")
# Out:
# {'fit_time': array([0.13190055, 0.12183785, 0.12049961, 0.1208148 , 0.1222949 ]),
#  'score_time': array([0.02505231, 0.02551985, 0.02493548, 0.02516341, 0.02559495]),
#  'test_score': array([0.79715922, 0.83508992, 0.78960079, 0.77405805, 0.82947324])}

# %%
# Get best RFE features for various folds and evaluate 
for fold in folds:
    # Pipeline for choosing features for fold
    estimator = SVR(kernel="linear")
    selector = RFE(estimator, n_features_to_select=8, step=1)
    pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('selector', selector)])
    
    # Fold data - exclude receiver_back_azimuth since linear model
    cv_train_X = train_feat_matrix_unscaled[fold[0], :-1]
    cv_train_y = train_y[fold[0]]
    cv_test_X = train_feat_matrix_unscaled[fold[1], :-1]
    cv_test_y = train_y[fold[1]]
    
    # Fit selector to fold training data
    s = pipeline.fit(cv_train_X, cv_train_y)
    # Make predictions on the fold test data
    preds = s.predict(cv_test_X)
    # Get the features for this model
    support = s.named_steps.selector.support_
    # Print the features
    print(train_feat_df.columns[:-1][support])
    # Print the test R^2 score
    print("Linear performance:", r2_score(cv_test_y, preds))
    
    # Use this features in a non-linear model. Cross validate over all the folds
    svr = SVR(C=1.0, epsilon=0.2)
    nl_pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
    rbf_cv = cross_validate(nl_pipeline, train_feat_matrix_unscaled[:, :-1][:, support],
                         train_y, cv=folds, scoring="r2")["test_score"]
    print(rbf_cv)
    print(np.mean(rbf_cv))
# Out:
# Index(['amp_08.0', 'amp_09.0', 'amp_10.0', 'amp_17.0', 'amp_18.0',
#        'signal_max_amplitude', 'signal_variance',
#        'source_receiver_distance_logkm'],
#       dtype='object')
# Linear performance: 0.7482715942041789
# [0.79734053 0.8351975  0.78952042 0.77718745 0.82944375]
# 0.8057379306158907
# Index(['amp_09.0', 'amp_10.0', 'amp_15.0', 'amp_17.0', 'signal_max_amplitude',
#        'signal_variance', 'source_receiver_distance_logkm',
#        'sin_receiver_back_azimuth'],
#       dtype='object')
# Linear performance: 0.7707502878726004
# [0.84864959 0.87941939 0.85044419 0.83090288 0.86379768]
# 0.8546427447241809
# Index(['amp_08.0', 'amp_12.0', 'amp_14.0', 'amp_16.0', 'amp_17.0',
#        'signal_max_amplitude', 'signal_variance',
#        'source_receiver_distance_logkm'],
#       dtype='object')
# Linear performance: 0.6722077070212156
# [0.79576165 0.83360737 0.78835157 0.77126259 0.82993089]
# 0.8037828150754885
# Index(['amp_ratio_12.0', 'amp_ratio_13.0', 'amp_09.0', 'amp_10.0', 'amp_18.0',
#        'signal_max_amplitude', 'signal_variance',
#        'source_receiver_distance_logkm'],
#       dtype='object')
# Linear performance: 0.7531506319486945
# [0.79508046 0.82684587 0.78078823 0.77487446 0.81926555]
# 0.7993709112721571
# Index(['amp_ratio_10.0', 'amp_ratio_11.0', 'amp_08.0', 'amp_10.0', 'amp_18.0',
#        'signal_max_amplitude', 'signal_variance',
#        'source_receiver_distance_logkm'],
#       dtype='object')
# Linear performance: 0.7737082599753546
# [0.79729833 0.83282397 0.78372386 0.78907656 0.82306296]
# 0.8051971363365815

# %% [markdown]
# ## Sequential Feature Selection.
# Forward selection until change in score is less than 1e-4 or reach half of the features. Slightly better CV performace with 13 features than 46 for non-linear SVR. Pretty comparable performace between the 13 and 46 features in linear SVR.

# %%
no_sin_ba_feat_inds = np.delete(np.arange(train_feat_matrix_unscaled.shape[1]), -2)

# %%
train_feat_df.columns[no_sin_ba_feat_inds]
# Out:
# Index(['amp_ratio_01.0', 'amp_ratio_02.0', 'amp_ratio_03.0', 'amp_ratio_04.0',
#        'amp_ratio_05.0', 'amp_ratio_06.0', 'amp_ratio_07.0', 'amp_ratio_08.0',
#        'amp_ratio_09.0', 'amp_ratio_10.0', 'amp_ratio_11.0', 'amp_ratio_12.0',
#        'amp_ratio_13.0', 'amp_ratio_14.0', 'amp_ratio_15.0', 'amp_ratio_16.0',
#        'amp_ratio_17.0', 'amp_ratio_18.0', 'amp_01.0', 'amp_02.0', 'amp_03.0',
#        'amp_04.0', 'amp_05.0', 'amp_06.0', 'amp_07.0', 'amp_08.0', 'amp_09.0',
#        'amp_10.0', 'amp_11.0', 'amp_12.0', 'amp_13.0', 'amp_14.0', 'amp_15.0',
#        'amp_16.0', 'amp_17.0', 'amp_18.0', 'signal_dominant_frequency',
#        'signal_dominant_amplitude', 'noise_max_amplitude',
#        'signal_max_amplitude', 'signal_variance', 'noise_variance',
#        'source_receiver_distance_logkm', 'source_depth_km',
#        'receiver_back_azimuth'],
#       dtype='object')

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
sfs = SequentialFeatureSelector(pipeline, n_features_to_select="auto", tol=1e-3, scoring="r2", 
                                cv=folds, n_jobs=3).fit(train_feat_matrix_unscaled[:,no_sin_ba_feat_inds], train_y)

sfs.get_feature_names_out(train_feat_df.columns[no_sin_ba_feat_inds])
# Out:
# array(['amp_ratio_04.0', 'amp_01.0', 'signal_max_amplitude',
#        'signal_variance', 'source_receiver_distance_logkm',
#        'receiver_back_azimuth'], dtype=object)

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:,no_sin_ba_feat_inds][:, sfs.get_support()], train_y, cv=folds)
# Out:
# {'fit_time': array([0.11975741, 0.10936785, 0.10206532, 0.1037786 , 0.10258627]),
#  'score_time': array([0.02107215, 0.01908302, 0.01928496, 0.01967454, 0.01910114]),
#  'test_score': array([0.86771592, 0.87616745, 0.85774425, 0.84854197, 0.864626  ])}

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
sfs = SequentialFeatureSelector(pipeline, n_features_to_select="auto", tol=1e-4, scoring="r2", 
                                cv=folds, n_jobs=3).fit(train_feat_matrix_unscaled[:,no_sin_ba_feat_inds], train_y)

sfs.get_feature_names_out(train_feat_df.columns[no_sin_ba_feat_inds])
# Out:
# array(['amp_ratio_04.0', 'amp_01.0', 'amp_02.0', 'amp_03.0', 'amp_09.0',
#        'amp_15.0', 'amp_18.0', 'signal_dominant_amplitude',
#        'signal_max_amplitude', 'signal_variance',
#        'source_receiver_distance_logkm', 'source_depth_km',
#        'receiver_back_azimuth'], dtype=object)

# %%
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:,no_sin_ba_feat_inds][:, sfs.get_support()], train_y, cv=folds)
# Out:
# {'fit_time': array([0.12783909, 0.1191442 , 0.11400723, 0.11158729, 0.11267567]),
#  'score_time': array([0.02513504, 0.02243304, 0.02280164, 0.02245593, 0.02235889]),
#  'test_score': array([0.87087679, 0.88075554, 0.86449167, 0.85738333, 0.87236972])}

# %%
# Performance when using all features
svr = SVR(C=1.0, epsilon=0.2)
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
cross_validate(pipeline, train_feat_matrix_unscaled[:, no_sin_ba_feat_inds], train_y, cv=folds)
# Out:
# {'fit_time': array([0.16392374, 0.15131593, 0.15170336, 0.1534512 , 0.15095425]),
#  'score_time': array([0.03496695, 0.03550553, 0.03569698, 0.03497982, 0.03533411]),
#  'test_score': array([0.85578627, 0.86341574, 0.84051301, 0.84432444, 0.85234434])}

# %% [markdown]
# ## Sequential Feature Selection Linear

# %%
svr = SVR(C=1.0, epsilon=0.2, kernel="linear")
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
sfs = SequentialFeatureSelector(pipeline, n_features_to_select="auto", tol=1e-3, scoring="r2", 
                                cv=folds, n_jobs=3).fit(train_feat_matrix_unscaled[:,:-1], train_y)

sfs.get_feature_names_out(train_feat_df.columns[:-1])
# Out:
# array(['amp_01.0', 'amp_18.0', 'signal_max_amplitude', 'signal_variance',
#        'source_receiver_distance_logkm', 'sin_receiver_back_azimuth'],
#       dtype=object)

# %%
svr = SVR(C=1.0, epsilon=0.2, kernel="linear")
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
all_feats_rbf_cv = cross_validate(pipeline, train_feat_matrix_unscaled[:,no_sin_ba_feat_inds][:, sfs.get_support()], train_y, cv=folds)
print(all_feats_rbf_cv["test_score"])
print(np.mean(all_feats_rbf_cv['test_score']))
# Out:
# [0.77591202 0.7791437  0.71958385 0.78573314 0.80274157]
# 0.7726228564826051

# %% [markdown]
# # Go more in-depth into the effect of the more important features

# %%
selected_features_sr = ['amp_02.0', 'amp_04.0', 'amp_07.0', 'amp_10.0', 'amp_ratio_01.0',
                       'signal_dominant_amplitude', 'signal_variance', 'noise_variance', 
                       'source_receiver_distance_logkm', 'noise_max_amplitude', 'signal_max_amplitude',
                       'receiver_back_azimuth', 'source_depth_km']

fewer_features_sr = ['amp_02.0','signal_max_amplitude', 'signal_variance', 'noise_variance', 
                       'source_receiver_distance_logkm', 'noise_max_amplitude', 'receiver_back_azimuth', 
                     'source_depth_km' ]

# %%
def svr_cv(X, y, folds, kernel="rbf", C=1.0, epsilon=0.2, degree=3):
    svr = SVR(C=C, epsilon=epsilon, kernel=kernel, degree=degree)
    pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', svr)])
    cv_scores = cross_validate(pipeline, X, y, scoring="r2", cv=folds)["test_score"]
    
    return cv_scores

# %%
def seq_feature_importance(selected_features, train_feat_df_unscaled, starting_features=None, kernel="rbf"):
    feat_selection = np.copy(selected_features)
    r2_maxs = []
    r2_mins = []
    r2_means = []
    
    best_features = []
    
    plot_start_ind = 1
    if starting_features is not None:
        best_features = starting_features
        train_X = train_feat_df_unscaled[best_features].values
        cv_scores = svr_cv(train_X, train_y, folds, kernel=kernel)
        mean_cv = np.mean(cv_scores)
        print(best_features, mean_cv)
        r2_means.append(mean_cv)
        r2_mins.append(mean_cv)
        r2_maxs.append(mean_cv)
        plot_start_ind = 0

    for it in range(len(selected_features)):
        print("iteration", it)
        print(best_features)

        it_r2_vals = []
    #     best_feat_ind = -1

        for feature_ind in range(len(feat_selection)):
            features = [feat_selection[feature_ind]]
            if len(best_features) == 0:
                train_X = train_feat_df_unscaled[features].values.reshape(-1, 1)
            else:
                features = np.concatenate([best_features, features])
                train_X = train_feat_df_unscaled[features].values

            cv_scores = svr_cv(train_X, train_y, folds, kernel=kernel)

            mean_cv = np.mean(cv_scores)
            print(features[-1], mean_cv)
    #         if mean_cv > max_r2:
    #             best_feat_ind = feature_ind
    #             max_r2 = mean_cv

            it_r2_vals.append(mean_cv)

        best_feat_ind = np.argmax(it_r2_vals)
        best_features.append(feat_selection[best_feat_ind])
        r2_means.append(np.mean(it_r2_vals))
        r2_mins.append(np.min(it_r2_vals))
        r2_maxs.append(np.max(it_r2_vals))

        feat_selection = np.delete(feat_selection, best_feat_ind)

    
    n_features = np.arange(plot_start_ind, len(selected_features)+1)
    plt.plot(n_features, r2_means, linestyle="--", color="k", label="mean")
    plt.plot(n_features, r2_mins, color="k", label="min")
    plt.fill_between(n_features, r2_maxs, r2_mins, color="gray")
    plt.plot(n_features, r2_maxs, marker="x", color="r", label="max")
    plt.xticks(n_features) #, labels=n_features[::-1]) #, labels=best_features, rotation=45);
    plt.grid()
    plt.xlabel("N Features") #("N Features to Choose From");
    plt.ylabel(r"Mean $R^2$ of 5-fold CV");
    plt.legend();
    
    return best_features

# %%
best_features_sr = seq_feature_importance(selected_features_sr, train_feat_df_unscaled)
best_features_sr
# Out:
# iteration 0
# []
# amp_02.0 0.4993858764538281
# amp_04.0 0.46259876733844585
# amp_07.0 0.3855661112629467
# amp_10.0 0.3506770542820277
# amp_ratio_01.0 0.22510076138025314
# signal_dominant_amplitude 0.36681181139138586
# signal_variance 0.3746639489645974
# noise_variance 0.04485051948589658
# source_receiver_distance_logkm 0.06437025611183389
# noise_max_amplitude 0.03788297274917796
# signal_max_amplitude 0.34086954145207715
# receiver_back_azimuth 0.07784259899354788
# source_depth_km -0.01201253449593367
# iteration 1
# ['amp_02.0']
# amp_04.0 0.5199832346136894
# amp_07.0 0.5227393968718828
# amp_10.0 0.541122266758895
# amp_ratio_01.0 0.5158883695178295
# signal_dominant_amplitude 0.5121034650278086
# signal_variance 0.5270111576879017
# noise_variance 0.4924670346546022
# source_receiver_distance_logkm 0.7374685167970382
# noise_max_amplitude 0.49409664687758337
# signal_max_amplitude 0.5196872029194959
# receiver_back_azimuth 0.6020654178970094
# source_depth_km 0.5504053597575058
# iteration 2
# ['amp_02.0', 'source_receiver_distance_logkm']
# amp_04.0 0.7828120699787945
# amp_07.0 0.8002272618782843
# amp_10.0 0.8043252078171917
# amp_ratio_01.0 0.7418001441715031
# signal_dominant_amplitude 0.7941866016442286
# signal_variance 0.8037847711886309
# noise_variance 0.7370613105219184
# noise_max_amplitude 0.739330215249902
# signal_max_amplitude 0.7906192259120897
# receiver_back_azimuth 0.7761355634913378
# source_depth_km 0.7382052141053507
# iteration 3
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0']
# amp_04.0 0.8124027739254833
# amp_07.0 0.8144559444609246
# amp_ratio_01.0 0.8080212492310528
# signal_dominant_amplitude 0.8082903498981848
# signal_variance 0.8083591352994315
# noise_variance 0.8006590647924373
# noise_max_amplitude 0.8030672173868367
# signal_max_amplitude 0.8063561484301228
# receiver_back_azimuth 0.8550726370276642
# source_depth_km 0.8133127508022142
# iteration 4
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth']
# amp_04.0 0.8533809083651646
# amp_07.0 0.8540133591837143
# amp_ratio_01.0 0.8566410252010732
# signal_dominant_amplitude 0.8553035220778853
# signal_variance 0.8557322949201863
# noise_variance 0.8469141961941103
# noise_max_amplitude 0.847443706930506
# signal_max_amplitude 0.8555996834266091
# source_depth_km 0.8558458907784849
# iteration 5
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'amp_ratio_01.0']
# amp_04.0 0.8554175038557845
# amp_07.0 0.8552815430955818
# signal_dominant_amplitude 0.8568048287972561
# signal_variance 0.857884651554599
# noise_variance 0.8492573638964427
# noise_max_amplitude 0.8492312448275572
# signal_max_amplitude 0.8573737717199694
# source_depth_km 0.8561957830370774
# iteration 6
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'amp_ratio_01.0', 'signal_variance']
# amp_04.0 0.8564794183735515
# amp_07.0 0.8568109248854789
# signal_dominant_amplitude 0.8623047354527813
# noise_variance 0.8510567463919839
# noise_max_amplitude 0.8509375766474732
# signal_max_amplitude 0.8645638102672439
# source_depth_km 0.8588180171307531
# iteration 7
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'amp_ratio_01.0', 'signal_variance', 'signal_max_amplitude']
# amp_04.0 0.8633177765377488
# amp_07.0 0.8634181556189097
# signal_dominant_amplitude 0.8637126255136323
# noise_variance 0.8577542696309134
# noise_max_amplitude 0.8573826408916864
# source_depth_km 0.8653334230160056
# iteration 8
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'amp_ratio_01.0', 'signal_variance', 'signal_max_amplitude', 'source_depth_km']
# amp_04.0 0.8651897049697228
# amp_07.0 0.8654418198551189
# signal_dominant_amplitude 0.8652540972046531
# noise_variance 0.8579722305700372
# noise_max_amplitude 0.8570101660258354
# iteration 9
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'amp_ratio_01.0', 'signal_variance', 'signal_max_amplitude', 'source_depth_km', 'amp_07.0']
# amp_04.0 0.8650223749761065
# signal_dominant_amplitude 0.8650627027484751
# noise_variance 0.8585112039481524
# noise_max_amplitude 0.8572337415612804
# iteration 10
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'amp_ratio_01.0', 'signal_variance', 'signal_max_amplitude', 'source_depth_km', 'amp_07.0', 'signal_dominant_amplitude']
# amp_04.0 0.8651172646233002
# noise_variance 0.8594172604773871
# noise_max_amplitude 0.8579515508827618
# iteration 11
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'amp_ratio_01.0', 'signal_variance', 'signal_max_amplitude', 'source_depth_km', 'amp_07.0', 'signal_dominant_amplitude', 'amp_04.0']
# noise_variance 0.8595121052817143
# noise_max_amplitude 0.8579185567590185
# iteration 12
# ['amp_02.0', 'source_receiver_distance_logkm', 'amp_10.0', 'receiver_back_azimuth', 'amp_ratio_01.0', 'signal_variance', 'signal_max_amplitude', 'source_depth_km', 'amp_07.0', 'signal_dominant_amplitude', 'amp_04.0', 'noise_variance']
# noise_max_amplitude 0.8561596772315916
# ['amp_02.0',
#  'source_receiver_distance_logkm',
#  'amp_10.0',
#  'receiver_back_azimuth',
#  'amp_ratio_01.0',
#  'signal_variance',
#  'signal_max_amplitude',
#  'source_depth_km',
#  'amp_07.0',
#  'signal_dominant_amplitude',
#  'amp_04.0',
#  'noise_variance',
#  'noise_max_amplitude']

# %%
# All selected features with sr distance and back azimuth
selected_feat_sr_cv = svr_cv(train_feat_df_unscaled[selected_features_sr], train_y, folds)
print(selected_feat_sr_cv)
print(np.mean(selected_feat_sr_cv))
# Out:
# [0.86503917 0.86299468 0.84724824 0.85266515 0.85285115]
# 0.8561596772315918

# %%
# Top 4 selected features with sr distance and back azimuth
top_feat_sr_cv = svr_cv(train_feat_df_unscaled[best_features_sr[0:4]], train_y, folds)
print(top_feat_sr_cv )
print(np.mean(top_feat_sr_cv))
# Out:
# [0.84691445 0.87412196 0.84704875 0.84469488 0.86258314]
# 0.8550726370276642

# %%
best_fewer_features_sr = seq_feature_importance(fewer_features_sr, train_feat_df_unscaled)
best_fewer_features_sr
# Out:
# iteration 0
# []
# amp_02.0 0.4993858764538281
# signal_max_amplitude 0.34086954145207715
# signal_variance 0.3746639489645974
# noise_variance 0.04485051948589658
# source_receiver_distance_logkm 0.06437025611183389
# noise_max_amplitude 0.03788297274917796
# receiver_back_azimuth 0.07784259899354788
# source_depth_km -0.01201253449593367
# iteration 1
# ['amp_02.0']
# signal_max_amplitude 0.5196872029194959
# signal_variance 0.5270111576879017
# noise_variance 0.4924670346546022
# source_receiver_distance_logkm 0.7374685167970382
# noise_max_amplitude 0.49409664687758337
# receiver_back_azimuth 0.6020654178970094
# source_depth_km 0.5504053597575058
# iteration 2
# ['amp_02.0', 'source_receiver_distance_logkm']
# signal_max_amplitude 0.7906192259120897
# signal_variance 0.8037847711886309
# noise_variance 0.7370613105219184
# noise_max_amplitude 0.739330215249902
# receiver_back_azimuth 0.7761355634913378
# source_depth_km 0.7382052141053507
# iteration 3
# ['amp_02.0', 'source_receiver_distance_logkm', 'signal_variance']
# signal_max_amplitude 0.8119444333980324
# noise_variance 0.8020825144404229
# noise_max_amplitude 0.8029244541648689
# receiver_back_azimuth 0.8533156936409568
# source_depth_km 0.8135928063677611
# iteration 4
# ['amp_02.0', 'source_receiver_distance_logkm', 'signal_variance', 'receiver_back_azimuth']
# signal_max_amplitude 0.8621133956085553
# noise_variance 0.8460921797830215
# noise_max_amplitude 0.8469164727440164
# source_depth_km 0.8566992091863284
# iteration 5
# ['amp_02.0', 'source_receiver_distance_logkm', 'signal_variance', 'receiver_back_azimuth', 'signal_max_amplitude']
# noise_variance 0.8544483649683674
# noise_max_amplitude 0.854463377346948
# source_depth_km 0.8654496102177482
# iteration 6
# ['amp_02.0', 'source_receiver_distance_logkm', 'signal_variance', 'receiver_back_azimuth', 'signal_max_amplitude', 'source_depth_km']
# noise_variance 0.8558482788281376
# noise_max_amplitude 0.8553451022432881
# iteration 7
# ['amp_02.0', 'source_receiver_distance_logkm', 'signal_variance', 'receiver_back_azimuth', 'signal_max_amplitude', 'source_depth_km', 'noise_variance']
# noise_max_amplitude 0.8549984946744175
# ['amp_02.0',
#  'source_receiver_distance_logkm',
#  'signal_variance',
#  'receiver_back_azimuth',
#  'signal_max_amplitude',
#  'source_depth_km',
#  'noise_variance',
#  'noise_max_amplitude']

# %%
# All fewer features
fewer_feat_sr_cv = svr_cv(train_feat_df_unscaled[fewer_features_sr], train_y, folds)
print(fewer_feat_sr_cv)
print(np.mean(fewer_feat_sr_cv))
# Out:
# [0.86990836 0.86113769 0.8477753  0.84791865 0.84825247]
# 0.8549984946744177

# %%
# Top 4 fewer features
top_fewer_feat_sr_cv = svr_cv(train_feat_df_unscaled[best_fewer_features_sr[0:4]], train_y, folds)
print(top_fewer_feat_sr_cv)
print(np.mean(top_fewer_feat_sr_cv))
# Out:
# [0.8511067  0.87329808 0.84581042 0.83821125 0.85815202]
# 0.8533156936409568

# %%
selected_feat_df = train_feat_df.copy()[selected_features_sr]
selected_feat_df.loc[:, "magnitude"] = train_y
corr = selected_feat_df.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_7a3ba_row0_col0, #T_7a3ba_row1_col1, #T_7a3ba_row2_col2, #T_7a3ba_row3_col3, #T_7a3ba_row4_col4, #T_7a3ba_row5_col5, #T_7a3ba_row6_col6, #T_7a3ba_row7_col7, #T_7a3ba_row8_col8, #T_7a3ba_row9_col9, #T_7a3ba_row10_col10, #T_7a3ba_row11_col11, #T_7a3ba_row12_col12, #T_7a3ba_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7a3ba_row0_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_7a3ba_row0_col2 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_7a3ba_row0_col3, #T_7a3ba_row5_col0 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_7a3ba_row0_col4 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_7a3ba_row0_col5 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_7a3ba_row0_col6 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_7a3ba_row0_col7, #T_7a3ba_row1_col9 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_7a3ba_row0_col8, #T_7a3ba_row6_col11 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_7a3ba_row0_col9 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_7a3ba_row0_col10, #T_7a3ba_row6_col0 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_7a3ba_row0_col11, #T_7a3ba_row0_col12, #T_7a3ba_row4_col7, #T_7a3ba_row8_col0, #T_7a3ba_row8_col1, #T_7a3ba_row8_col2, #T_7a3ba_row8_col3, #T_7a3ba_row8_col5, #T_7a3ba_row8_col6, #T_7a3ba_row8_col9, #T_7a3ba_row8_col10, #T_7a3ba_row10_col8, #T_7a3ba_row11_col4, #T_7a3ba_row11_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7a3ba_row0_col13, #T_7a3ba_row13_col2, #T_7a3ba_row13_col6 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_7a3ba_row1_col0 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_7a3ba_row1_col2, #T_7a3ba_row2_col1, #T_7a3ba_row2_col5, #T_7a3ba_row3_col5, #T_7a3ba_row5_col2, #T_7a3ba_row5_col3 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_7a3ba_row1_col3, #T_7a3ba_row1_col5, #T_7a3ba_row5_col1, #T_7a3ba_row10_col1 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_7a3ba_row1_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_7a3ba_row1_col6 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_7a3ba_row1_col7 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_7a3ba_row1_col8, #T_7a3ba_row1_col11, #T_7a3ba_row9_col12 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_7a3ba_row1_col10 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_7a3ba_row1_col12 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_7a3ba_row1_col13 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_7a3ba_row2_col0 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_7a3ba_row2_col3, #T_7a3ba_row3_col2, #T_7a3ba_row3_col10, #T_7a3ba_row10_col3 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_7a3ba_row2_col4, #T_7a3ba_row4_col13, #T_7a3ba_row13_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_7a3ba_row2_col6, #T_7a3ba_row6_col2, #T_7a3ba_row7_col9, #T_7a3ba_row9_col7 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_7a3ba_row2_col7, #T_7a3ba_row5_col7, #T_7a3ba_row6_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_7a3ba_row2_col8, #T_7a3ba_row3_col8, #T_7a3ba_row4_col9, #T_7a3ba_row5_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_7a3ba_row2_col9, #T_7a3ba_row3_col7, #T_7a3ba_row5_col9 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_7a3ba_row2_col10, #T_7a3ba_row10_col2 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_7a3ba_row2_col11, #T_7a3ba_row11_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_7a3ba_row2_col12, #T_7a3ba_row4_col12 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_7a3ba_row2_col13 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_7a3ba_row3_col0 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_7a3ba_row3_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_7a3ba_row3_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_7a3ba_row3_col6, #T_7a3ba_row6_col3 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_7a3ba_row3_col9, #T_7a3ba_row9_col13 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_7a3ba_row3_col11 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_7a3ba_row3_col12, #T_7a3ba_row4_col11, #T_7a3ba_row7_col12 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_7a3ba_row3_col13 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_7a3ba_row4_col0 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_7a3ba_row4_col1, #T_7a3ba_row4_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_7a3ba_row4_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_7a3ba_row4_col5 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_7a3ba_row4_col6 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_7a3ba_row4_col8, #T_7a3ba_row11_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_7a3ba_row4_col10 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_7a3ba_row5_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_7a3ba_row5_col6, #T_7a3ba_row5_col10, #T_7a3ba_row6_col5, #T_7a3ba_row6_col10, #T_7a3ba_row10_col5, #T_7a3ba_row10_col6 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_7a3ba_row5_col11 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_7a3ba_row5_col12, #T_7a3ba_row12_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_7a3ba_row5_col13 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_7a3ba_row6_col1 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_7a3ba_row6_col4, #T_7a3ba_row7_col1, #T_7a3ba_row9_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_7a3ba_row6_col8 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_7a3ba_row6_col9, #T_7a3ba_row7_col13, #T_7a3ba_row10_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_7a3ba_row6_col12, #T_7a3ba_row10_col12 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_7a3ba_row6_col13 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_7a3ba_row7_col0, #T_7a3ba_row9_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_7a3ba_row7_col2, #T_7a3ba_row7_col6, #T_7a3ba_row9_col2, #T_7a3ba_row9_col5, #T_7a3ba_row9_col6, #T_7a3ba_row9_col10 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_7a3ba_row7_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_7a3ba_row7_col4, #T_7a3ba_row12_col9 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_7a3ba_row7_col5, #T_7a3ba_row7_col10, #T_7a3ba_row9_col3 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_7a3ba_row7_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_7a3ba_row7_col11, #T_7a3ba_row9_col11 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_7a3ba_row8_col4, #T_7a3ba_row8_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_7a3ba_row8_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_7a3ba_row8_col12, #T_7a3ba_row12_col11 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_7a3ba_row8_col13 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_7a3ba_row9_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_7a3ba_row9_col8, #T_7a3ba_row11_col10 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_7a3ba_row10_col0 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_7a3ba_row10_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_7a3ba_row10_col9 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_7a3ba_row10_col11 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_7a3ba_row10_col13 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_7a3ba_row11_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_7a3ba_row11_col1, #T_7a3ba_row12_col13 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_7a3ba_row11_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_7a3ba_row11_col3 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_7a3ba_row11_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_7a3ba_row11_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_7a3ba_row11_col9, #T_7a3ba_row13_col11 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_7a3ba_row11_col12 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_7a3ba_row12_col0 {
#   b

# %% [markdown]
# ## Add required starting features

# %%
additional_features_sr = ['amp_02.0', 'amp_04.0', 'amp_07.0', 'amp_10.0', 'amp_ratio_01.0',
                       'signal_max_amplitude', 'signal_variance', 'noise_variance', 'noise_max_amplitude']
starting_features = ['source_receiver_distance_logkm','receiver_back_azimuth', 'source_depth_km']
best_features_with_start = seq_feature_importance(additional_features_sr, train_feat_df_unscaled,
                                                  starting_features=starting_features)
best_features_with_start
# Out:
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km'] 0.17760700785844558
# iteration 0
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km']
# amp_02.0 0.7829791734152056
# amp_04.0 0.8051819601078348
# amp_07.0 0.8306751834967614
# amp_10.0 0.8391881007540493
# amp_ratio_01.0 0.3717119338907902
# signal_max_amplitude 0.8078800224108778
# signal_variance 0.8432680935111037
# noise_variance 0.21528664780711573
# noise_max_amplitude 0.21352083282715517
# iteration 1
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance']
# amp_02.0 0.8566992091863282
# amp_04.0 0.8483225366571896
# amp_07.0 0.8468867029164651
# amp_10.0 0.8450615274784472
# amp_ratio_01.0 0.8437457372098753
# signal_max_amplitude 0.8536400714217234
# noise_variance 0.8335632383816935
# noise_max_amplitude 0.8342248711398291
# iteration 2
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0']
# amp_04.0 0.8563956258444276
# amp_07.0 0.8561630446840557
# amp_10.0 0.8585686002386099
# amp_ratio_01.0 0.8572091755176687
# signal_max_amplitude 0.8654496102177479
# noise_variance 0.8475159359222826
# noise_max_amplitude 0.8471416630396655
# iteration 3
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude']
# amp_04.0 0.8641736612919644
# amp_07.0 0.8642861825665541
# amp_10.0 0.8653115591878787
# amp_ratio_01.0 0.8649166039612401
# noise_variance 0.8558482788281374
# noise_max_amplitude 0.8553451022432881
# iteration 4
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'amp_10.0']
# amp_04.0 0.8649812908737136
# amp_07.0 0.865158439755407
# amp_ratio_01.0 0.8653334230160056
# noise_variance 0.8557958108180233
# noise_max_amplitude 0.854875677119543
# iteration 5
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'amp_10.0', 'amp_ratio_01.0']
# amp_04.0 0.8651897049697228
# amp_07.0 0.8654418198551191
# noise_variance 0.8579722305700374
# noise_max_amplitude 0.8570101660258354
# iteration 6
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'amp_10.0', 'amp_ratio_01.0', 'amp_07.0']
# amp_04.0 0.8650223749761065
# noise_variance 0.8585112039481523
# noise_max_amplitude 0.8572337415612802
# iteration 7
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'amp_10.0', 'amp_ratio_01.0', 'amp_07.0', 'amp_04.0']
# noise_variance 0.858943391777033
# noise_max_amplitude 0.8574661986931013
# iteration 8
# ['source_receiver_distance_logkm', 'receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'amp_10.0', 'amp_ratio_01.0', 'amp_07.0', 'amp_04.0', 'noise_variance']
# noise_max_amplitude 0.8557061005587002
# ['source_receiver_distance_logkm',
#  'receiver_back_azimuth',
#  'source_depth_km',
#  'signal_variance',
#  'amp_02.0',
#  'signal_max_amplitude',
#  'amp_10.0',
#  'amp_ratio_01.0',
#  'amp_07.0',
#  'amp_04.0',
#  'noise_variance',
#  'noise_max_amplitude']

# %%
np.mean(svr_cv(train_feat_df_unscaled[best_features_with_start[0:4]], train_y, folds))
# Out:
# 0.8432680935111037

# %%
np.mean(svr_cv(train_feat_df_unscaled[best_features_with_start[0:5]], train_y, folds))
# Out:
# 0.8566992091863282

# %% [markdown]
# ## Require starting features - linear model

# %%
additional_features_sr = ['amp_02.0', 'amp_04.0', 'amp_07.0', 'amp_10.0', 'amp_ratio_01.0',
                       'signal_max_amplitude', 'signal_dominant_frequency', 'signal_variance', 
                          'noise_variance', 'noise_max_amplitude', 'signal_max_amplitude']
starting_features = ['source_receiver_distance_logkm','sin_receiver_back_azimuth', 'source_depth_km']
best_features_with_start_linear = seq_feature_importance(additional_features_sr, train_feat_df_unscaled,
                                                  starting_features=starting_features, kernel="linear")
best_features_with_start_linear
# Out:
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km'] 0.07470763626832358
# iteration 0
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km']
# amp_02.0 0.6856092799758372
# amp_04.0 0.7198639405836682
# amp_07.0 0.7169139593638786
# amp_10.0 0.708174466229684
# amp_ratio_01.0 0.2826458953966905
# signal_max_amplitude 0.6897191002314556
# signal_dominant_frequency 0.09213358918881102
# signal_variance 0.7315964198925986
# noise_variance 0.14121748110967333
# noise_max_amplitude 0.13910896016606247
# signal_max_amplitude 0.6897191002314556
# iteration 1
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'signal_variance']
# amp_02.0 0.752193203960376
# amp_04.0 0.7445535929887975
# amp_07.0 0.7360899124475366
# amp_10.0 0.7321976332038026
# amp_ratio_01.0 0.7390254721151981
# signal_max_amplitude 0.7505613364252229
# signal_dominant_frequency 0.7454601403362081
# noise_variance 0.7336040015337268
# noise_max_amplitude 0.7336953194272668
# signal_max_amplitude 0.7505613364252229
# iteration 2
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0']
# amp_04.0 0.7534915336352983
# amp_07.0 0.7510694218338543
# amp_10.0 0.7517223597624326
# amp_ratio_01.0 0.7533865513432831
# signal_max_amplitude 0.7626567499683038
# signal_dominant_frequency 0.7556068996656812
# noise_variance 0.752616243114857
# noise_max_amplitude 0.7527105340418421
# signal_max_amplitude 0.7626567499683038
# iteration 3
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude']
# amp_04.0 0.7636450785178169
# amp_07.0 0.7611374298119932
# amp_10.0 0.7625246104302551
# amp_ratio_01.0 0.7636067387599036
# signal_dominant_frequency 0.7657931109500371
# noise_variance 0.7639321277520018
# noise_max_amplitude 0.7638236935124547
# signal_max_amplitude 0.7626181285532846
# iteration 4
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'signal_dominant_frequency']
# amp_04.0 0.7664843582012255
# amp_07.0 0.7635592066123053
# amp_10.0 0.7657070659722106
# amp_ratio_01.0 0.7665050323384661
# noise_variance 0.7660702076724533
# noise_max_amplitude 0.7663210188692486
# signal_max_amplitude 0.7657793259291623
# iteration 5
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'signal_dominant_frequency', 'amp_ratio_01.0']
# amp_04.0 0.7675281408358577
# amp_07.0 0.7643316257384477
# amp_10.0 0.7663358711508798
# noise_variance 0.7682297421658155
# noise_max_amplitude 0.768049736826045
# signal_max_amplitude 0.7665058356280918
# iteration 6
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'signal_dominant_frequency', 'amp_ratio_01.0', 'noise_variance']
# amp_04.0 0.7688574395110914
# amp_07.0 0.7669060496627103
# amp_10.0 0.7680993771350224
# noise_max_amplitude 0.7679068354503984
# signal_max_amplitude 0.7681555492994845
# iteration 7
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'signal_dominant_frequency', 'amp_ratio_01.0', 'noise_variance', 'amp_04.0']
# amp_07.0 0.7670297316401306
# amp_10.0 0.7687337759636781
# noise_max_amplitude 0.7686347666390668
# signal_max_amplitude 0.7688567777011315
# iteration 8
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'signal_dominant_frequency', 'amp_ratio_01.0', 'noise_variance', 'amp_04.0', 'signal_max_amplitude']
# amp_07.0 0.7670754208137052
# amp_10.0 0.7687829975915303
# noise_max_amplitude 0.7687701254834254
# iteration 9
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'signal_dominant_frequency', 'amp_ratio_01.0', 'noise_variance', 'amp_04.0', 'signal_max_amplitude', 'amp_10.0']
# amp_07.0 0.7670237403728736
# noise_max_amplitude 0.7685126630867228
# iteration 10
# ['source_receiver_distance_logkm', 'sin_receiver_back_azimuth', 'source_depth_km', 'signal_variance', 'amp_02.0', 'signal_max_amplitude', 'signal_dominant_frequency', 'amp_ratio_01.0', 'noise_variance', 'amp_04.0', 'signal_max_amplitude', 'amp_10.0', 'noise_max_amplitude']
# amp_07.0 0.7667924116975817
# ['source_receiver_distance_logkm',
#  'sin_receiver_back_azimuth',
#  'source_depth_km',
#  'signal_variance',
#  'amp_02.0',
#  'signal_max_amplitude',
#  'signal_dominant_frequency',
#  'amp_ratio_01.0',
#  'noise_variance',
#  'amp_04.0',
#  'signal_max_amplitude',
#  'amp_10.0',
#  'noise_max_amplitude',
#  'amp_07.0']

# %%
np.mean(svr_cv(train_feat_df_unscaled[best_features_with_start_linear[0:4]], train_y, folds, kernel='linear'))
# Out:
# 0.7315964198925986

# %%
np.mean(svr_cv(train_feat_df_unscaled[best_features_with_start_linear[0:6]], train_y, folds, kernel="linear"))
# Out:
# 0.7626567499683038

# %%
linear_features = ['source_receiver_distance_logkm',
 'sin_receiver_back_azimuth',
 'source_depth_km',
 'amp_02.0',
 'noise_max_amplitude',
 'signal_max_amplitude',
 'signal_variance',
 'noise_variance', 
 'amp_ratio_01.0']

np.mean(svr_cv(train_feat_df_unscaled[linear_features], train_y, folds, kernel='linear'))
# Out:
# 0.7662561102400216

# %%
rbf_linear_features = ['source_receiver_distance_logkm',
 'receiver_back_azimuth',
 'source_depth_km',
 'amp_02.0',
 'noise_max_amplitude',
 'signal_max_amplitude',
 'signal_variance',
 'noise_variance', 
 'amp_ratio_01.0']

np.mean(svr_cv(train_feat_df_unscaled[rbf_linear_features], train_y, folds))
# Out:
# 0.855829163394849

# %%
linear_feat_df = train_feat_df.copy()[linear_features]
linear_feat_df.loc[:, "magnitude"] = train_y
corr = linear_feat_df.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_f119d_row0_col0, #T_f119d_row1_col1, #T_f119d_row2_col2, #T_f119d_row3_col3, #T_f119d_row4_col4, #T_f119d_row5_col5, #T_f119d_row6_col6, #T_f119d_row7_col7, #T_f119d_row8_col8, #T_f119d_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f119d_row0_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f119d_row0_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_f119d_row0_col3, #T_f119d_row0_col4, #T_f119d_row0_col5, #T_f119d_row0_col6, #T_f119d_row1_col2, #T_f119d_row2_col1, #T_f119d_row2_col9, #T_f119d_row5_col0, #T_f119d_row7_col8, #T_f119d_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f119d_row0_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f119d_row0_col8, #T_f119d_row6_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_f119d_row0_col9 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_f119d_row1_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f119d_row1_col3, #T_f119d_row4_col3, #T_f119d_row7_col3 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_f119d_row1_col4, #T_f119d_row3_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_f119d_row1_col5 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_f119d_row1_col6, #T_f119d_row8_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_f119d_row1_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_f119d_row1_col8 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_f119d_row1_col9 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_f119d_row2_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_f119d_row2_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_f119d_row2_col4, #T_f119d_row4_col8 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_f119d_row2_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_f119d_row2_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_f119d_row2_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f119d_row2_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_f119d_row3_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_f119d_row3_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_f119d_row3_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_f119d_row3_col5, #T_f119d_row6_col3 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_f119d_row3_col6 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_f119d_row3_col7 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_f119d_row3_col8, #T_f119d_row8_col6 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_f119d_row3_col9 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_f119d_row4_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_f119d_row4_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_f119d_row4_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_f119d_row4_col5, #T_f119d_row4_col6, #T_f119d_row7_col6 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_f119d_row4_col7, #T_f119d_row7_col4 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_f119d_row4_col9, #T_f119d_row5_col2, #T_f119d_row6_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_f119d_row5_col1, #T_f119d_row6_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_f119d_row5_col3 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_f119d_row5_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_f119d_row5_col6, #T_f119d_row6_col5 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_f119d_row5_col7, #T_f119d_row6_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_f119d_row5_col8 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_f119d_row5_col9 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_f119d_row6_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_f119d_row6_col8 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_f119d_row6_col9 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_f119d_row7_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_f119d_row7_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_f119d_row7_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_f119d_row7_col5, #T_f119d_row9_col8 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_f119d_row7_col9 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_f119d_row8_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_f119d_row8_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_f119d_row8_col3 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_f119d_row8_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_f119d_row8_col5 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_f119d_row8_col9 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_f119d_row9_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_f119d_row9_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_f119d_row9_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_f119d_row9_col3 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_f119d_row9_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_f119d_row9_col5 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_f119d_row9_col6 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_f119d_row9_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# </style>
# <table id="T_f119d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f119d_level0_col0" class="col_heading level0 col0" >source_receiver_distance_logkm</th>
#       <th id="T_f119d_level0_col1" class="col_heading level0 col1" >sin_receiver_back_azimuth</th>
#       <th id="T_f119d_level0_col2" class="col_heading level0 col2" >source_depth_km</th>
#       <th id="T_f119d_level0_col3" class="col_heading level0 col3" >amp_02.0</th>
#       <th id="T_f119d_level0_col4" class="col_heading level0 col4" >noise_max_amplitude</th>
#       <th id="T_f119d_level0_col5" class="col_heading level0 col5" >signal_max_amplitude</th>
#       <th id="T_f119d_level0_col6" class="col_heading level0 col6" >signal_variance</th>
#       <th id="T_f119d_level0_col7" class="col_heading level0 col7" >noise_variance</th>
#       <th id="T_f119d_level0_col8" class="col_heading level0 col8" >amp_ratio_01.0</th>
#       <th id="T_f119d_level0_col9" class="col_heading level0 col9" >magnitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f119d_level0_row0" class="row_heading level0 row0" >source_receiver_distance_logkm</th>
#       <td id="T_f119d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f119d_row0_col1" class="data row0 col1" >-0.228444</td>
#       <td id="T_f119d_row0_col2" class="data row0 col2" >0.376358</td>
#       <td id="T_f119d_row0_col3" class="data row0 col3" >-0.396637</td>
#       <td id="T_f119d_row0_col4" class="data row0 col4" >-0.133776</td>
#       <td id="T_f119d_row0_col5" class="data row0 col5" >-0.572683</td>
#       <td id="T_f119d_row0_col6" class="data row0 col6" >-0.561152</td>
#       <td id="T_f119d_row0_col7" class="data row0 col7" >-0.118270</td>
#       <td id="T_f119d_row0_col8" class="data row0 col8" >-0.143740</td>
#       <td id="T_f119d_row0_col9" class="data row0 col9" >0.105633</td>
#     </tr>
#     <tr>
#       <th id="T_f119d_level0_row1" class="row_heading level0 row1" >sin_receiver_back_azimuth</th>
#       <td id="T_f119d_row1_col0" class="data row1 col0" >-0.228444</td>
#       <td id="T_f119d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f119d_row1_col2" class="data row1 col2" >-0.426976</td>
#       <td id="T_f119d_row1_col3" class="data row1 col3" >0.304407</td>
#       <td id="T_f119d_row1_col4" class="data row1 col4" >0.061685</td>
#       <td id="T_f119d_row1_col5" class="data row1 col5" >0.141851</td>
#       <td id="T_f119d_row1_col6" class="data row1 col6" >0.143732</td>
#       <td id="T_f119d_row1_col7" class="data row1 col7" >0.065541</td>
#       <td id="T_f119d_row1_col8" class="data row1 col8" >0.217441</td>
#       <td id="T_f119d_row1_col9" class="data row1 col9" >0.226049</td>
#     </tr>
#     <tr>
#       <th id="

# %%
test_feat_matrix_unscaled = compute_feature_matrix(test_df, scaler=False)
test_feat_matrix_scaled = scaler.transform(test_feat_matrix_unscaled)
test_feat_df_scaled = pd.DataFrame(test_feat_matrix_scaled, columns=columns)
test_y = test_df.magnitude.values

test_feat_df_scaled.head()
# Out:
#    amp_ratio_01.0  amp_ratio_02.0  amp_ratio_03.0  amp_ratio_04.0  \
# 0        0.955886        0.430241       -0.241383        0.083702
# 1        1.851012        0.870117        1.458790        1.217532
# 2        2.191932        0.431322        0.135789        1.417664
# 3        0.746301        0.489838        1.025244        0.935687
# 4       -1.299056        0.038365       -0.712009       -1.135300
#
#    amp_ratio_05.0  amp_ratio_06.0  amp_ratio_07.0  amp_ratio_08.0  \
# 0       -0.634524       -1.107932       -1.121472       -1.054437
# 1        0.543021       -0.358935       -0.687083       -0.752302
# 2        0.964446        0.358174       -0.046167       -0.299052
# 3        1.276084        1.472230        1.427140        1.269113
# 4       -1.433885       -1.451020       -1.406172       -1.378239
#
#    amp_ratio_09.0  amp_ratio_10.0  ...  signal_dominant_frequency  \
# 0       -0.865969       -0.686599  ...                  -2.813620
# 1       -0.756579       -0.719600  ...                  -4.005577
# 2       -0.456541       -0.558794  ...                  -1.621663
# 3        1.058550        1.032382  ...                   0.117917
# 4       -1.450278       -1.547960  ...                  -2.813620
#
#    signal_dominant_amplitude  noise_max_amplitude  signal_max_amplitude  \
# 0                   0.128591             1.642340             -0.179412
# 1                   0.823478             2.182743              0.457769
# 2                   0.297747             1.070615              0.020439
# 3                   0.473416            -1.335316              0.411344
# 4                  -1.534712            -0.470755             -1.533466
#
#    signal_variance  noise_variance  source_receiver_distance_logkm  \
# 0         0.019532        1.674111                        1.496502
# 1         0.751650        1.933880                        1.523481
# 2         0.179574        1.018431                        1.171918
# 3         0.404606       -1.236075                       -1.057140
# 4        -1.635269       -0.503085                        0.565093
#
#    source_depth_km  sin_receiver_back_azimuth  receiver_back_azimuth
# 0         2.006311                  -0.055023              -0.334392
# 1         1.957979                  -0.082828              -0.316395
# 2        -0.912163                   1.118164              -0.967643
# 3        -0.819218                   1.170777              -0.994500
# 4        -0.808065                   2.484076              -1.903849
#
# [5 rows x 46 columns]

# %%
svr_linear = SVR(C=1.0, epsilon=0.1, kernel="linear")
svr_linear.fit(train_feat_df[linear_features], train_y)

y_est_linear = svr_linear.predict(test_feat_df_scaled[linear_features])
linear_test_r2 =r2_score(test_y, y_est_linear) 
print(linear_test_r2)
train_est_linear = svr_linear.predict(train_feat_df[linear_features]) 
print(r2_score(train_y, train_est_linear))
# Out:
# 0.7471587073243664
# 0.7678559625079033

# %%
svr_rbf = SVR(C=1.0, epsilon=0.2, kernel="rbf")
svr_rbf.fit(train_feat_df[rbf_linear_features], train_y)

y_est_rbf = svr_rbf.predict(test_feat_df_scaled[rbf_linear_features])
rbf_test_r2 = r2_score(test_y, y_est_rbf)
print(rbf_test_r2)
train_est_rbf = svr_rbf.predict(train_feat_df[rbf_linear_features]) 
print(r2_score(train_y, train_est_rbf))
# Out:
# 0.8515071014292017
# 0.8938037630056486

# %%
svr_rbf = SVR(C=1.0, epsilon=0.1, kernel="rbf")
svr_rbf.fit(train_feat_df[rbf_linear_features], train_y)

y_est_rbf = svr_rbf.predict(test_feat_df_scaled[rbf_linear_features])
rbf_test_r2 = r2_score(test_y, y_est_rbf)
print(rbf_test_r2)
train_est_rbf = svr_rbf.predict(train_feat_df[rbf_linear_features]) 
print(r2_score(train_y, train_est_rbf))
# Out:
# 0.8554225375482265
# 0.8997183260934308

# %%
plt.scatter(test_y, y_est_linear, alpha=0.5)
plt.plot(np.arange(0, 4.0, 0.5), np.arange(0, 4.0, 0.5), color="red")
plt.xlabel(r"Actual $M_L$", fontsize=16, labelpad=10)
plt.ylabel(r"Predicted $M_L$", fontsize=16, labelpad=10)
plt.text(0, 3.0, f'{r"$R^2$="} {linear_test_r2:.02f}', fontsize=14)
plt.text(0, 2.65, f'N={test_feat_df_scaled.shape[0]}', fontsize=14)
plt.title("P Magnitudes - SVR Linear", fontsize=20, y=1.05)
# Out:
# Text(0.5, 1.05, 'P Magnitudes - SVR Linear')

# %%
plt.scatter(test_y, y_est_rbf, alpha=0.5)
plt.plot(np.arange(0, 4.0, 0.5), np.arange(0, 4.0, 0.5), color="red")
plt.xlabel(r"Actual $M_L$", fontsize=16, labelpad=10)
plt.ylabel(r"Predicted $M_L$", fontsize=16, labelpad=10)
plt.text(0, 3.0, f'{r"$R^2$="} {rbf_test_r2:.02f}', fontsize=14)
plt.text(0, 2.65, f'N={test_feat_df_scaled.shape[0]}', fontsize=14)
plt.title(r"$M_L$ using P-arrival features", fontsize=20, y=1.05)
# Out:
# Text(0.5, 1.05, '$M_L$ using P-arrival features')

# %%
train_feat_df.shape
# Out:
# (3621, 46)

# %%
test_feat_df_scaled.shape
# Out:
# (884, 46)

# %%
svr_rbf = SVR(C=1.0, epsilon=0.1, kernel="rbf")
svr_rbf.fit(train_feat_df[train_feat_df.columns[no_sin_ba_feat_inds].tolist()], train_y)

y_est_rbf = svr_rbf.predict(test_feat_df_scaled[train_feat_df.columns[no_sin_ba_feat_inds].tolist()])
rbf_test_r2 = r2_score(test_y, y_est_rbf)
print(rbf_test_r2)
train_est_rbf = svr_rbf.predict(train_feat_df[train_feat_df.columns[no_sin_ba_feat_inds].tolist()]) 
print(r2_score(train_y, train_est_rbf))
# Out:
# 0.862514327245834
# 0.8987665337253342

# %% [markdown]
# ## Closer look at features with sr features

# %%
def add_feat_to_base(base_features, additional_features, all_features_cv=None, top_features_cv=None):

    cv_means = []

    for cf in additional_features:
        feat_list = base_features.copy()
        feat_list.append(cf)
        cv_vals = svr_cv(train_feat_df_unscaled[feat_list], train_y, folds)
        cv_means.append(np.mean(cv_vals))

    plt.scatter(range(len(additional_features)), cv_means, marker="x")
    plt.xticks(range(len(additional_features)), labels=additional_features, rotation=45);
    if all_features_cv is not None:
        plt.axhline(np.mean(all_features_cv))
    if top_features_cv is not None:
        plt.axhline(np.mean(top_features_cv), color="C1")
    plt.show()
    
    return cv_means

# %%
base_features = ['source_receiver_distance_logkm','source_depth_km', "receiver_back_azimuth"]

correlated_features = ['amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_variance',
                     'signal_dominant_amplitude']

cv_means = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm','source_depth_km', "receiver_back_azimuth", 'amp_02.0']

correlated_features = ['amp_10.0',
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_variance',
                     'signal_dominant_amplitude']

cv_means_amp02  = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm', "receiver_back_azimuth", 'amp_02.0']

correlated_features = ['amp_10.0',
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_variance',
                     'signal_dominant_amplitude']

cv_means_nodepth = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm', 'amp_02.0']

correlated_features = ['amp_10.0',
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_variance',
                     'signal_dominant_amplitude']


cv_means_nodepth_noba = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

# SR distance is important 
# base_features = ["receiver_back_azimuth",'amp_ratio_01.0', "amp_01.0"]

# correlated_features = ['amp_02.0', "amp_08.0", "amp_12.0", "amp_18.0", "signal_variance", 
#                        "signal_dominant_amplitude", "signal_max_amplitude"]

# cv_means_nodepth_nosrd = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
#                            top_features_cv=top_feat_sr_cv)

# %%
base_features = ['source_receiver_distance_logkm','source_depth_km', "receiver_back_azimuth"]

correlated_features = ['signal_variance', 'amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_dominant_amplitude']

cv_means = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm','source_depth_km', "receiver_back_azimuth", 'signal_variance']

correlated_features = ['amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_dominant_amplitude']

cv_means_amp02  = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm', "receiver_back_azimuth", 'signal_variance']

correlated_features = ['amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_dominant_amplitude']


cv_means_nodepth = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

base_features = ['source_receiver_distance_logkm', 'signal_variance']

correlated_features = ['amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_dominant_amplitude']

cv_means_nodepth_noba = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
                           top_features_cv=top_feat_sr_cv)

# SR distance is important 
# base_features = ["receiver_back_azimuth",'amp_ratio_01.0', "amp_01.0"]

# correlated_features = ['amp_02.0', "amp_08.0", "amp_12.0", "amp_18.0", "signal_variance", 
#                        "signal_dominant_amplitude", "signal_max_amplitude"]

# cv_means_nodepth_nosrd = add_feat_to_base(base_features, correlated_features, all_features_cv=selected_feat_sr_cv, 
#                            top_features_cv=top_feat_sr_cv)

# %%
correlated_features = ['amp_02.0', 'amp_10.0',
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_variance',
                     'signal_dominant_amplitude']

plt.scatter( range(0,len(correlated_features)), cv_means, marker="x", label="no_amp2.0")
plt.scatter( range(1,len(correlated_features)), cv_means_amp02, marker="o", label="yes_amp2.0")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth, marker="v", label="yes_amp2.0_no_depth")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_noba, marker="x", label="yes_amp2.0_nodepth_noba")
# plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_nosrd, marker="x", label="yes_amp1.0_nodepth_nosr")

plt.xticks(range(len(correlated_features)), labels=correlated_features, rotation=45);
plt.axhline(np.mean(selected_feat_sr_cv), label="all_selected_features")
plt.axhline(np.mean(top_feat_sr_cv), color="C1", label="top 5 features")
plt.legend();

# %%
correlated_features = ['signal_variance', 'amp_02.0', 'amp_10.0', 
                     'noise_max_amplitude',
                     'amp_04.0',
                     'amp_07.0',
                     'noise_variance',
                     'signal_dominant_amplitude']

plt.scatter( range(0,len(correlated_features)), cv_means, marker="x", label="no_sv")
plt.scatter( range(1,len(correlated_features)), cv_means_amp02, marker="o", label="yes_sv")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth, marker="v", label="yes_sv_no_depth")
plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_noba, marker="x", label="yes_sv_nodepth_noba")
# plt.scatter( range(1,len(correlated_features)), cv_means_nodepth_nosrd, marker="x", label="yes_amp1.0_nodepth_nosr")

plt.xticks(range(len(correlated_features)), labels=correlated_features, rotation=45);
plt.axhline(np.mean(selected_feat_sr_cv), label="all_selected_features")
plt.axhline(np.mean(top_feat_sr_cv), color="C1", label="top 5 features")
plt.legend();

# %%
fewer_features_sr = ['source_receiver_distance_logkm', "receiver_back_azimuth", "source_depth_km",'amp_02.0', 
                          "amp_10.0", "signal_variance"]
fewer_feat_sr_df = train_feat_df.copy()[fewer_features_sr]
fewer_feat_sr_df.loc[:, "magnitude"] = train_y
corr = fewer_feat_sr_df.corr()
corr.style.background_gradient(cmap="coolwarm")

# %%
fewer_feat_sr_cv = svr_cv(train_feat_df_unscaled[fewer_features_sr], train_y, folds)
print(fewer_feat_sr_cv)
print(np.mean(fewer_feat_sr_cv))

# %%
fewest_features_sr = ['source_receiver_distance_logkm', "receiver_back_azimuth", "source_depth_km","signal_variance"]
fewest_feat_sr_df = train_feat_df.copy()[fewest_features_sr]
fewest_feat_sr_df.loc[:, "magnitude"] = train_y
corr = fewest_feat_sr_df.corr()
corr.style.background_gradient(cmap="coolwarm")

# %%
fewest_feat_sr_cv = svr_cv(train_feat_df_unscaled[fewest_features_sr], train_y, folds)
print(fewest_feat_sr_cv)
print(np.mean(fewest_feat_sr_cv))

# %%
linear_features_sr = ['source_receiver_distance_logkm', "sin_receiver_back_azimuth", "source_depth_km",
                      "signal_variance"]
                      #,'amp_02.0', "amp_10.0", "noise_variance"]

linear_feat_sr_cv = svr_cv(train_feat_df_unscaled[linear_features_sr], train_y, folds, kernel="linear")
print(linear_feat_sr_cv)
print(np.mean(linear_feat_sr_cv))

# %% [markdown]
# ## Default C, gamma, and epsilon seem to work well for SVR with RBF

# %%
#C_range = [1.0]#np.logspace(-2, 10, 5)
gamma_range = [7.4e-05, 0.1, 0.2, 0.3, 0.4, 5e-1, 1, "scale", "auto"]#np.logspace(-9, 3, 5)
epsilon_range = [5e-3, 1e-2, 5e-2, 1e-1, 2e-1]
param_grid = {"svr__gamma":gamma_range,  "svr__epsilon":epsilon_range} #"svr__C":C_range,
pipeline = Pipeline(steps=[("scaler", StandardScaler()), ('svr', SVR(C=1.0))])
grid = GridSearchCV(pipeline, param_grid=param_grid, scoring="r2", n_jobs=3, cv=folds)
svr_cv_results = grid.fit(train_feat_df_unscaled[fewer_features_sr], train_y)

# %%
scores = grid.cv_results_["mean_test_score"].reshape(len(epsilon_range), len(gamma_range))
plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(
    scores,
    interpolation="nearest",
    cmap=plt.cm.viridis,
    #norm=MidpointNormalize(vmin=0.2, midpoint=0.92),
)
plt.xlabel("Gamma")
plt.ylabel("Epsilon")
plt.colorbar()
plt.xticks(np.arange(len(gamma_range)), gamma_range, rotation=45)
plt.yticks(np.arange(len(epsilon_range)), epsilon_range)
plt.title("Validation accuracy")
plt.show()

# %% [markdown]
# ## XGBoost
#
# Try more hyperparameters, try with limited features

# %%
from xgboost import XGBRegressor
from xgboost import DMatrix
import xgboost

# %%
from sklearn.utils.fixes import loguniform
import scipy.stats as stats

# %%
xgb = XGBRegressor(objective='reg:squarederror', eval_metric='rmse').fit(
                                    train_feat_matrix_unscaled[folds[0][0]], train_y[folds[0][0]])
xgb.score(train_feat_matrix_unscaled[folds[0][1]], train_y[folds[0][1]])

# %%
train_feat_df.columns[43]

# %%
fig, ax = plt.subplots(1, figsize=(10, 20))
xgboost.plot_importance(xgb, ax=ax)

# %%
feat_bool = np.isin(train_feat_df.columns, fewer_features_sr)
xgb = XGBRegressor(objective='reg:squarederror', eval_metric='rmse').fit(
                                    train_feat_matrix_unscaled[folds[0][0]][:, feat_bool], train_y[folds[0][0]])
xgb.score(train_feat_matrix_unscaled[folds[0][1]][:, feat_bool], train_y[folds[0][1]])

# %%
xgboost.plot_importance(xgb)

# %%
feat_bool = np.isin(train_feat_df.columns, fewer_features_lat_lon)
xgb = XGBRegressor(objective='reg:squarederror', eval_metric='rmse').fit(
                                    train_feat_matrix_unscaled[folds[0][0]][:, feat_bool], train_y[folds[0][0]])
xgb.score(train_feat_matrix_unscaled[folds[0][1]][:, feat_bool], train_y[folds[0][1]])

# %%
xgboost.plot_importance(xgb)

# %%
grid_params = {'max_depth': [1, 2, 3, 5, 10], 
          'eta': [0.05, 0.1, 0.2, 0.3, 0.5],
          'gamma': [0, 0.2, 0.5, 1, 1.5, 2, 5], 
         'min_child_weight':[0, 0.5, 1, 2], 
         'max_delta_step': [0, 1, 2], 
          'subsample': [0.5, 1]}

params = {'max_depth': stats.randint(3, 18),
          'gamma': stats.uniform(0, 5),
          'learning_rate': loguniform(1e-2, 1e0),
          'subsample': np.arange(0.5, 1.0, 0.1),
          'colsample_bytree':stats.uniform(0.5,1),
          'min_child_weight':stats.randint(0, 10), 
          'n_estimators': [100, 250, 500, 750],
          }
    
# params = {'objective': 'reg:squarederror'}
# params['eval_metric'] = 'rmse'
# params['nthread'] = 2

# %%
xgb = XGBRegressor(objective='reg:squarederror', eval_metric='rmse') #, topnthread=2
# grid_search = GridSearchCV(xgb, param_grid=grid_params, scoring="r2", 
#                            n_jobs=3, cv=folds).fit(train_feat_matrix_unscaled, train_y)
rand_search = RandomizedSearchCV(xgb, param_distributions=params, scoring="r2", 
                           n_jobs=3, cv=folds).fit(train_feat_matrix_unscaled[:, feat_bool], train_y)

# %%
rand_search.best_estimator_

# %%
# {'eta': 0.1,
#  'gamma': 0.5,
#  'max_delta_step': 1,
#  'max_depth': 5,
#  'min_child_weight': 0.5}

# 0.8620877350386309

# %%
rand_search.best_params_

# %%
rand_search.best_score_

# %%
results_df = pd.DataFrame(grid_search.cv_results_)
results_df.sort_values("rank_test_score")

# %%
num_round = 100
dtrain = DMatrix(train_feat_matrix_unscaled, label=train_y, feature_names=train_feat_df_unscaled.columns)
bst_cv = xgboost.cv(param, dtrain, num_round, folds=folds, early_stopping_rounds=3, 
               callbacks=[xgb.callback.EvaluationMonitor(show_stdv=True)])

# %%
x_ticks = range(1, len(bst_cv)+1)
plt.plot(x_ticks, bst_cv["train-rmse-mean"], color="k")
plt.plot(x_ticks, bst_cv["train-rmse-mean"]+bst_cv["train-rmse-std"], linestyle="--", color="C0")
plt.plot(x_ticks, bst_cv["train-rmse-mean"]-bst_cv["train-rmse-std"], linestyle="--", color="C0")
plt.fill_between(x_ticks,bst_cv["train-rmse-mean"]+bst_cv["train-rmse-std"], 
                 bst_cv["train-rmse-mean"]-bst_cv["train-rmse-std"], color="C0", alpha=0.5, label="train")

plt.plot(x_ticks, bst_cv["test-rmse-mean"], color="k")
plt.plot(x_ticks, bst_cv["test-rmse-mean"]+bst_cv["test-rmse-std"], linestyle="--", color="C1")
plt.plot(x_ticks, bst_cv["test-rmse-mean"]-bst_cv["test-rmse-std"], linestyle="--", color="C1")
plt.fill_between(x_ticks, bst_cv["test-rmse-mean"]+bst_cv["test-rmse-std"], 
                 bst_cv["test-rmse-mean"]-bst_cv["test-rmse-std"], color="C1", alpha=0.5, label="test")

plt.ylabel("RMSE")
plt.xlabel("Iteration")

#plt.xticks(x_ticks)
plt.legend()
