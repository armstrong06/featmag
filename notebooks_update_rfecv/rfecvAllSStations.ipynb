# %%
import numpy as np
import pandas as pd
from sklearn.base import clone 
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
import json
import sys
import os
# make paths above 'notebooks/' visible for local imports.
# +----------------------------------------------------------------------------+
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.processing import GatherFeatureDatasets
from src.utils import CrossValidation, write_dict_to_json
from src.feature_selection import CustomRFECVUpdate
from src.feature_selection import IntrinsicFeatureSelection as ifs

# %% [markdown]
# # Load in the data for all stations

# %%
proc = GatherFeatureDatasets(is_p=False)

# %%
datadir = '/uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_splits'
train = pd.read_csv(os.path.join(datadir, 's.train.csv'))
outfile_dir = '/uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds'
outfile_name = 'SVR.DT.rel'

# %%
station_feature_dict, station_meta_dict, feature_names = proc.process_all_stations_datasets(train, 
                                                                  scaler=False,
                                                                  linear_model=False,
                                                                  source_dist_type='dist')
# Out:
# YHB
# X shape: (1248, 45), y shape: (1248,)
# YHL
# X shape: (537, 45), y shape: (537,)
# YMR
# X shape: (1533, 45), y shape: (1533,)
# YHH
# X shape: (1222, 45), y shape: (1222,)
# B207
# X shape: (341, 45), y shape: (341,)
# FLWY
# X shape: (319, 45), y shape: (319,)
# YUF
# X shape: (816, 45), y shape: (816,)
# YPP
# X shape: (189, 45), y shape: (189,)
# YNR
# X shape: (2090, 45), y shape: (2090,)
# YML
# X shape: (423, 45), y shape: (423,)
# YFT
# X shape: (899, 45), y shape: (899,)
# LKWY
# X shape: (209, 45), y shape: (209,)
# YTP
# X shape: (391, 45), y shape: (391,)
# B206
# X shape: (195, 45), y shape: (195,)
# YMC
# X shape: (1443, 45), y shape: (1443,)
# YNM
# X shape: (487, 45), y shape: (487,)
# B950
# X shape: (152, 45), y shape: (152,)
# YDD
# X shape: (244, 45), y shape: (244,)

# %%
feature_names
# Out:
# array(['amp_ratio_1', 'amp_ratio_2', 'amp_ratio_3', 'amp_ratio_4',
#        'amp_ratio_5', 'amp_ratio_6', 'amp_ratio_7', 'amp_ratio_8',
#        'amp_ratio_9', 'amp_ratio_10', 'amp_ratio_11', 'amp_ratio_12',
#        'amp_ratio_13', 'amp_ratio_14', 'amp_ratio_15', 'amp_ratio_16',
#        'amp_ratio_17', 'amp_ratio_18', 'amp_1', 'amp_2', 'amp_3', 'amp_4',
#        'amp_5', 'amp_6', 'amp_7', 'amp_8', 'amp_9', 'amp_10', 'amp_11',
#        'amp_12', 'amp_13', 'amp_14', 'amp_15', 'amp_16', 'amp_17',
#        'amp_18', 'signal_dominant_frequency', 'signal_dominant_amplitude',
#        'noise_max_amplitude', 'signal_max_amplitude', 'signal_variance',
#        'noise_variance', 'source_depth_km',
#        'source_receiver_distance_logkm',
#        'source_receiver_back_azimuth_deg'], dtype='<U32')

# %% [markdown]
# ## Set parameters

# %%
### Set Parameters ###
cv_random_state=2652124
estimator_seed = 2652129
# The model to used to estimate feature importance 
estimator_model =  DecisionTreeRegressor(random_state=estimator_seed)
# # Boolean - True if data for estimator_model needs to be scaled
estimator_scaler = False
# The main model to fit
predictor_model = SVR(kernel='rbf')
# Boolean - True if data for model needs to be scaled 
model_scaler = True
# The scoring method to use in RFECV and GridCV
scoring_method = 'r2'
# The function used to evaluate the performance on the test model
score_func = r2_score
# True if a larger score_func value is better
larger_score_is_better = True
# The parameter space for GridCV to search
# Decrease upper-limit of C for linear model because 100 is very slow 
svr_Cspace = [1, 10, 100]
svr_gspace = [0.1, 0.01, 0.001]
param_grid = [
    {'m__C': svr_Cspace, 'm__gamma': svr_gspace},
]
# The number of jobs for RFECV and GridCV to use
n_jobs = 10
# number of folds for outer CV
cv_folds_outer = 5
# number of times to repeat outer CV
n_outer_repeats = 2
# number of folds for inner CV (used for hyperparameter tuning)
cv_folds_inner = 5
# number of folds for the final hyperparameter grid search
cv_folds_hp = 5
### Intrisic feature selection information 
# Function that takes in X, y, list of np arrays containing 
# the indices of features to filter, and K features to select
if_feat_inds = [np.arange(0, 18), np.arange(18, 36)]
if_K = 5
#####################

# %%
print(feature_names[if_feat_inds[0]])
print(feature_names[if_feat_inds[1]])
# Out:
# ['amp_ratio_1' 'amp_ratio_2' 'amp_ratio_3' 'amp_ratio_4' 'amp_ratio_5'
#  'amp_ratio_6' 'amp_ratio_7' 'amp_ratio_8' 'amp_ratio_9' 'amp_ratio_10'
#  'amp_ratio_11' 'amp_ratio_12' 'amp_ratio_13' 'amp_ratio_14'
#  'amp_ratio_15' 'amp_ratio_16' 'amp_ratio_17' 'amp_ratio_18']
# ['amp_1' 'amp_2' 'amp_3' 'amp_4' 'amp_5' 'amp_6' 'amp_7' 'amp_8' 'amp_9'
#  'amp_10' 'amp_11' 'amp_12' 'amp_13' 'amp_14' 'amp_15' 'amp_16' 'amp_17'
#  'amp_18']

# %% [markdown]
# ## Do RFECV and RFE with the selected N on the full training set for all stations

# %%
all_rfecv_results = {}
all_full_rfe_results = {}
for stat in station_feature_dict.keys():
    print(stat)
    X = station_feature_dict[stat]['X_train']
    y = station_meta_dict[stat]['y_train']
    # Do RFECV
    rfecv_results = CustomRFECVUpdate.do_rfecv(X, 
                                         y,
                                         clone(estimator_model),
                                         clone(predictor_model),
                                         param_grid,
                                         estimator_scaler=estimator_scaler,
                                         predictor_scaler=model_scaler,
                                         estimator_params_grid=None,
                                         scoring_method=scoring_method,
                                         score_func=score_func,
                                         n_jobs=n_jobs,
                                         cv_folds_outer=cv_folds_outer,
                                         cv_folds_inner=cv_folds_inner,
                                         n_outer_repeats=n_outer_repeats,
                                         cv_random_state=cv_random_state,
                                         larger_score_is_better=larger_score_is_better,
                                         intrinsic_filter_func=ifs.MI_filter_func,
                                         feature_inds_to_filter=if_feat_inds,
                                         intrinsic_filter_K=if_K
                                         )
    filename_rfecv = os.path.join(outfile_dir, f'{stat}.{outfile_name}.rfecv.json')
    write_dict_to_json(filename_rfecv, rfecv_results)
    all_rfecv_results[stat] = rfecv_results


    # Use selected N from RFECV on full training set
    mi_selected_features, mi_filtered_feature_inds = ifs.MI_filter_func(X, 
                                                                        y, 
                                                                        if_feat_inds, 
                                                                        if_K)
    X_mi = X[:, mi_filtered_feature_inds]
    hp_grid_search, hp_cv = CrossValidation.setup_cv(clone(predictor_model), 
                                                        param_grid, 
                                                        model_scaler=model_scaler, 
                                                        scoring_method=scoring_method, 
                                                        n_jobs=n_jobs, 
                                                        cv_folds=cv_folds_hp, 
                                                        cv_random_state=cv_random_state+10, 
                                                        refit_model=False)
    
    full_N_results = CustomRFECVUpdate.get_final_N_features(X_mi,
                                                        y,
                                                        rfecv_results,
                                                        estimator_model,
                                                        estimator_scaler,
                                                        hp_grid_search,
                                                        filtered_feat_inds=mi_filtered_feature_inds)

    full_N_results["intrinsic_K_feature_selection"] = mi_selected_features
    filename_rfe = os.path.join(outfile_dir, f'{stat}.{outfile_name}.rfe.full.json')
    write_dict_to_json(filename_rfe, full_N_results)
    all_full_rfe_results[stat] = full_N_results


filename_rfecv = os.path.join(outfile_dir, f'all.{outfile_name}.rfecv.json')
write_dict_to_json(filename_rfecv, all_rfecv_results)
filename_rfe = os.path.join(outfile_dir, f'all.{outfile_name}.rfe.full.json')
write_dict_to_json(filename_rfe, all_full_rfe_results)
# Out:
# YHB
# reducing features to 19
# Fold 0: N=16, test_score=0.953
# reducing features to 19
# Fold 1: N=18, test_score=0.958
# reducing features to 19
# Fold 2: N=19, test_score=0.952
# reducing features to 19
# Fold 3: N=8, test_score=0.956
# reducing features to 19
# Fold 4: N=12, test_score=0.952
# reducing features to 19
# Fold 5: N=19, test_score=0.950
# reducing features to 19
# Fold 6: N=18, test_score=0.963
# reducing features to 19
# Fold 7: N=17, test_score=0.959
# reducing features to 19
# Fold 8: N=10, test_score=0.953
# reducing features to 19
# Fold 9: N=15, test_score=0.946
# total time: 188.76 s
# Selected number of features: 18 (avg. score of 0.95); 1 STE: N=7 (avg. 0.95)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YHB.SVR.DT.rel.rfecv.json
# {'best': 18, 'oste': 7}
# 18: CV Mean: 0.95, CV STD: 0.00
# 7: CV Mean: 0.95, CV STD: 0.00
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YHB.SVR.DT.rel.rfe.full.json
# YHL
# reducing features to 19
# Fold 0: N=19, test_score=0.947
# reducing features to 19
# Fold 1: N=9, test_score=0.941
# reducing features to 19
# Fold 2: N=8, test_score=0.934
# reducing features to 19
# Fold 3: N=15, test_score=0.932
# reducing features to 19
# Fold 4: N=16, test_score=0.920
# reducing features to 19
# Fold 5: N=18, test_score=0.941
# reducing features to 19
# Fold 6: N=17, test_score=0.940
# reducing features to 19
# Fold 7: N=8, test_score=0.945
# reducing features to 19
# Fold 8: N=13, test_score=0.917
# reducing features to 19
# Fold 9: N=14, test_score=0.937
# total time: 56.90 s
# Selected number of features: 15 (avg. score of 0.93); 1 STE: N=7 (avg. 0.93)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YHL.SVR.DT.rel.rfecv.json
# {'best': 15, 'oste': 7}
# 15: CV Mean: 0.93, CV STD: 0.01
# 7: CV Mean: 0.92, CV STD: 0.02
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YHL.SVR.DT.rel.rfe.full.json
# YMR
# reducing features to 19
# Fold 0: N=12, test_score=0.948
# reducing features to 19
# Fold 1: N=9, test_score=0.951
# reducing features to 19
# Fold 2: N=12, test_score=0.957
# reducing features to 19
# Fold 3: N=13, test_score=0.950
# reducing features to 19
# Fold 4: N=17, test_score=0.951
# reducing features to 19
# Fold 5: N=15, test_score=0.954
# reducing features to 19
# Fold 6: N=16, test_score=0.938
# reducing features to 19
# Fold 7: N=17, test_score=0.952
# reducing features to 19
# Fold 8: N=19, test_score=0.959
# reducing features to 19
# Fold 9: N=9, test_score=0.952
# total time: 290.81 s
# Selected number of features: 16 (avg. score of 0.95); 1 STE: N=6 (avg. 0.94)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YMR.SVR.DT.rel.rfecv.json
# {'best': 16, 'oste': 6}
# 16: CV Mean: 0.95, CV STD: 0.01
# 6: CV Mean: 0.94, CV STD: 0.01
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YMR.SVR.DT.rel.rfe.full.json
# YHH
# reducing features to 19
# Fold 0: N=18, test_score=0.902
# reducing features to 19
# Fold 1: N=17, test_score=0.901
# reducing features to 19
# Fold 2: N=19, test_score=0.908
# reducing features to 19
# Fold 3: N=18, test_score=0.894
# reducing features to 19
# Fold 4: N=12, test_score=0.923
# reducing features to 19
# Fold 5: N=13, test_score=0.924
# reducing features to 19
# Fold 6: N=12, test_score=0.888
# reducing features to 19
# Fold 7: N=18, test_score=0.893
# reducing features to 19
# Fold 8: N=19, test_score=0.942
# reducing features to 19
# Fold 9: N=11, test_score=0.887
# total time: 222.80 s
# Selected number of features: 18 (avg. score of 0.90); 1 STE: N=9 (avg. 0.89)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YHH.SVR.DT.rel.rfecv.json
# {'best': 18, 'oste': 9}
# 18: CV Mean: 0.90, CV STD: 0.02
# 9: CV Mean: 0.90, CV STD: 0.02
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YHH.SVR.DT.rel.rfe.full.json
# B207
# reducing features to 19
# Fold 0: N=9, test_score=0.939
# reducing features to 19
# Fold 1: N=11, test_score=0.928
# reducing features to 19
# Fold 2: N=6, test_score=0.877
# reducing features to 19
# Fold 3: N=8, test_score=0.924
# reducing features to 19
# Fold 4: N=19, test_score=0.909
# reducing features to 19
# Fold 5: N=16, test_score=0.909
# reducing features to 19
# Fold 6: N=18, test_score=0.920
# reducing features to 19
# Fold 7: N=9, test_score=0.897
# reducing features to 19
# Fold 8: N=9, test_score=0.944
# reducing features to 19
# Fold 9: N=7, test_score=0.932
# total time: 33.66 s
# Selected number of features: 9 (avg. score of 0.91); 1 STE: N=5 (avg. 0.90)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/B207.SVR.DT.rel.rfecv.json
# {'best': 9, 'oste': 5}
# 9: CV Mean: 0.92, CV STD: 0.02
# 5: CV Mean: 0.90, CV STD: 0.02
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/B207.SVR.DT.rel.rfe.full.json
# FLWY
# reducing features to 19
# Fold 0: N=19, test_score=0.838
# reducing features to 19
# Fold 1: N=4, test_score=0.818
# reducing features to 19
# Fold 2: N=9, test_score=0.808
# reducing features to 19
# Fold 3: N=13, test_score=0.739
# reducing features to 19
# Fold 4: N=10, test_score=0.849
# reducing features to 19
# Fold 5: N=5, test_score=0.842
# reducing features to 19
# Fold 6: N=11, test_score=0.785
# reducing features to 19
# Fold 7: N=17, test_score=0.835
# reducing features to 19
# Fold 8: N=6, test_score=0.822
# reducing features to 19
# Fold 9: N=19, test_score=0.823
# total time: 31.30 s
# Selected number of features: 19 (avg. score of 0.81); 1 STE: N=12 (avg. 0.80)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/FLWY.SVR.DT.rel.rfecv.json
# {'best': 19, 'oste': 12}
# 19: CV Mean: 0.80, CV STD: 0.04
# 12: CV Mean: 0.81, CV STD: 0.04
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/FLWY.SVR.DT.rel.rfe.full.json
# YUF
# reducing features to 19
# Fold 0: N=11, test_score=0.930
# reducing features to 19
# Fold 1: N=15, test_score=0.950
# reducing features to 19
# Fold 2: N=11, test_score=0.959
# reducing features to 19
# Fold 3: N=10, test_score=0.938
# reducing features to 19
# Fold 4: N=16, test_score=0.902
# reducing features to 19
# Fold 5: N=14, test_score=0.949
# reducing features to 19
# Fold 6: N=14, test_score=0.955
# reducing features to 19
# Fold 7: N=15, test_score=0.910
# reducing features to 19
# Fold 8: N=19, test_score=0.947
# reducing features to 19
# Fold 9: N=12, test_score=0.925
# total time: 103.52 s
# Selected number of features: 15 (avg. score of 0.93); 1 STE: N=10 (avg. 0.92)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YUF.SVR.DT.rel.rfecv.json
# {'best': 15, 'oste': 10}
# 15: CV Mean: 0.93, CV STD: 0.01
# 10: CV Mean: 0.93, CV STD: 0.01
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YUF.SVR.DT.rel.rfe.full.json
# YPP
# reducing features to 19
# Fold 0: N=7, test_score=0.938
# reducing features to 19
# Fold 1: N=9, test_score=0.898
# reducing features to 19
# Fold 2: N=16, test_score=0.917
# reducing features to 19
# Fold 3: N=18, test_score=0.881
# reducing features to 19
# Fold 4: N=10, test_score=0.874
# reducing features to 19
# Fold 5: N=5, test_score=0.956
# reducing features to 19
# Fold 6: N=8, test_score=0.883
# reducing features to 19
# Fold 7: N=7, test_score=0.871
# reducing features to 19
# Fold 8: N=16, test_score=0.931
# reducing features to 19
# Fold 9: N=12, test_score=0.926
# total time: 20.66 s
# Selected number of features: 19 (avg. score of 0.89); 1 STE: N=5 (avg. 0.87)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YPP.SVR.DT.rel.rfecv.json
# {'best': 19, 'oste': 5}
# 19: CV Mean: 0.90, CV STD: 0.03
# 5: CV Mean: 0.90, CV STD: 0.02
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YPP.SVR.DT.rel.rfe.full.json
# YNR
# reducing features to 19
# Fold 0: N=17, test_score=0.939
# reducing features to 19
# Fold 1: N=11, test_score=0.955
# reducing features to 19
# Fold 2: N=15, test_score=0.954
# reducing features to 19
# Fold 3: N=15, test_score=0.940
# reducing features to 19
# Fold 4: N=19, test_score=0.958
# reducing features to 19
# Fold 5: N=11, test_score=0.960
# reducing features to 19
# Fold 6: N=11, test_score=0.956
# reducing features to 19
# Fold 7: N=19, test_score=0.954
# reducing features to 19
# Fold 8: N=14, test_score=0.950
# reducing features to 19
# Fold 9: N=10, test_score=0.925
# total time: 472.02 s
# Selected number of features: 15 (avg. score of 0.95); 1 STE: N=5 (avg. 0.93)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YNR.SVR.DT.rel.rfecv.json
# {'best': 15, 'oste': 5}
# 15: CV Mean: 0.95, CV STD: 0.01
# 5: CV Mean: 0.93, CV STD: 0.01
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YNR.SVR.DT.rel.rfe.full.json
# YML
# reducing features to 19
# Fold 0: N=19, test_score=0.920
# reducing features to 19
# Fold 1: N=8, test_score=0.948
# reducing features to 19
# Fold 2: N=12, test_score=0.918
# reducing features to 19
# Fold 3: N=10, test_score=0.950
# reducing features to 19
# Fold 4: N=8, test_score=0.925
# reducing features to 19
# Fold 5: N=7, test_score=0.952
# reducing features to 19
# Fold 6: N=10, test_score=0.931
# reducing features to 19
# Fold 7: N=11, test_score=0.923
# reducing features to 19
# Fold 8: N=17, test_score=0.918
# reducing features to 19
# Fold 9: N=10, test_score=0.920
# total time: 43.23 s
# Selected number of features: 10 (avg. score of 0.92); 1 STE: N=3 (avg. 0.90)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YML.SVR.DT.rel.rfecv.json
# {'best': 10, 'oste': 3}
# 10: CV Mean: 0.92, CV STD: 0.02
# 3: CV Mean: 0.90, CV STD: 0.02
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YML.SVR.DT.rel.rfe.full.json
# YFT
# reducing features to 19
# Fold 0: N=13, test_score=0.964
# reducing features to 19
# Fold 1: N=10, test_score=0.966
# reducing features to 19
# Fold 2: N=18, test_score=0.952
# reducing features to 19
# Fold 3: N=11, test_score=0.944
# reducing features to 19
# Fold 4: N=8, test_score=0.953
# reducing features to 19
# Fold 5: N=13, test_score=0.956
# reducing features to 19
# Fold 6: N=9, test_score=0.959
# reducing features to 19
# Fold 7: N=19, test_score=0.963
# reducing features to 19
# Fold 8: N=19, test_score=0.957
# reducing features to 19
# Fold 9: N=18, test_score=0.957
# total time: 101.51 s
# Selected number of features: 17 (avg. score of 0.96); 1 STE: N=3 (avg. 0.93)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YFT.SVR.DT.rel.rfecv.json
# {'best': 17, 'oste': 3}
# 17: CV Mean: 0.95, CV STD: 0.01
# 3: CV Mean: 0.93, CV STD: 0.01
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YFT.SVR.DT.rel.rfe.full.json
# LKWY
# reducing features to 19
# Fold 0: N=6, test_score=0.891
# reducing features to 19
# Fold 1: N=14, test_score=0.936
# reducing features to 19
# Fold 2: N=3, test_score=0.943
# reducing features to 19
# Fold 3: N=14, test_score=0.903
# reducing features to 19
# Fold 4: N=16, test_score=0.946
# reducing features to 19
# Fold 5: N=11, test_score=0.883
# reducing features to 19
# Fold 6: N=11, test_score=0.951
# reducing features to 19
# Fold 7: N=10, test_score=0.897
# reducing features to 19
# Fold 8: N=7, test_score=0.939
# reducing features to 19
# Fold 9: N=16, test_score=0.947
# total time: 20.29 s
# Selected number of features: 7 (avg. score of 0.91); 1 STE: N=2 (avg. 0.87)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/LKWY.SVR.DT.rel.rfecv.json
# {'best': 7, 'oste': 2}
# 7: CV Mean: 0.92, CV STD: 0.02
# 2: CV Mean: 0.90, CV STD: 0.02
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/LKWY.SVR.DT.rel.rfe.full.json
# YTP
# reducing features to 19
# Fold 0: N=3, test_score=0.886
# reducing features to 19
# Fold 1: N=17, test_score=0.904
# reducing features to 19
# Fold 2: N=19, test_score=0.913
# reducing features to 19
# Fold 3: N=18, test_score=0.895
# reducing features to 19
# Fold 4: N=19, test_score=0.892
# reducing features to 19
# Fold 5: N=19, test_score=0.900
# reducing features to 19
# Fold 6: N=17, test_score=0.864
# reducing features to 19
# Fold 7: N=16, test_score=0.912
# reducing features to 19
# Fold 8: N=16, test_score=0.920
# reducing features to 19
# Fold 9: N=19, test_score=0.868
# total time: 36.06 s
# Selected number of features: 19 (avg. score of 0.89); 1 STE: N=5 (avg. 0.88)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YTP.SVR.DT.rel.rfecv.json
# {'best': 19, 'oste': 5}
# 19: CV Mean: 0.89, CV STD: 0.03
# 5: CV Mean: 0.88, CV STD: 0.04
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YTP.SVR.DT.rel.rfe.full.json
# B206
# reducing features to 19
# Fold 0: N=9, test_score=0.949
# reducing features to 19
# Fold 1: N=12, test_score=0.839
# reducing features to 19
# Fold 2: N=5, test_score=0.953
# reducing features to 19
# Fold 3: N=6, test_score=0.899
# reducing features to 19
# Fold 4: N=17, test_score=0.955
# reducing features to 19
# Fold 5: N=12, test_score=0.845
# reducing features to 19
# Fold 6: N=5, test_score=0.948
# reducing features to 19
# Fold 7: N=15, test_score=0.887
# reducing features to 19
# Fold 8: N=18, test_score=0.935
# reducing features to 19
# Fold 9: N=11, test_score=0.944
# total time: 19.78 s
# Selected number of features: 12 (avg. score of 0.90); 1 STE: N=5 (avg. 0.87)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/B206.SVR.DT.rel.rfecv.json
# {'best': 12, 'oste': 5}
# 12: CV Mean: 0.88, CV STD: 0.06
# 5: CV Mean: 0.87, CV STD: 0.07
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/B206.SVR.DT.rel.rfe.full.json
# YMC
# reducing features to 19
# Fold 0: N=14, test_score=0.848
# reducing features to 19
# Fold 1: N=11, test_score=0.852
# reducing features to 19
# Fold 2: N=12, test_score=0.851
# reducing features to 19
# Fold 3: N=11, test_score=0.860
# reducing features to 19
# Fold 4: N=10, test_score=0.830
# reducing features to 19
# Fold 5: N=16, test_score=0.833
# reducing features to 19
# Fold 6: N=12, test_score=0.860
# reducing features to 19
# Fold 7: N=7, test_score=0.854
# reducing features to 19
# Fold 8: N=14, test_score=0.834
# reducing features to 19
# Fold 9: N=17, test_score=0.858
# total time: 327.69 s
# Selected number of features: 13 (avg. score of 0.84); 1 STE: N=7 (avg. 0.82)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YMC.SVR.DT.rel.rfecv.json
# {'best': 13, 'oste': 7}
# 13: CV Mean: 0.85, CV STD: 0.02
# 7: CV Mean: 0.83, CV STD: 0.03
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YMC.SVR.DT.rel.rfe.full.json
# YNM
# reducing features to 19
# Fold 0: N=15, test_score=0.944
# reducing features to 19
# Fold 1: N=11, test_score=0.962
# reducing features to 19
# Fold 2: N=11, test_score=0.962
# reducing features to 19
# Fold 3: N=8, test_score=0.967
# reducing features to 19
# Fold 4: N=15, test_score=0.962
# reducing features to 19
# Fold 5: N=13, test_score=0.953
# reducing features to 19
# Fold 6: N=19, test_score=0.963
# reducing features to 19
# Fold 7: N=12, test_score=0.972
# reducing features to 19
# Fold 8: N=16, test_score=0.948
# reducing features to 19
# Fold 9: N=13, test_score=0.975
# total time: 41.49 s
# Selected number of features: 12 (avg. score of 0.96); 1 STE: N=5 (avg. 0.95)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YNM.SVR.DT.rel.rfecv.json
# {'best': 12, 'oste': 5}
# 12: CV Mean: 0.96, CV STD: 0.00
# 5: CV Mean: 0.96, CV STD: 0.01
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YNM.SVR.DT.rel.rfe.full.json
# B950
# reducing features to 19
# Fold 0: N=8, test_score=0.920
# reducing features to 19
# Fold 1: N=16, test_score=0.897
# reducing features to 19
# Fold 2: N=19, test_score=0.929
# reducing features to 19
# Fold 3: N=19, test_score=0.919
# reducing features to 19
# Fold 4: N=4, test_score=0.829
# reducing features to 19
# Fold 5: N=9, test_score=0.920
# reducing features to 19
# Fold 6: N=9, test_score=0.875
# reducing features to 19
# Fold 7: N=10, test_score=0.924
# reducing features to 19
# Fold 8: N=13, test_score=0.876
# reducing features to 19
# Fold 9: N=18, test_score=0.934
# total time: 18.32 s
# Selected number of features: 17 (avg. score of 0.89); 1 STE: N=9 (avg. 0.88)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/B950.SVR.DT.rel.rfecv.json
# {'best': 17, 'oste': 9}
# 17: CV Mean: 0.90, CV STD: 0.04
# 9: CV Mean: 0.89, CV STD: 0.04
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/B950.SVR.DT.rel.rfe.full.json
# YDD
# reducing features to 19
# Fold 0: N=16, test_score=0.904
# reducing features to 19
# Fold 1: N=9, test_score=0.890
# reducing features to 19
# Fold 2: N=4, test_score=0.909
# reducing features to 19
# Fold 3: N=4, test_score=0.935
# reducing features to 19
# Fold 4: N=19, test_score=0.948
# reducing features to 19
# Fold 5: N=3, test_score=0.934
# reducing features to 19
# Fold 6: N=5, test_score=0.892
# reducing features to 19
# Fold 7: N=10, test_score=0.925
# reducing features to 19
# Fold 8: N=11, test_score=0.952
# reducing features to 19
# Fold 9: N=6, test_score=0.912
# total time: 23.12 s
# Selected number of features: 5 (avg. score of 0.91); 1 STE: N=3 (avg. 0.90)
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YDD.SVR.DT.rel.rfecv.json
# {'best': 5, 'oste': 3}
# 5: CV Mean: 0.90, CV STD: 0.03
# 3: CV Mean: 0.91, CV STD: 0.03
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/YDD.SVR.DT.rel.rfe.full.json
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/all.SVR.DT.rel.rfecv.json
# Writing /uufs/chpc.utah.edu/common/home/koper-group3/alysha/magnitudes/feature_selection_update/rfecvS_diffSeeds/all.SVR.DT.rel.rfe.full.json
